# %%
pip install numpy==1.23.3
# Out:
# Requirement already satisfied: numpy==1.23.3 in /usr/local/lib/python3.10/dist-packages (1.23.3)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
print(np.__version__)
# Out:
# 1.23.3

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import os

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau

# %%
print(tf.config.list_physical_devices())
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
print(tf.__version__)
# Out:
# 2.15.0

# %%
labels = ['PNEUMONIA', 'NORMAL']
img_size = 150
def get_training_data(data_dir):
    data = []
    for label in labels:
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data,dtype="object")

# %%
train = get_training_data('/content/drive/MyDrive/pneumonia_data/train_CLAHE_limit3')
test = get_training_data('/content/drive/MyDrive/pneumonia_data/test_CLAHE_limit3')
val = get_training_data('/content/drive/MyDrive/pneumonia_data/val_CLAHE_limit3')

# %%
import seaborn as sns

# %%
print(sns.__version__)
# Out:
# 0.13.1

# %%
l = []
for i in train:
    if(i[1] == 0):
        l.append("Pneumonia")
    else:
        l.append("Normal")
sns.set_style('darkgrid')
sns.countplot(l)
# Out:
# <Axes: xlabel='count'>

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[0][0], cmap='gray')
plt.title(labels[train[0][1]])

plt.figure(figsize = (5,5))
plt.imshow(train[-1][0], cmap='gray')
plt.title(labels[train[-1][1]])
# Out:
# Text(0.5, 1.0, 'NORMAL')

# %%
x_train = []
y_train = []

x_val = []
y_val = []

x_test = []
y_test = []

for feature, label in train:
    x_train.append(feature)
    y_train.append(label)

for feature, label in test:
    x_test.append(feature)
    y_test.append(label)

for feature, label in val:
    x_val.append(feature)
    y_val.append(label)

# %%
# Normalize the data
x_train = np.array(x_train) / 255
x_val = np.array(x_val) / 255
x_test = np.array(x_test) / 255

# %%
# resize data for deep learning
x_train = x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)

x_val = x_val.reshape(-1, img_size, img_size, 1)
y_val = np.array(y_val)

x_test = x_test.reshape(-1, img_size, img_size, 1)
y_test = np.array(y_test)

# %%
print("Count before augmentation:", len(x_train))
# Out:
# Count before augmentation: 4684

# %%
def load_augmented_data(augmented_dir, label, img_size):
    augmented_data = []
    for img in os.listdir(augmented_dir):
        try:
            img_arr = cv2.imread(os.path.join(augmented_dir, img), cv2.IMREAD_GRAYSCALE)
            resized_arr = cv2.resize(img_arr, (img_size, img_size))
            augmented_data.append([resized_arr, label])
        except Exception as e:
            print(e)
    return np.array(augmented_data)

# Define parameters
# Define parameters
save_dir = '/content/drive/MyDrive/pneumonia_data/augmented_CLAHE_limit3/NORMAL'  # Directory to save augmented images
label = 'NORMAL'  # Class label to augment
img_size = 150  # Image size (adjust if different)
additional_images_needed = 2690  # Number of additional images needed
batch_size = 32  # Number of images to generate per original image

# Load augmented 'Normal' images (assuming label for 'Normal' is 1)
augmented_normal_data = load_augmented_data(save_dir, label=1, img_size=img_size)

# Convert to appropriate format and normalize
x_augmented_normal = np.array([i[0] for i in augmented_normal_data]) / 255
x_augmented_normal = x_augmented_normal.reshape(-1, img_size, img_size, 1)
y_augmented_normal = np.array([i[1] for i in augmented_normal_data])

# Append to existing training data
x_train = np.concatenate((x_train, x_augmented_normal), axis=0)
y_train = np.concatenate((y_train, y_augmented_normal), axis=0)

# Shuffle the dataset
indices = np.arange(x_train.shape[0])
np.random.shuffle(indices)
x_train = x_train[indices]
y_train = y_train[indices]

# Count after augmentation
print("Count after augmentation:", len(x_train))
# Out:
# <ipython-input-19-83f794ec0b6f>:10: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(augmented_data)
# Count after augmentation: 7069

# %% [markdown]
# # Optimized Optimization

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

class CNN(Sequential):
    def __init__(self, nfilters, sfilters):
        super().__init__()
        tf.random.set_seed(0)
        self.add(Conv2D(nfilters[0], kernel_size=(sfilters[0], sfilters[0]), padding='same', activation='relu', input_shape=(150, 150, 1)))
        self.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

        self.add(Conv2D(nfilters[1], kernel_size=(sfilters[1], sfilters[1]), padding='same', activation='relu'))
        self.add(Dropout(0.1))
        self.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

        self.add(Conv2D(nfilters[2], kernel_size=(sfilters[2], sfilters[2]), padding='same', activation='relu'))
        self.add(Dropout(0.2))
        self.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

        self.add(Flatten())
        self.add(Dropout(0.2))
        self.add(Dense(128, activation='relu'))
        self.add(Dense(units=1, activation='sigmoid'))
        self.compile(optimizer="adam", loss='binary_crossentropy', metrics=['accuracy'])

# %%
class Genetic:
    def __init__(self, pop_size, nlayers, max_nfilters, max_sfilters):
        self.pop_size = pop_size
        self.nlayers = nlayers
        self.max_nfilters = max_nfilters
        self.max_sfilters = max_sfilters
        self.max_acc = 0
        self.best_arch = np.zeros((1, 6))
        self.gen_acc = []


    # def generate_population(self):
    #     np.random.seed(0)

    #     # Membuat partisi untuk nfilter
    #     partition_size_nfilter = self.max_nfilters // self.pop_size
    #     pop_nlayers = np.array([
    #         np.random.randint(1 + i * partition_size_nfilter, (i + 1) * partition_size_nfilter, self.nlayers)
    #         for i in range(self.pop_size)
    #     ])

    #     # Membuat partisi untuk sfilter
    #     partition_size_sfilter = self.max_sfilters // self.pop_size
    #     pop_sfilters = np.array([
    #         np.random.randint(1 + i * partition_size_sfilter, (i + 1) * partition_size_sfilter, self.nlayers)
    #         for i in range(self.pop_size)
    #     ])

    #     # Menggabungkan kedua set parameter
    #     pop_total = np.concatenate((pop_nlayers, pop_sfilters), axis=1)
    #     return pop_total

    def generate_unique_values(self, max_value, taken_values):
        partition_size = max_value // self.nlayers
        unique_values = []
        for j in range(self.nlayers):
            start = j * partition_size + 1
            if j == self.nlayers - 1:  # Ensure the last partition reaches the max value
                end = max_value + 1
            else:
                end = start + partition_size

            # Generate a unique value within the partition
            value = np.random.randint(start, end)
            while value in taken_values:  # Ensure uniqueness
                value += 1
                if value >= end:  # Reset if exceeds partition
                    value = start

            taken_values.add(value)
            unique_values.append(value)

        return unique_values

    def generate_population(self):
        np.random.seed(0)

        # Initialize population array
        pop_total = np.zeros((self.pop_size, self.nlayers * 2), dtype=int)

        for i in range(self.pop_size):
            taken_values_nfilters = set()
            taken_values_sfilters = set()

            # Generate unique nfilters and sfilters for each individual
            nfilters = self.generate_unique_values(self.max_nfilters, taken_values_nfilters)
            sfilters = self.generate_unique_values(self.max_sfilters, taken_values_sfilters)

            # Combine nfilters and sfilters for the individual
            pop_total[i] = nfilters + sfilters

        return pop_total


    def select_parents(self, pop, nparents, fitness):
        parents = np.zeros((nparents, pop.shape[1]))
        for i in range(nparents):
            best = np.argmax(fitness)
            parents[i] = pop[best]
            fitness[best] = -99999
        return parents

    def crossover(self, parents):
        nchild = self.pop_size - parents.shape[0]
        nparents = parents.shape[0]
        child = np.zeros((nchild, parents.shape[1]))
        for i in range(nchild):
            first = i % nparents
            second = (i + 1) % nparents
            child[i, :2] = parents[first][:2]
            child[i, 2] = parents[second][2]
            child[i, 3:5] = parents[first][3:5]
            child[i, 5] = parents[second][5]
        return child

    def mutation(self, child):
        for i in range(child.shape[0]):
            val = np.random.randint(1, 6)
            ind = np.random.randint(1, 4) - 1
            if child[i][ind] + val > 100:
                child[i][ind] -= val
            else:
                child[i][ind] += val
            val = np.random.randint(1, 4)
            ind = np.random.randint(4, 7) - 1
            if child[i][ind] + val > 20:
                child[i][ind] -= val
            else:
                child[i][ind] += val
        return child

    def fitness(self, pop, X, Y, epochs):
        pop_acc = []
        for i in range(pop.shape[0]):
            nfilters = pop[i][0:3]
            sfilters = pop[i][3:]
            model = CNN(nfilters, sfilters)
            learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=2, verbose=1, factor=0.3, min_lr=0.000001)
            history = model.fit(X, Y, batch_size=64, epochs=epochs, validation_data=[x_val, y_val], callbacks=[learning_rate_reduction])
            acc = max(history.history['accuracy'])
            pop_acc.append(acc * 100)
        if max(pop_acc) > self.max_acc:
            self.max_acc = max(pop_acc)
            self.best_arch = pop[np.argmax(pop_acc)]
        self.gen_acc.append(max(pop_acc))
        return pop_acc

    def smooth_curve(self, factor, gen):
        smoothed_points = []
        for point in self.gen_acc:
            if smoothed_points:
                prev = smoothed_points[-1]
                smoothed_points.append(prev * factor + point * (1 - factor))
            else:
                smoothed_points.append(point)
        plt.plot(range(gen + 1), smoothed_points, 'g', label='Smoothed training acc')
        plt.xticks(np.arange(gen + 1))
        plt.legend()
        plt.title('Fitness Accuracy vs Generations')
        plt.xlabel('Generations')
        plt.ylabel('Fitness (%)')
        plt.show()

# %%
pop_size = 10
nlayers = 3
max_nfilters = 100
max_sfilters = 10
epochs = 10
num_generations = 30

genCNN = Genetic(pop_size, nlayers, max_nfilters, max_sfilters)
# pop = genCNN.generate_population()
pop = np.array([[35, 45, 94,  6,  5, 14],
                [35, 45, 86,  5,  4, 11],
                [35, 45, 96,  5,  5, 14],
                [41, 45, 91,  5,  4, 17],
                [38, 50, 93,  6,  8, 17],
                [35, 45, 91,  9,  5, 11],
                [35, 45, 98,  8,  4, 14],
                [35, 45, 95,  5,  6, 17],
                [43, 45, 93,  5,  5, 17],
                [43, 50, 94,  7,  8, 14]])

# pop = np.array(result_pop)

pop
# Out:
# array([[35, 45, 94,  6,  5, 14],
#        [35, 45, 86,  5,  4, 11],
#        [35, 45, 96,  5,  5, 14],
#        [41, 45, 91,  5,  4, 17],
#        [38, 50, 93,  6,  8, 17],
#        [35, 45, 91,  9,  5, 11],
#        [35, 45, 98,  8,  4, 14],
#        [35, 45, 95,  5,  6, 17],
#        [43, 45, 93,  5,  5, 17],
#        [43, 50, 94,  7,  8, 14]])

# %%
with tf.device('/cpu:0'):
   x = tf.convert_to_tensor(x_train, np.float32)
   y = tf.convert_to_tensor(y_train, np.float32)

with tf.device('/cpu:0'):
   x_t = tf.convert_to_tensor(x_test, np.float32)
   y_t = tf.convert_to_tensor(y_test, np.float32)

bestModelEachGeneration = []

True_Positive = []
True_Negative = []
False_Positive = []
False_negative = []
acc = []
error = []
precision = []
recall = []
TP_rate = []
FP_rate = []
specificity = []
wrong_prediction = []
F1 = []

for i in range(num_generations + 1):
    print(pop)
    pop_acc = genCNN.fitness(pop, x, y, epochs)
    print('Best Accuracy at the generation {}: {}'.format(i, genCNN.max_acc))
    parents = genCNN.select_parents(pop, 5, pop_acc.copy())
    child = genCNN.crossover(parents)
    child = genCNN.mutation(child)
    pop = np.concatenate((parents, child), axis=0).astype('int')
    bestModelEachGeneration.append(genCNN.best_arch)

    model = Sequential([
            Conv2D(genCNN.best_arch[0], (genCNN.best_arch[3], genCNN.best_arch[3]), strides=1, padding='same', activation='relu', input_shape=(150, 150, 1)),
            MaxPool2D((2, 2), strides=2, padding='same'),
            Conv2D(genCNN.best_arch[1], (genCNN.best_arch[4], genCNN.best_arch[4]), strides=1, padding='same', activation='relu'),
            Dropout(0.1),
            MaxPool2D((2, 2), strides=2, padding='same'),
            Conv2D(genCNN.best_arch[2], (genCNN.best_arch[5], genCNN.best_arch[5]), strides=1, padding='same', activation='relu'),
            Dropout(0.2),
            MaxPool2D((2, 2), strides=2, padding='same'),
            Flatten(),
            Dense(128, activation='relu'),
            Dropout(0.2),
            Dense(1, activation='sigmoid')
         ])
    model.compile(optimizer="adam", loss='binary_crossentropy', metrics=['accuracy'])
    model.summary()
    learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=2, verbose=1, factor=0.3, min_lr=0.000001)
    model.fit(x, y, batch_size=64, epochs=10, validation_data=(x_val, y_val), callbacks=[learning_rate_reduction])
    predictions = model.predict(x_t)
    predictions = predictions.reshape(1,-1)[0]
    predictions[:15]
    # Predictions are probabilities, convert them to binary labels
    binary_predictions = [1 if i > 0.5 else 0 for i in predictions]
    cm = confusion_matrix(y_t,binary_predictions)
    TP = cm[0][0]  # True Positives
    TN = cm[1][1]  # True Negatives
    FP = cm[0][1]  # False Positives
    FN = cm[1][0]  # False Negatives
    classification_accuracy = (TP + TN) / float(TP + TN + FP + FN)
    classification_error = (FP + FN) / float(TP + TN + FP + FN)
    precision_calc = TP / float(TP + FP)
    recall_calc = TP / float(TP + FN)
    true_positive_rate = TP / float(TP + FN)
    false_positive_rate = FP / float(FP + TN)
    specificity_calc = TN / (TN + FP)
    F1_score = 2 * (precision_calc * recall_calc) / (precision_calc + recall_calc)
    wrong_calc = FN + FP

    True_Positive.append(TP)
    True_Negative.append(TN)
    False_Positive.append(FP)
    False_negative.append(FN)
    acc.append(classification_accuracy)
    error.append(classification_error)
    precision.append(precision_calc)
    recall.append(recall_calc)
    TP_rate.append(true_positive_rate)
    FP_rate.append(false_positive_rate)
    specificity.append(specificity_calc)
    F1.append(F1_score)
    wrong_prediction.append(wrong_calc)

    df = {
    'TP': True_Positive,
    'TN': True_Negative,
    'FP': False_Positive,
    'FN': False_negative,
    'acc': acc,
    'error': error,
    'precision': precision,
    'recall': recall,
    'TP_rate': TP_rate,
    'FP_rate': FP_rate,
    'specificity': specificity,
    'F1_score': F1,
    'wrong_prediction' : wrong_prediction
    }

    df = pd.DataFrame(df)
    df.to_csv('CLAHE_metrics_limit3_21-50.csv', index=False)
# Out:
# [[35 45 94  6  5 14]
#  [35 45 86  5  4 11]
#  [35 45 96  5  5 14]
#  [41 45 91  5  4 17]
#  [38 50 93  6  8 17]
#  [35 45 91  9  5 11]
#  [35 45 98  8  4 14]
#  [35 45 95  5  6 17]
#  [43 45 93  5  5 17]
#  [43 50 94  7  8 14]]
# Epoch 1/10
# 111/111 [==============================] - 18s 73ms/step - loss: 0.3775 - accuracy: 0.8274 - val_loss: 0.1465 - val_accuracy: 0.9436 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 5s 49ms/step - loss: 0.1356 - accuracy: 0.9486 - val_loss: 0.0975 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 5s 49ms/step - loss: 0.1054 - accuracy: 0.9625 - val_loss: 0.1007 - val_accuracy: 0.9761 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 5s 49ms/step - loss: 0.0830 - accuracy: 0.9713 - val_loss: 0.0852 - val_accuracy: 0.9709 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0768 - accuracy: 0.9734
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 5s 49ms/step - loss: 0.0768 - accuracy: 0.9734 - val_loss: 0.0783 - val_accuracy: 0.9692 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 5s 49ms/step - loss: 0.0487 - accuracy: 0.9837 - val_loss: 0.0901 - val_accuracy: 0.9607 - lr: 3.0000e-04
# Epoch 7/10
# 111/111 [==============================] - 5s 49ms/step - loss: 0.0374 - accuracy: 0.9885 - val_loss: 0.0589 - val_accuracy: 0.9795 - lr: 3.0000e-04
# Epoch 8/10
# 111/111 [==============================] - 5s 49ms/step - loss: 0.0320 - accuracy: 0.9897 - val_loss: 0.0765 - val_accuracy: 0.9692 - lr: 3.0000e-04
# Epoch 9/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0266 - accuracy: 0.9902
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 111/111 [==============================] - 5s 49ms/step - loss: 0.0266 - accuracy: 0.9902 - val_loss: 0.0738 - val_accuracy: 0.9744 - lr: 3.0000e-04
# Epoch 10/10
# 111/111 [==============================] - 5s 49ms/step - loss: 0.0200 - accuracy: 0.9931 - val_loss: 0.0628 - val_accuracy: 0.9761 - lr: 9.0000e-05
# Epoch 1/10
# 111/111 [==============================] - 12s 61ms/step - loss: 0.3707 - accuracy: 0.8441 - val_loss: 0.1327 - val_accuracy: 0.9556 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 5s 45ms/step - loss: 0.1231 - accuracy: 0.9540 - val_loss: 0.1121 - val_accuracy: 0.9556 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 5s 45ms/step - loss: 0.0968 - accuracy: 0.9665 - val_loss: 0.1066 - val_accuracy: 0.9590 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 5s 45ms/step - loss: 0.0783 - accuracy: 0.9718 - val_loss: 0.0976 - val_accuracy: 0.9641 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 5s 45ms/step - loss: 0.0666 - accuracy: 0.9771 - val_loss: 0.0708 - val_accuracy: 0.9709 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 5s 45ms/step - loss: 0.0584 - accuracy: 0.9803 - val_loss: 0.0818 - val_accuracy: 0.9692 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0521 - accuracy: 0.9810
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 5s 45ms/step - loss: 0.0521 - accuracy: 0.9810 - val_loss: 0.0873 - val_accuracy: 0.9658 - lr: 0.0010
# Epoch 8/10
# 111/111 [==============================] - 5s 45ms/step - loss: 0.0328 - accuracy: 0.9877 - val_loss: 0.0733 - val_accuracy: 0.9726 - lr: 3.0000e-04
# Epoch 9/10
# 111/111 [==============================] - 5s 45ms/step - loss: 0.0258 - accuracy: 0.9914 - val_loss: 0.0654 - val_accuracy: 0.9744 - lr: 3.0000e-04
# Epoch 10/10
# 111/111 [==============================] - 5s 45ms/step - loss: 0.0210 - accuracy: 0.9934 - val_loss: 0.0485 - val_accuracy: 0.9795 - lr: 3.0000e-04
# Epoch 1/10
# 111/111 [==============================] - 12s 64ms/step - loss: 0.5027 - accuracy: 0.8310 - val_loss: 0.1606 - val_accuracy: 0.9453 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 5s 49ms/step - loss: 0.1287 - accuracy: 0.9523 - val_loss: 0.1313 - val_accuracy: 0.9521 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 5s 49ms/step - loss: 0.0982 - accuracy: 0.9662 - val_loss: 0.0979 - val_accuracy: 0.9607 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 5s 48ms/step - loss: 0.0819 - accuracy: 0.9700 - val_loss: 0.1002 - val_accuracy: 0.9573 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0703 - accuracy: 0.9752
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 5s 49ms/step - loss: 0.0703 - accuracy: 0.9752 - val_loss: 0.1088 - val_accuracy: 0.9590 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 5s 49ms/step - loss: 0.
- val_accuracy: 0.9692 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 7s 59ms/step - loss: 0.0684 - accuracy: 0.9772 - val_loss: 0.1373 - val_accuracy: 0.9470 - lr: 0.0010
# Epoch 6/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0566 - accuracy: 0.9788
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 7s 59ms/step - loss: 0.0565 - accuracy: 0.9788 - val_loss: 0.0804 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 7s 59ms/step - loss: 0.0333 - accuracy: 0.9892 - val_loss: 0.0580 - val_accuracy: 0.9778 - lr: 3.0000e-04
# Epoch 8/10
# 111/111 [==============================] - 7s 59ms/step - loss: 0.0252 - accuracy: 0.9914 - val_loss: 0.0748 - val_accuracy: 0.9744 - lr: 3.0000e-04
# Epoch 9/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0179 - accuracy: 0.9936
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 111/111 [==============================] - 7s 60ms/step - loss: 0.0180 - accuracy: 0.9935 - val_loss: 0.0738 - val_accuracy: 0.9658 - lr: 3.0000e-04
# Epoch 10/10
# 111/111 [==============================] - 7s 60ms/step - loss: 0.0152 - accuracy: 0.9945 - val_loss: 0.0540 - val_accuracy: 0.9778 - lr: 9.0000e-05
# Epoch 1/10
# 111/111 [==============================] - 15s 82ms/step - loss: 0.3842 - accuracy: 0.8192 - val_loss: 0.1713 - val_accuracy: 0.9470 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 7s 60ms/step - loss: 0.1263 - accuracy: 0.9533 - val_loss: 0.1170 - val_accuracy: 0.9504 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 7s 60ms/step - loss: 0.0935 - accuracy: 0.9679 - val_loss: 0.1130 - val_accuracy: 0.9556 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 7s 60ms/step - loss: 0.0801 - accuracy: 0.9717 - val_loss: 0.0736 - val_accuracy: 0.9761 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 7s 60ms/step - loss: 0.0699 - accuracy: 0.9765 - val_loss: 0.1109 - val_accuracy: 0.9556 - lr: 0.0010
# Epoch 6/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0552 - accuracy: 0.9807
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 7s 60ms/step - loss: 0.0556 - accuracy: 0.9806 - val_loss: 0.0779 - val_accuracy: 0.9641 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 7s 60ms/step - loss: 0.0322 - accuracy: 0.9890 - val_loss: 0.0649 - val_accuracy: 0.9778 - lr: 3.0000e-04
# Epoch 8/10
# 111/111 [==============================] - 7s 60ms/step - loss: 0.0262 - accuracy: 0.9918 - val_loss: 0.0699 - val_accuracy: 0.9744 - lr: 3.0000e-04
# Epoch 9/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0214 - accuracy: 0.9943
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 111/111 [==============================] - 7s 60ms/step - loss: 0.0216 - accuracy: 0.9942 - val_loss: 0.0834 - val_accuracy: 0.9641 - lr: 3.0000e-04
# Epoch 10/10
# 111/111 [==============================] - 7s 60ms/step - loss: 0.0158 - accuracy: 0.9960 - val_loss: 0.0655 - val_accuracy: 0.9778 - lr: 9.0000e-05
# Epoch 1/10
# 111/111 [==============================] - 17s 88ms/step - loss: 0.3431 - accuracy: 0.8393 - val_loss: 0.2176 - val_accuracy: 0.9248 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 7s 62ms/step - loss: 0.1402 - accuracy: 0.9486 - val_loss: 0.1143 - val_accuracy: 0.9573 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 7s 62ms/step - loss: 0.1149 - accuracy: 0.9617 - val_loss: 0.1495 - val_accuracy: 0.9607 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 7s 63ms/step - loss: 0.1006 - accuracy: 0.9663 - val_loss: 0.1215 - val_accuracy: 0.9504 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 7s 62ms/step - loss: 0.0921 - accuracy: 0.9690 - val_loss: 0.0669 - val_accuracy: 0.9744 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 7s 62ms/step - loss: 0.0712 - accuracy: 0.9757 - val_loss: 0.0806 - val_accuracy: 0.9692 - lr: 0.0010
# Epoch 7/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0650 - accuracy: 0.9768
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 7s 62ms/step - loss: 0.0662 - accuracy: 0.9764 - val_loss: 0.1066 - val_accuracy: 0.9556 - lr: 0.0010
# Epoch 8/10
# 111/111 [==============================] - 7s 62ms/step - loss: 0.0486 - accuracy: 0.9830 - val_loss: 0.0647 - val_accuracy: 0.9761 - lr: 3.0000e-04
# Epoch 9/10
# 111/111 [==============================] - 7s 63ms/step - loss: 0.0402 - accuracy: 0.9854 - val_loss: 0.0715 - val_accuracy: 0.9761 - lr: 3.0000e-04
# Epoch 10/10
# 111/111 [==============================] - 7s 63ms/step - loss: 0.0378 - accuracy: 0.9863 - val_loss: 0.0588 - val_accuracy: 0.9778 - lr: 3.0000e-04
# Best Accuracy at the generation 0: 99.60390329360962
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_30 (Conv2D)          (None, 150, 150, 43)      1118
#
#  max_pooling2d_30 (MaxPooli  (None, 75, 75, 43)        0
#  ng2D)
#
#  conv2d_31 (Conv2D)          (None, 75, 75, 45)        48420
#
#  dropout_30 (Dropout)        (None, 75, 75, 45)        0
#
#  max_pooling2d_31 (MaxPooli  (None, 38, 38, 45)        0
#  ng2D)
#
#  conv2d_32 (Conv2D)          (None, 38, 38, 93)        1209558
#
#  dropout_31 (Dropout)        (None, 38, 38, 93)        0
#
#  max_pooling2d_32 (MaxPooli  (None, 19, 19, 93)        0
#  ng2D)
#
#  flatten_10 (Flatten)        (None, 33573)             0
#
#  dense_20 (Dense)            (None, 128)               4297472
#
#  dropout_32 (Dropout)        (None, 128)               0
#
#  dense_21 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 5556697 (21.20 MB)
# Trainable params: 5556697 (21.20 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 111/111 [==============================] - 13s 78ms/step - loss: 0.3166 - accuracy: 0.8533 - val_loss: 0.1609 - val_accuracy: 0.9419 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 7s 61ms/step - loss: 0.1304 - accuracy: 0.9502 - val_loss: 0.1730 - val_accuracy: 0.9624 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 7s 61ms/step - loss: 0.1062 - accuracy: 0.9651 - val_loss: 0.1070 - val_accuracy: 0.9624 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 7s 61ms/step - loss: 0.0832 - accuracy: 0.9727 - val_loss: 0.1064 - val_accuracy: 0.9658 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 7s 61ms/step - loss: 0.0736 - accuracy: 0.9758 - val_loss: 0.0989 - val_accuracy: 0.9607 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 7s 61ms/step - loss: 0.0596 - accuracy: 0.9792 - val_loss: 0.0732 - val_accuracy: 0.9744 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 7s 61ms/step - loss: 0.0519 - accuracy: 0.9812 - val_loss: 0.0884 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 8/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0430 - accuracy: 0.9848
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 7s 61ms/step - loss: 0.
- val_accuracy: 0.9538 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 6s 52ms/step - loss: 0.1006 - accuracy: 0.9648 - val_loss: 0.1164 - val_accuracy: 0.9641 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 6s 52ms/step - loss: 0.0823 - accuracy: 0.9724 - val_loss: 0.0945 - val_accuracy: 0.9641 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 6s 52ms/step - loss: 0.0772 - accuracy: 0.9733 - val_loss: 0.0792 - val_accuracy: 0.9709 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 6s 52ms/step - loss: 0.0594 - accuracy: 0.9796 - val_loss: 0.0667 - val_accuracy: 0.9761 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 6s 52ms/step - loss: 0.0535 - accuracy: 0.9799 - val_loss: 0.0689 - val_accuracy: 0.9692 - lr: 0.0010
# Epoch 8/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0502 - accuracy: 0.9820
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 6s 52ms/step - loss: 0.0500 - accuracy: 0.9820 - val_loss: 0.0930 - val_accuracy: 0.9624 - lr: 0.0010
# Epoch 9/10
# 111/111 [==============================] - 6s 52ms/step - loss: 0.0285 - accuracy: 0.9887 - val_loss: 0.0705 - val_accuracy: 0.9692 - lr: 3.0000e-04
# Epoch 10/10
# 111/111 [==============================] - 6s 52ms/step - loss: 0.0208 - accuracy: 0.9931 - val_loss: 0.0417 - val_accuracy: 0.9863 - lr: 3.0000e-04
# Epoch 1/10
# 111/111 [==============================] - 17s 82ms/step - loss: 0.4172 - accuracy: 0.8015 - val_loss: 0.1889 - val_accuracy: 0.9333 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 7s 61ms/step - loss: 0.1400 - accuracy: 0.9479 - val_loss: 0.1153 - val_accuracy: 0.9641 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 7s 61ms/step - loss: 0.1074 - accuracy: 0.9617 - val_loss: 0.1138 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 7s 61ms/step - loss: 0.0835 - accuracy: 0.9707 - val_loss: 0.0936 - val_accuracy: 0.9607 - lr: 0.0010
# Epoch 5/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0786 - accuracy: 0.9724
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 7s 61ms/step - loss: 0.0784 - accuracy: 0.9726 - val_loss: 0.1310 - val_accuracy: 0.9487 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 7s 61ms/step - loss: 0.0515 - accuracy: 0.9825 - val_loss: 0.0945 - val_accuracy: 0.9658 - lr: 3.0000e-04
# Epoch 7/10
# 111/111 [==============================] - 7s 61ms/step - loss: 0.0444 - accuracy: 0.9849 - val_loss: 0.0625 - val_accuracy: 0.9795 - lr: 3.0000e-04
# Epoch 8/10
# 111/111 [==============================] - 7s 61ms/step - loss: 0.0393 - accuracy: 0.9857 - val_loss: 0.0784 - val_accuracy: 0.9726 - lr: 3.0000e-04
# Epoch 9/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0361 - accuracy: 0.9871
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 111/111 [==============================] - 7s 61ms/step - loss: 0.0362 - accuracy: 0.9870 - val_loss: 0.0876 - val_accuracy: 0.9641 - lr: 3.0000e-04
# Epoch 10/10
# 111/111 [==============================] - 7s 61ms/step - loss: 0.0264 - accuracy: 0.9915 - val_loss: 0.0734 - val_accuracy: 0.9744 - lr: 9.0000e-05
# Best Accuracy at the generation 1: 99.60390329360962
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_63 (Conv2D)          (None, 150, 150, 43)      1118
#
#  max_pooling2d_63 (MaxPooli  (None, 75, 75, 43)        0
#  ng2D)
#
#  conv2d_64 (Conv2D)          (None, 75, 75, 45)        48420
#
#  dropout_63 (Dropout)        (None, 75, 75, 45)        0
#
#  max_pooling2d_64 (MaxPooli  (None, 38, 38, 45)        0
#  ng2D)
#
#  conv2d_65 (Conv2D)          (None, 38, 38, 93)        1209558
#
#  dropout_64 (Dropout)        (None, 38, 38, 93)        0
#
#  max_pooling2d_65 (MaxPooli  (None, 19, 19, 93)        0
#  ng2D)
#
#  flatten_21 (Flatten)        (None, 33573)             0
#
#  dense_42 (Dense)            (None, 128)               4297472
#
#  dropout_65 (Dropout)        (None, 128)               0
#
#  dense_43 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 5556697 (21.20 MB)
# Trainable params: 5556697 (21.20 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 111/111 [==============================] - 9s 63ms/step - loss: 0.3423 - accuracy: 0.8448 - val_loss: 0.1577 - val_accuracy: 0.9453 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 7s 61ms/step - loss: 0.1198 - accuracy: 0.9564 - val_loss: 0.1010 - val_accuracy: 0.9607 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 7s 61ms/step - loss: 0.0861 - accuracy: 0.9703 - val_loss: 0.1048 - val_accuracy: 0.9573 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 7s 61ms/step - loss: 0.0747 - accuracy: 0.9738 - val_loss: 0.1058 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 7s 61ms/step - loss: 0.0649 - accuracy: 0.9786 - val_loss: 0.1315 - val_accuracy: 0.9521 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 7s 61ms/step - loss: 0.0558 - accuracy: 0.9812 - val_loss: 0.0972 - val_accuracy: 0.9692 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 7s 61ms/step - loss: 0.0447 - accuracy: 0.9849 - val_loss: 0.0830 - val_accuracy: 0.9761 - lr: 0.0010
# Epoch 8/10
# 111/111 [==============================] - 7s 61ms/step - loss: 0.0489 - accuracy: 0.9816 - val_loss: 0.1006 - val_accuracy: 0.9556 - lr: 0.0010
# Epoch 9/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0350 - accuracy: 0.9869
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 7s 61ms/step - loss: 0.0349 - accuracy: 0.9870 - val_loss: 0.1161 - val_accuracy: 0.9556 - lr: 0.0010
# Epoch 10/10
# 111/111 [==============================] - 7s 61ms/step - loss: 0.0197 - accuracy: 0.9928 - val_loss: 0.0522 - val_accuracy: 0.9829 - lr: 3.0000e-04
# 19/19 [==============================] - 0s 8ms/step
# [[35 45 86  5  4 11]
#  [43 45 93  5  5 17]
#  [38 45 86  5  6 14]
#  [35 46 94  5  6 14]
#  [35 50 93  6  7 17]
#  [35 45 97  5  6 17]
#  [43 45 87  5  5 17]
#  [39 45 94  6  6 14]
#  [35 46 96  7  6 17]
#  [35 54 86  6  8 11]]
# Epoch 1/10
# 111/111 [==============================] - 7s 48ms/step - loss: 0.3444 - accuracy: 0.8421 - val_loss: 0.1755 - val_accuracy: 0.9333 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 5s 45ms/step - loss: 0.1217 - accuracy: 0.9536 - val_loss: 0.0954 - val_accuracy: 0.9590 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 5s 45ms/step - loss: 0.1001 - accuracy: 0.9651 - val_loss: 0.1024 - val_accuracy: 0.9744 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 5s 45ms/step - loss: 0.0793 - accuracy: 0.9721 - val_loss: 0.1115 - val_accuracy: 0.9470 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0741 - accuracy: 0.9740
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 5s 45ms/step - loss: 0.0741 - accuracy: 0.9740 - val_loss: 0.0649 - val_accuracy: 0.9726 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 5s 45ms/step - loss: 0.0457 - accuracy: 0.9851 - val_loss: 0.0993 - val_accuracy: 0.9641 - lr: 3.0000e-04
# Epoch 7/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0372 - accuracy: 0.9874
# Epoch 7: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 111/111 [==============================] - 5s 45ms/step - loss: 0.0372 - accuracy: 0.9874 - val_loss: 0.0679 - val_accuracy: 0.9692 - lr: 3.0000e-04
# Epoch 8/10
# 111/111 [==============================] - 5s 45ms/step - loss: 0.0282 - accuracy: 0.9902 - val_loss: 0.0660 - val_accuracy: 0.9778 - lr: 9.0000e-05
# Epoch 9/10
# 111/111 [==============================] - 5s 45ms/step - loss: 0.0245 - accuracy: 0.9919 - val_loss: 0.0666 - val_accuracy: 0.9778 - lr: 9.0000e-05
# Epoch 10/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0233 - accuracy: 0.9925
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 111/111 [==============================] - 5s 45ms/step - loss: 0.0233 - accuracy: 0.9925 - val_loss: 0.0710 - val_accuracy: 0.9744 - lr: 9.0000e-05
# Epoch 1/10
# 111/111 [==============================] - 8s 62ms/step - loss: 0.5248 - accuracy: 0.8100 - val_loss: 0.1978 - val_accuracy: 0.9316 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 7s 59ms/step - loss: 0.1379 - accuracy: 0.9467 - val_loss: 0.1156 - val_accuracy: 0.9538 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 7s 60ms/step - loss: 0.1012 - accuracy: 0.9649 - val_loss: 0.1255 - val_accuracy: 0.9504 - lr: 0.0010
# Epoch 4/10
# ...
#  ing2D)
#
#  conv2d_361 (Conv2D)         (None, 75, 75, 45)        48420
#
#  dropout_360 (Dropout)       (None, 75, 75, 45)        0
#
#  max_pooling2d_361 (MaxPool  (None, 38, 38, 45)        0
#  ing2D)
#
#  conv2d_362 (Conv2D)         (None, 38, 38, 93)        1209558
#
#  dropout_361 (Dropout)       (None, 38, 38, 93)        0
#
#  max_pooling2d_362 (MaxPool  (None, 19, 19, 93)        0
#  ing2D)
#
#  flatten_120 (Flatten)       (None, 33573)             0
#
#  dense_240 (Dense)           (None, 128)               4297472
#
#  dropout_362 (Dropout)       (None, 128)               0
#
#  dense_241 (Dense)           (None, 1)                 129
#
# =================================================================
# Total params: 5556697 (21.20 MB)
# Trainable params: 5556697 (21.20 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 111/111 [==============================] - 9s 64ms/step - loss: 0.4883 - accuracy: 0.7739 - val_loss: 0.1568 - val_accuracy: 0.9504 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 7s 61ms/step - loss: 0.1425 - accuracy: 0.9458 - val_loss: 0.1156 - val_accuracy: 0.9709 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 7s 62ms/step - loss: 0.0983 - accuracy: 0.9631 - val_loss: 0.1361 - val_accuracy: 0.9402 - lr: 0.0010
# Epoch 4/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0769 - accuracy: 0.9732
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 7s 61ms/step - loss: 0.0768 - accuracy: 0.9731 - val_loss: 0.1067 - val_accuracy: 0.9641 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 7s 61ms/step - loss: 0.0531 - accuracy: 0.9796 - val_loss: 0.0777 - val_accuracy: 0.9726 - lr: 3.0000e-04
# Epoch 6/10
# 111/111 [==============================] - 7s 62ms/step - loss: 0.0408 - accuracy: 0.9856 - val_loss: 0.0764 - val_accuracy: 0.9778 - lr: 3.0000e-04
# Epoch 7/10
# 111/111 [==============================] - 7s 61ms/step - loss: 0.0348 - accuracy: 0.9878 - val_loss: 0.0728 - val_accuracy: 0.9761 - lr: 3.0000e-04
# Epoch 8/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0289 - accuracy: 0.9899
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 111/111 [==============================] - 7s 61ms/step - loss: 0.0288 - accuracy: 0.9900 - val_loss: 0.0884 - val_accuracy: 0.9675 - lr: 3.0000e-04
# Epoch 9/10
# 111/111 [==============================] - 7s 61ms/step - loss: 0.0195 - accuracy: 0.9934 - val_loss: 0.0990 - val_accuracy: 0.9624 - lr: 9.0000e-05
# Epoch 10/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0171 - accuracy: 0.9955
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 111/111 [==============================] - 7s 62ms/step - loss: 0.0171 - accuracy: 0.9955 - val_loss: 0.0778 - val_accuracy: 0.9744 - lr: 9.0000e-05
# 19/19 [==============================] - 0s 7ms/step
# [[50 46 91  6  6 20]
#  [43 45 92  7  5 20]
#  [44 45 91  5  7 20]
#  [45 46 91  6  5 17]
#  [45 45 87  5  5 20]
#  [53 46 92  6  8 20]
#  [45 45 91  8  5 20]
#  [44 45 92  6  7 17]
#  [45 46 88  9  5 20]
#  [45 49 91  5  5 19]]
# Epoch 1/10
# 111/111 [==============================] - 10s 75ms/step - loss: 0.4379 - accuracy: 0.8041 - val_loss: 0.2406 - val_accuracy: 0.9043 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 8s 72ms/step - loss: 0.1690 - accuracy: 0.9361 - val_loss: 0.2640 - val_accuracy: 0.9145 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 8s 72ms/step - loss: 0.1299 - accuracy: 0.9554 - val_loss: 0.1478 - val_accuracy: 0.9573 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 8s 72ms/step - loss: 0.0941 - accuracy: 0.9673 - val_loss: 0.0891 - val_accuracy: 0.9692 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 8s 72ms/step - loss: 0.0876 - accuracy: 0.9686 - val_loss: 0.0994 - val_accuracy: 0.9556 - lr: 0.0010
# Epoch 6/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0784 - accuracy: 0.9734
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 8s 72ms/step - loss: 0.0785 - accuracy: 0.9734 - val_loss: 0.1115 - val_accuracy: 0.9487 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 8s 73ms/step - loss: 0.0567 - accuracy: 0.9808 - val_loss: 0.0796 - val_accuracy: 0.9726 - lr: 3.0000e-04
# Epoch 8/10
# 111/111 [==============================] - 8s 72ms/step - loss: 0.0508 - accuracy: 0.9818 - val_loss: 0.0852 - val_accuracy: 0.9692 - lr: 3.0000e-04
# Epoch 9/10
# 111/111 [==============================] - 8s 73ms/step - loss: 0.0456 - accuracy: 0.9837 - val_loss: 0.0735 - val_accuracy: 0.9744 - lr: 3.0000e-04
# Epoch 10/10
# 111/111 [==============================] - 8s 73ms/step - loss: 0.0431 - accuracy: 0.9847 - val_loss: 0.0597 - val_accuracy: 0.9778 - lr: 3.0000e-04
# Epoch 1/10
# 111/111 [==============================] - 9s 67ms/step - loss: 0.5900 - accuracy: 0.7339 - val_loss: 0.2635 - val_accuracy: 0.8974 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 7s 65ms/step - loss: 0.1728 - accuracy: 0.9311 - val_loss: 0.2255 - val_accuracy: 0.9060 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 7s 65ms/step - loss: 0.1376 - accuracy: 0.9503 - val_loss: 0.1690 - val_accuracy: 0.9487 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 7s 65ms/step - loss: 0.1099 - accuracy: 0.9612 - val_loss: 0.1085 - val_accuracy: 0.9573 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 7s 65ms/step - loss: 0.0938 - accuracy: 0.9665 - val_loss: 0.1432 - val_accuracy: 0.9504 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 7s 65ms/step - loss: 0.0898 - accuracy: 0.9686 - val_loss: 0.0952 - val_accuracy: 0.9744 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 7s 65ms/step - loss: 0.0891 - accuracy: 0.9680 - val_loss: 0.1134 - val_accuracy: 0.9607 - lr: 0.0010
# Epoch 8/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0785 - accuracy: 0.9705
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 7s 65ms/step - loss: 0.0782 - accuracy: 0.9706 - val_loss: 0.1227 - val_accuracy: 0.9538 - lr: 0.0010
# Epoch 9/10
# 111/111 [==============================] - 7s 65ms/step - loss: 0.0579 - accuracy: 0.9802 - val_loss: 0.0816 - val_accuracy: 0.9726 - lr: 3.0000e-04
# Epoch 10/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0504 - accuracy: 0.9824
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 111/111 [==============================] - 7s 65ms/step - loss: 0.0504 - accuracy: 0.9823 - val_loss: 0.0794 - val_accuracy: 0.9709 - lr: 3.0000e-04
# Epoch 1/10
# 111/111 [==============================] - 9s 70ms/step - loss: 0.3981 - accuracy: 0.8213 - val_loss: 0.2027 - val_accuracy: 0.9333 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 8s 68ms/step - loss: 0.1582 - accuracy: 0.9416 - val_loss: 0.1353 - val_accuracy: 0.9607 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 8s 68ms/step - loss: 0.1055 - accuracy: 0.9629 - val_loss: 0.1286 - val_accuracy: 0.9573 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 8s 68ms/step - loss: 0.0934 - accuracy: 0.9672 - val_loss: 0.0907 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 8s 68ms/step - loss: 0.0897 - accuracy: 0.9666 - val_loss: 0.1156 - val_accuracy: 0.9538 - lr: 0.0010
# Epoch 6/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0650 - accuracy: 0.9784
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 8s 68ms/step - loss: 0.0652 - accuracy: 0.9784 - val_loss: 0.1174 - val_accuracy: 0.9521 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 8s 68ms/step - loss: 0.0492 - accuracy: 0.9823 - val_loss: 0.0708 - val_accuracy: 0.9778 - lr: 3.0000e-04
# Epoch 8/10
# 111/111 [==============================] - 8s 68ms/step - loss: 0.0400 - accuracy: 0.9859 - val_loss: 0.0646 - val_accuracy: 0.9812 - lr: 3.0000e-04
# Epoch 9/10
# 111/111 [==============================] - 8s 68ms/step - loss: 0.0365 - accuracy: 0.9881 - val_loss: 0.0744 - val_accuracy: 0.9726 - lr: 3.0000e-04
# Epoch 10/10
# 111/111 [==============================] - 8s 68ms/step - loss: 0.0341 - accuracy: 0.9881 - val_loss: 0.0494 - val_accuracy: 0.9846 - lr: 3.0000e-04
# Epoch 1/10
# 111/111 [==============================] - 9s 64ms/step - loss: 0.3917 - accuracy: 0.8351 - val_loss: 0.1518 - val_accuracy: 0.9470 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 7s 62ms/step - loss: 0.1295 - accuracy: 0.9522 - val_loss: 0.0996 - val_accuracy: 0.9658 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 7s 62ms/step - loss: 0.1059 - accuracy: 0.9635 - val_loss: 0.1245 - val_accuracy: 0.9538 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 7s 62ms/step - loss: 0.0882 - accuracy: 0.9710 - val_loss: 0.0840 - val_accuracy: 0.9692 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 7s 62ms/step - loss: 0.0842 - accuracy: 0.9699 - val_loss: 0.0804 - val_accuracy: 0.9726 - lr: 0.0010
# Epoch 6/10
#  16/111 [===>..........................] - ETA: 5s - loss: 0.0951 - accuracy: 0.9727
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-1b89125f815c> in <cell line: 25>()
#      25 for i in range(num_generations + 1):
#      26     print(pop)
# ---> 27     pop_acc = genCNN.fitness(pop, x, y, epochs)
#      28     print('Best Accuracy at the generation {}: {}'.format(i, genCNN.max_acc))
#      29     parents = genCNN.select_parents(pop, 5, pop_acc.copy())
#
# <ipython-input-21-fa3d34b1078e> in fitness(self, pop, X, Y, epochs)
#     117             model = CNN(nfilters, sfilters)
#     118             learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=2, verbose=1, factor=0.3, min_lr=0.000001)
# --> 119             history = model.fit(X, Y, batch_size=64, epochs=epochs, validation_data=[x_val, y_val], callbacks=[learning_rate_reduction])
#     120             acc = max(history.history['accuracy'])
#     121             pop_acc.append(acc * 100)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1805                         ):
#    1806                             callbacks.on_train_batch_begin(step)
# -> 1807                             tmp_logs = self.train_function(iterator)
#    1808                             if data_handler.should_sync:
#    1809                                 context.async_wait()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     830
#     831       with OptionalXlaContext(self._jit_compile):
# --> 832         result = self._call(*args, **kwds)
#     833
#     834       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     866       # In this case we have created variables on the first call, so we run the
#     867       # defunned version which is guaranteed to never create variables.
# --> 868       return tracing_compilation.call_function(
#     869           args, kwds, self._no_variable_creation_config
#     870       )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1321         and executing_eagerly):
#    1322       # No tape is watching; skip to running the function.
# -> 1323       return self._inference_function.call_preflattened(args)
#    1324     forward_backward = self._select_forward_and_backward_functions(
#    1325         args,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1484     cancellation_context = cancellation.context()
#    1485     if cancellation_context is None:
# -> 1486       outputs = execute.execute(
#    1487           name.decode("utf-8"),
#    1488           num_outputs=num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
genCNN.smooth_curve(0.5,num_generations)

# %%
genCNN.best_arch
# Out:
# array([43, 45, 93,  5,  5, 17])

# %%
genCNN.max_acc
# Out:
# 99.73121881484985

# %%
genCNN.gen_acc
# Out:
# [99.60390329360962,
#  99.56146478652954,
#  99.57560896873474,
#  99.57560896873474,
#  99.6463418006897,
#  99.60390329360962,
#  99.73121881484985,
#  99.4200050830841,
#  99.51902627944946,
#  99.4341492652893,
#  99.6180534362793]

# %%
bestModelEachGeneration
# Out:
# [array([43, 45, 93,  5,  5, 17]),
#  array([43, 45, 93,  5,  5, 17]),
#  array([43, 45, 93,  5,  5, 17]),
#  array([43, 45, 93,  5,  5, 17]),
#  array([35, 45, 86,  5,  4, 11]),
#  array([35, 45, 86,  5,  4, 11]),
#  array([43, 45, 93,  5,  5, 17]),
#  array([43, 45, 93,  5,  5, 17]),
#  array([43, 45, 93,  5,  5, 17]),
#  array([43, 45, 93,  5,  5, 17]),
#  array([43, 45, 93,  5,  5, 17])]

# %%
# Next pop
# array([[38, 47, 79,  4,  5, 13],
#        [37, 47, 77,  4,  4, 11],
#        [32, 52, 79,  4,  4, 12],
#        [32, 47, 78,  4,  4,  6],
#        [40, 51, 77,  5,  9, 11],
#        [40, 47, 77,  4,  5, 13],
#        [37, 47, 81,  7,  4, 12],
#        [32, 52, 83,  4,  4,  7],
#        [32, 47, 79,  7,  4, 11],
#        [40, 51, 82,  5,  9, 14]])

pop
# Out:
# array([[50, 46, 91,  6,  6, 20],
#        [43, 45, 92,  7,  5, 20],
#        [44, 45, 91,  5,  7, 20],
#        [45, 46, 91,  6,  5, 17],
#        [45, 45, 87,  5,  5, 20],
#        [53, 46, 92,  6,  8, 20],
#        [45, 45, 91,  8,  5, 20],
#        [44, 45, 92,  6,  7, 17],
#        [45, 46, 88,  9,  5, 20],
#        [45, 49, 91,  5,  5, 19]])

# %% [markdown]
# ## Optimized Model

# %%
bestParam = genCNN.best_arch
# array([38, 47, 79,  4,  5, 13])
bestParam
# Out:
# array([43, 45, 93,  5,  5, 17])

# %%
model = Sequential()
model.add(Conv2D(bestParam[0] , (bestParam[3],bestParam[3]) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = (150,150,1)))
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model.add(Conv2D(bestParam[1] , (bestParam[4],bestParam[4]) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.1))
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model.add(Conv2D(bestParam[2] , (bestParam[5],bestParam[5]) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.2))
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model.add(Flatten())
model.add(Dense(units = 128 , activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(units = 1 , activation = 'sigmoid'))
model.compile(optimizer = "adam" , loss = 'binary_crossentropy' , metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_375 (Conv2D)         (None, 150, 150, 43)      1118
#
#  max_pooling2d_375 (MaxPool  (None, 75, 75, 43)        0
#  ing2D)
#
#  conv2d_376 (Conv2D)         (None, 75, 75, 45)        48420
#
#  dropout_375 (Dropout)       (None, 75, 75, 45)        0
#
#  max_pooling2d_376 (MaxPool  (None, 38, 38, 45)        0
#  ing2D)
#
#  conv2d_377 (Conv2D)         (None, 38, 38, 93)        1209558
#
#  dropout_376 (Dropout)       (None, 38, 38, 93)        0
#
#  max_pooling2d_377 (MaxPool  (None, 19, 19, 93)        0
#  ing2D)
#
#  flatten_125 (Flatten)       (None, 33573)             0
#
#  dense_250 (Dense)           (None, 128)               4297472
#
#  dropout_377 (Dropout)       (None, 128)               0
#
#  dense_251 (Dense)           (None, 1)                 129
#
# =================================================================
# Total params: 5556697 (21.20 MB)
# Trainable params: 5556697 (21.20 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 2, verbose=1,factor=0.3, min_lr=0.000001)

# %%
history = model.fit(x_train,y_train, batch_size = 64 ,epochs = 10 , validation_data = [x_val, y_val] ,callbacks = [learning_rate_reduction])
# Out:
# Epoch 1/10
# 111/111 [==============================] - 9s 64ms/step - loss: 0.3998 - accuracy: 0.8420 - val_loss: 0.1516 - val_accuracy: 0.9470 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 7s 61ms/step - loss: 0.1266 - accuracy: 0.9528 - val_loss: 0.1144 - val_accuracy: 0.9658 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 7s 62ms/step - loss: 0.0982 - accuracy: 0.9652 - val_loss: 0.0976 - val_accuracy: 0.9761 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 7s 61ms/step - loss: 0.0843 - accuracy: 0.9692 - val_loss: 0.1096 - val_accuracy: 0.9590 - lr: 0.0010
# Epoch 5/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0714 - accuracy: 0.9764
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 7s 61ms/step - loss: 0.0713 - accuracy: 0.9765 - val_loss: 0.0871 - val_accuracy: 0.9709 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 7s 61ms/step - loss: 0.0491 - accuracy: 0.9843 - val_loss: 0.0840 - val_accuracy: 0.9744 - lr: 3.0000e-04
# Epoch 7/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0388 - accuracy: 0.9872
# Epoch 7: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 111/111 [==============================] - 7s 62ms/step - loss: 0.0391 - accuracy: 0.9871 - val_loss: 0.0786 - val_accuracy: 0.9675 - lr: 3.0000e-04
# Epoch 8/10
# 111/111 [==============================] - 7s 61ms/step - loss: 0.0318 - accuracy: 0.9895 - val_loss: 0.0593 - val_accuracy: 0.9812 - lr: 9.0000e-05
# Epoch 9/10
# 111/111 [==============================] - 7s 61ms/step - loss: 0.0287 - accuracy: 0.9905 - val_loss: 0.0684 - val_accuracy: 0.9744 - lr: 9.0000e-05
# Epoch 10/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0269 - accuracy: 0.9913
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 111/111 [==============================] - 7s 61ms/step - loss: 0.0268 - accuracy: 0.9914 - val_loss: 0.0666 - val_accuracy: 0.9726 - lr: 9.0000e-05

# %%
# Adjust the range to match the number of epochs in your history data
epochs = [i for i in range(len(history.history['accuracy']))]

fig, ax = plt.subplots(1, 2, figsize=(20, 10))

train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

ax[0].plot(epochs, train_acc, 'go-', label='Training Accuracy')
ax[0].plot(epochs, val_acc, 'ro-', label='Validation Accuracy')
ax[0].set_title('Training & Validation Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs, train_loss, 'g-o', label='Training Loss')
ax[1].plot(epochs, val_loss, 'r-o', label='Validation Loss')
ax[1].set_title('Training & Validation Loss')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Loss")

plt.show()

# %%
predictions = model.predict(x_test)
predictions = predictions.reshape(1,-1)[0]
predictions[:15]
# Out:
# 19/19 [==============================] - 0s 7ms/step
# array([6.4171609e-03, 1.5647447e-02, 1.1621286e-04, 2.0455916e-03,
#        1.9095804e-03, 1.2904751e-03, 1.3821112e-02, 1.8207213e-02,
#        2.1803014e-04, 1.2816592e-05, 9.2993549e-04, 4.2898575e-04,
#        7.9769891e-04, 1.9078098e-04, 1.0163079e-02], dtype=float32)

# %%
from sklearn.metrics import classification_report

# Assuming predictions are probabilities, convert them to binary labels
binary_predictions = [1 if i > 0.5 else 0 for i in predictions]

# Generate a classification report
print(classification_report(y_test, binary_predictions, target_names=['Pneumonia (Class 0)', 'Normal (Class 1)']))
# Out:
#                      precision    recall  f1-score   support
#
# Pneumonia (Class 0)       0.99      0.98      0.98       428
#    Normal (Class 1)       0.95      0.97      0.96       159
#
#            accuracy                           0.98       587
#           macro avg       0.97      0.98      0.97       587
#        weighted avg       0.98      0.98      0.98       587

# %%
print(classification_report(y_test, binary_predictions, target_names = ['Pneumonia (Class 0)','Normal (Class 1)']))
# Out:
#                      precision    recall  f1-score   support
#
# Pneumonia (Class 0)       0.99      0.98      0.98       428
#    Normal (Class 1)       0.95      0.97      0.96       159
#
#            accuracy                           0.98       587
#           macro avg       0.97      0.98      0.97       587
#        weighted avg       0.98      0.98      0.98       587

# %%
cm = confusion_matrix(y_test,binary_predictions)
cm
# Out:
# array([[419,   9],
#        [  4, 155]])

# %%
cm = pd.DataFrame(cm , index = ['0','1'] , columns = ['0','1'])

# %%
plt.figure(figsize = (10,10))
sns.heatmap(cm,cmap= "Blues", linecolor = 'black' , linewidth = 1 , annot = True, fmt='',xticklabels = labels,yticklabels = labels)
# Out:
# <Axes: >
