result = []

for sublist in model:
    # Convert the sublist to a tuple to be able to use it in a set
    tuple_version = tuple(sublist)
    
    # Only add the sublist to the result if it hasn't been seen
    if tuple_version not in seen:
        result.append(sublist)
        seen.add(tuple_version)

# Print the result

result

# %%
import pandas as pd
# Creating a DataFrame to store the data
data_corrected = {
    'gen': [i + 1 for i in range(len(result))],  # 0-based index for model
    'conv1': [i[0] for i in result],
    'conv2': [i[1] for i in result],
    'conv3': [i[2] for i in result],
    'filter1': [i[3] for i in result],
    'filter2': [i[4] for i in result],
    'filter3': [i[5] for i in result]
}

# Convert the dictionary to DataFrame
df_corrected = pd.DataFrame(data_corrected)
df_corrected

# %%
df_limit3_unique = pd.read_csv('clahe_metrics_limit3_unique.csv')
df_limit3_unique

# %%
merge_dataframe = pd.concat([df_corrected, df_limit3_unique], axis=1)
merge_dataframe

# %%
merge_dataframe.to_csv('limit3_unique_final.csv')

# %% [markdown]
# # CLAHE Unique

# %%
model=[[29,45,75,4,4,5],
        [29,45,75,4,4,5],
        [29,45,75,4,4,5],
        [29,45,75,4,4,5],
        [29,45,75,4,4,5],
        [32,49,75,5,4,5],
        [32,49,75,5,4,5],
        [32,49,75,5,4,5],
        [32,49,75,5,4,5],
        [38,47,79,4,5,13],
        [37,47,77,4,4,11],
        [41,47,82,4,4,16],
        [40,47,79,4,4,13],
        [40,47,79,4,4,13],
        [40,47,79,4,4,13],
        [32,56,80,4,4,18],
        [32,56,80,4,4,18],
        [32,56,80,4,4,18],
        [32,56,80,4,4,18],
        [35,59,80,4,7,17],
        [35,59,80,4,7,17],
        [37,59,80,4,7,15],
        [38,61,83,4,9,18],
        [38,61,83,4,9,18],
        [38,61,83,4,9,18],
        [38,61,83,4,9,18],
        [38,61,97,4,9,18],
        [38,61,97,4,9,18],
        [38,61,97,4,9,18],
        [38,61,98,4,9,16],
        [38,61,98,4,9,16],
        [38,61,98,4,9,16],
        [44,65,83,11,9,20],
        [44,65,83,11,9,20],
        [44,65,83,11,9,20],
        [44,65,83,11,9,20],
        [44,65,83,11,9,20],
        [44,65,83,11,9,20],
        [44,65,83,11,9,20],
        [44,65,83,11,9,20],
        [44,65,83,11,9,20],
        [44,65,83,11,9,20],
        [41,66,97,7,10,19],
        [41,66,97,7,10,19],
        [41,66,97,7,10,19],
        [43,73,100,14,17,19],
        [43,73,100,14,17,19],
        [43,73,100,14,17,19],
        [43,73,100,14,17,19],
        [43,73,100,14,17,19],
        [43,73,100,14,17,19],
        [43,73,100,14,17,19],
        [43,73,100,14,17,19]]

# %%
seen = set()
result = []

for sublist in model:
    # Convert the sublist to a tuple to be able to use it in a set
    tuple_version = tuple(sublist)
    
    # Only add the sublist to the result if it hasn't been seen
    if tuple_version not in seen:
        result.append(sublist)
        seen.add(tuple_version)

# Print the result

result
# Out:
# [[29, 45, 75, 4, 4, 5],
#  [32, 49, 75, 5, 4, 5],
#  [38, 47, 79, 4, 5, 13],
#  [37, 47, 77, 4, 4, 11],
#  [41, 47, 82, 4, 4, 16],
#  [40, 47, 79, 4, 4, 13],
#  [32, 56, 80, 4, 4, 18],
#  [35, 59, 80, 4, 7, 17],
#  [37, 59, 80, 4, 7, 15],
#  [38, 61, 83, 4, 9, 18],
#  [38, 61, 97, 4, 9, 18],
#  [38, 61, 98, 4, 9, 16],
#  [44, 65, 83, 11, 9, 20],
#  [41, 66, 97, 7, 10, 19],
#  [43, 73, 100, 14, 17, 19]]

# %%
import pandas as pd
# Creating a DataFrame to store the data
data_corrected = {
    'gen': [i + 1 for i in range(len(result))],  # 0-based index for model
    'conv1': [i[0] for i in result],
    'conv2': [i[1] for i in result],
    'conv3': [i[2] for i in result],
    'filter1': [i[3] for i in result],
    'filter2': [i[4] for i in result],
    'filter3': [i[5] for i in result]
}

# Convert the dictionary to DataFrame
df_corrected = pd.DataFrame(data_corrected)
df_corrected
# Out:
#     gen  conv1  conv2  conv3  filter1  filter2  filter3
# 0     1     29     45     75        4        4        5
# 1     2     32     49     75        5        4        5
# 2     3     38     47     79        4        5       13
# 3     4     37     47     77        4        4       11
# 4     5     41     47     82        4        4       16
# 5     6     40     47     79        4        4       13
# 6     7     32     56     80        4        4       18
# 7     8     35     59     80        4        7       17
# 8     9     37     59     80        4        7       15
# 9    10     38     61     83        4        9       18
# 10   11     38     61     97        4        9       18
# 11   12     38     61     98        4        9       16
# 12   13     44     65     83       11        9       20
# 13   14     41     66     97        7       10       19
# 14   15     43     73    100       14       17       19

# %%
clahe_unique = pd.read_csv('CLAHE/clahe_metrics_unique_FIXED.csv')
clahe_unique
# Out:
#     Number   TP   TN  FP  FN       acc     error  precision    recall  \
# 0        1  424  151   4   8  0.979557  0.020443   0.990654  0.981481
# 1        2  419  155   9   4  0.977853  0.022147   0.978972  0.990544
# 2        3  419  153   9   6  0.974446  0.025554   0.978972  0.985882
# 3        4  423  151   5   8  0.977853  0.022147   0.988318  0.981439
# 4        5  420  154   8   5  0.977853  0.022147   0.981308  0.988235
# 5        6  419  154   9   5  0.976150  0.023850   0.978972  0.988208
# 6        7  420  153   8   6  0.976150  0.023850   0.981308  0.985915
# 7        8  419  153   9   6  0.974446  0.025554   0.978972  0.985882
# 8        9  418  156  10   3  0.977853  0.022147   0.976636  0.992874
# 9       10  421  154   7   5  0.979557  0.020443   0.983645  0.988263
# 10      11  421  156   7   3  0.982964  0.017036   0.983645  0.992925
# 11      12  418  155  10   4  0.976150  0.023850   0.976636  0.990521
# ...

# %%
merge_dataframe = pd.concat([df_corrected, clahe_unique], axis=1)
merge_dataframe
# Out:
#     gen  conv1  conv2  conv3  filter1  filter2  filter3  Number   TP   TN  \
# 0     1     29     45     75        4        4        5       1  424  151
# 1     2     32     49     75        5        4        5       2  419  155
# 2     3     38     47     79        4        5       13       3  419  153
# 3     4     37     47     77        4        4       11       4  423  151
# 4     5     41     47     82        4        4       16       5  420  154
# 5     6     40     47     79        4        4       13       6  419  154
# 6     7     32     56     80        4        4       18       7  420  153
# 7     8     35     59     80        4        7       17       8  419  153
# 8     9     37     59     80        4        7       15       9  418  156
# 9    10     38     61     83        4        9       18      10  421  154
# 10   11     38     61     97        4        9       18      11  421  156
# 11   12     38     61     98        4        9       16      12  418  155
# ...

# %%
merge_dataframe.to_csv('clahe_unique_final_withmodel.csv')

# %% [markdown]
# # Normal Unique

# %%
model=[[14,46,62,2,5,7],
[29,45,88,4,4,5],
[29,45,70,4,4,13],
[29,45,70,4,4,13],
[15,48,88,3,5,5],
[15,48,88,3,5,5],
[15,48,88,3,5,5],
[15,48,88,3,5,5],
[15,48,88,3,5,5],
[15,48,88,3,5,5],
[15,48,88,3,5,5],
[33,47,73,4,8,20],
[33,47,73,4,8,20],
[35,36,75,4,6,19],
[35,36,75,4,6,19],
[35,36,75,4,6,19],
[35,36,75,4,6,19],
[35,36,75,4,6,19],
[35,36,75,4,6,19],
[35,36,75,4,6,19],
[35,36,75,4,6,19],
[35,36,75,4,6,19],
[40,44,84,5,13,20],
[44,36,84,4,8,18],
[44,36,84,4,8,18],
[44,36,84,4,8,18],
[44,36,84,4,8,18],
[44,36,84,4,8,18],
[44,36,84,4,8,18],
[45,37,85,4,10,20],
[45,37,85,4,10,20],
[45,37,85,4,10,20],
[45,37,85,4,10,20],
[45,37,85,4,10,20],
[45,37,85,4,10,20],
[45,37,85,4,10,20],
[45,37,85,4,10,20],
[45,37,85,4,10,20],
[45,37,85,4,10,20],
[45,37,85,4,10,20],
[45,37,85,4,10,20],
[45,37,85,4,10,20],
[54,44,87,8,14,20],
[54,41,92,6,16,20],
[60,46,87,4,15,20],
[58,41,97,6,14,20],
[58,41,97,6,14,20],
[58,41,97,6,14,20],
[60,47,92,5,14,16],
[60,47,92,5,14,16]]


accuracy=[98.85415434837341,
98.93903136253357,
99.36341643333435,
99.4482934474945,
99.58975911140442,
99.33512806892395,
99.00975823402405,
99.36341643333435,
99.20780658721924,
99.40585494041443,
99.53317046165466,
99.22195672988892,
99.22195672988892,
99.4200050830841,
99.25024509429932,
99.20780658721924,
99.49073195457458,
99.17951822280884,
98.96731972694397,
99.13707971572876,
99.10878539085388,
99.15122389793396,
99.17951822280884,
99.46244359016418,
99.17951822280884,
99.37756657600403,
99.4200050830841,
99.25024509429932,
99.25024509429932,
99.54732060432434,
99.0663468837738,
99.0663468837738,
99.46244359016418,
98.86829853057861,
99.53317046165466,
98.93903136253357,
99.25024509429932,
99.080491065979,
99.46244359016418,
99.15122389793396,
99.20780658721924,
99.19366240501404,
98.75512719154358,
99.10878539085388,
99.34927225112915,
99.36341643333435,
99.19366240501404,
99.33512806892395,
99.40585494041443,
99.34927225112915]

# %%
seen = set()
result = []

for sublist in model:
    # Convert the sublist to a tuple to be able to use it in a set
    tuple_version = tuple(sublist)
    
    # Only add the sublist to the result if it hasn't been seen
    if tuple_version not in seen:
        result.append(sublist)
        seen.add(tuple_version)

# Print the result

result

# %%
import pandas as pd
# Creating a DataFrame to store the data
data_corrected = {
    'gen': [i + 1 for i in range(len(result))],  # 0-based index for model
    'conv1': [i[0] for i in result],
    'conv2': [i[1] for i in result],
    'conv3': [i[2] for i in result],
    'filter1': [i[3] for i in result],
    'filter2': [i[4] for i in result],
    'filter3': [i[5] for i in result]
}

# Convert the dictionary to DataFrame
df_corrected = pd.DataFrame(data_corrected)
df_corrected

# %%
normal_unique = pd.read_csv('model_metrics_unique.csv')
normal_unique

# %%
merge_dataframe = pd.concat([df_corrected, normal_unique], axis=1)
merge_dataframe

# %%
merge_dataframe.to_csv('normal_unique_final.csv')
