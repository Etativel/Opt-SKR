# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import os

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau

# %%
print(tf.config.list_physical_devices())
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
print(tf.__version__)
# Out:
# 2.10.0

# %%
labels = ['PNEUMONIA', 'NORMAL']
img_size = 150
def get_training_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data,dtype="object")

# %%
train = get_training_data('../data/train_CLAHE')      
test = get_training_data('../data/test_CLAHE')
val = get_training_data('../data/val_CLAHE')

# %%
import seaborn as sns

# %%
print(sns.__version__)
# Out:
# 0.11.1

# %%
l = []
for i in train:
    if(i[1] == 0):
        l.append("Pneumonia")
    else:
        l.append("Normal")
sns.set_style('darkgrid')
sns.countplot(l)
# Out:
# g:\Anaconda\envs\tensorflowgpu\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# g:\Anaconda\envs\tensorflowgpu\lib\site-packages\seaborn\_core.py:1478: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
# <Axes: ylabel='count'>

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[0][0], cmap='gray')
plt.title(labels[train[0][1]])

plt.figure(figsize = (5,5))
plt.imshow(train[-1][0], cmap='gray')
plt.title(labels[train[-1][1]])
# Out:
# Text(0.5, 1.0, 'NORMAL')

# %%
x_train = []
y_train = []

x_val = []
y_val = []

x_test = []
y_test = []

for feature, label in train:
    x_train.append(feature)
    y_train.append(label)

for feature, label in test:
    x_test.append(feature)
    y_test.append(label)
    
for feature, label in val:
    x_val.append(feature)
    y_val.append(label)

# %%
# Normalize the data
x_train = np.array(x_train) / 255
x_val = np.array(x_val) / 255
x_test = np.array(x_test) / 255

# %%
# resize data for deep learning 
x_train = x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)

x_val = x_val.reshape(-1, img_size, img_size, 1)
y_val = np.array(y_val)

x_test = x_test.reshape(-1, img_size, img_size, 1)
y_test = np.array(y_test)

# %%
print("Count before augmentation:", len(x_train))
# Out:
# Count before augmentation: 4684

# %%
def load_augmented_data(augmented_dir, label, img_size):
    augmented_data = []
    for img in os.listdir(augmented_dir):
        try:
            img_arr = cv2.imread(os.path.join(augmented_dir, img), cv2.IMREAD_GRAYSCALE)
            resized_arr = cv2.resize(img_arr, (img_size, img_size))
            augmented_data.append([resized_arr, label])
        except Exception as e:
            print(e)
    return np.array(augmented_data)

# Define parameters
data_dir = '../data/train_CLAHE'  # Adjust this path to your dataset
save_dir = '../data/augmented_CLAHE/NORMAL'  # Directory to save augmented images
label = 'NORMAL'  # Class label to augment
img_size = 150  # Image size (adjust if different)
additional_images_needed = 2690  # Number of additional images needed
batch_size = 32  # Number of images to generate per original image

# Load augmented 'Normal' images (assuming label for 'Normal' is 1)
augmented_normal_data = load_augmented_data(save_dir, label=1, img_size=img_size)

# Convert to appropriate format and normalize
x_augmented_normal = np.array([i[0] for i in augmented_normal_data]) / 255
x_augmented_normal = x_augmented_normal.reshape(-1, img_size, img_size, 1)
y_augmented_normal = np.array([i[1] for i in augmented_normal_data])

# Append to existing training data
x_train = np.concatenate((x_train, x_augmented_normal), axis=0)
y_train = np.concatenate((y_train, y_augmented_normal), axis=0)

# Shuffle the dataset
indices = np.arange(x_train.shape[0])
np.random.shuffle(indices)
x_train = x_train[indices]
y_train = y_train[indices]

# Count after augmentation
print("Count after augmentation:", len(x_train))
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_19840\680744385.py:10: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(augmented_data)
# Count after augmentation: 7069

# %%
# model = Sequential()
# model.add(Conv2D(32 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = (150,150,1)))
# model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

# model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
# model.add(Dropout(0.1))
# model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

# model.add(Conv2D(100 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
# model.add(Dropout(0.2))
# model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

# model.add(Flatten())
# model.add(Dense(units = 128 , activation = 'relu'))
# model.add(Dropout(0.2))
# model.add(Dense(units = 1 , activation = 'sigmoid'))
# model.compile(optimizer = "adam" , loss = 'binary_crossentropy' , metrics = ['accuracy'])
# model.summary()


# model = Sequential()
# model.add(Conv2D(24 , (1,1) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = (150,150,1)))
# model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

# model.add(Conv2D(40 , (4,4) , strides = 1 , padding = 'same' , activation = 'relu'))
# model.add(Dropout(0.1))
# model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

# model.add(Conv2D(91 , (9,9) , strides = 1 , padding = 'same' , activation = 'relu'))
# model.add(Dropout(0.2))
# model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

# model.add(Flatten())
# model.add(Dense(units = 128 , activation = 'relu'))
# model.add(Dropout(0.2))
# model.add(Dense(units = 1 , activation = 'sigmoid'))
# model.compile(optimizer = "adam" , loss = 'binary_crossentropy' , metrics = ['accuracy'])
# model.summary()

# 15, 67, 98,  4,  6, 10 Best 5 Generation

# model = Sequential()
# model.add(Conv2D(15 , (4,4) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = (150,150,1)))
# model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

# model.add(Conv2D(67 , (6,6) , strides = 1 , padding = 'same' , activation = 'relu'))
# model.add(Dropout(0.1))
# model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

# model.add(Conv2D(98 , (10,10) , strides = 1 , padding = 'same' , activation = 'relu'))
# model.add(Dropout(0.2))
# model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

# model.add(Flatten())
# model.add(Dense(units = 128 , activation = 'relu'))
# model.add(Dropout(0.2))
# model.add(Dense(units = 1 , activation = 'sigmoid'))
# model.compile(optimizer = "adam" , loss = 'binary_crossentropy' , metrics = ['accuracy'])
# model.summary()

# %%
# learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 2, verbose=1,factor=0.3, min_lr=0.000001)

# %%
# history = model.fit(x_train,y_train, batch_size = 64 ,epochs = 10 , validation_data = [x_val, y_val] ,callbacks = [learning_rate_reduction])

# %%
# # Adjust the range to match the number of epochs in your history data
# epochs = [i for i in range(len(history.history['accuracy']))]

# fig, ax = plt.subplots(1, 2, figsize=(20, 10))

# train_acc = history.history['accuracy']
# train_loss = history.history['loss']
# val_acc = history.history['val_accuracy']
# val_loss = history.history['val_loss']

# ax[0].plot(epochs, train_acc, 'go-', label='Training Accuracy')
# ax[0].plot(epochs, val_acc, 'ro-', label='Validation Accuracy')
# ax[0].set_title('Training & Validation Accuracy')
# ax[0].legend()
# ax[0].set_xlabel("Epochs")
# ax[0].set_ylabel("Accuracy")

# ax[1].plot(epochs, train_loss, 'g-o', label='Training Loss')
# ax[1].plot(epochs, val_loss, 'r-o', label='Validation Loss')
# ax[1].set_title('Training & Validation Loss')
# ax[1].legend()
# ax[1].set_xlabel("Epochs")
# ax[1].set_ylabel("Loss")

# plt.show()

# %%
# predictions = model.predict(x_test)
# predictions = predictions.reshape(1,-1)[0]
# predictions[:15]

# %%
# from sklearn.metrics import classification_report

# # Assuming predictions are probabilities, convert them to binary labels
# binary_predictions = [1 if i > 0.5 else 0 for i in predictions]

# # Generate a classification report
# print(classification_report(y_test, binary_predictions, target_names=['Pneumonia (Class 0)', 'Normal (Class 1)']))

# %%
# array([[418,  10],
#        [  5, 154]], dtype=int64)

# %%
# cm = confusion_matrix(y_test,binary_predictions)
# cm

# %%
# cm = pd.DataFrame(cm , index = ['0','1'] , columns = ['0','1'])

# %%
# plt.figure(figsize = (10,10))
# sns.heatmap(cm,cmap= "Blues", linecolor = 'black' , linewidth = 1 , annot = True, fmt='',xticklabels = labels,yticklabels = labels)

# %% [markdown]
# # Optimization

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

class CNN(Sequential):
    def __init__(self, nfilters, sfilters):
        super().__init__()
        tf.random.set_seed(0)
        self.add(Conv2D(nfilters[0], kernel_size=(sfilters[0], sfilters[0]), padding='same', activation='relu', input_shape=(150, 150, 1)))
        self.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

        self.add(Conv2D(nfilters[1], kernel_size=(sfilters[1], sfilters[1]), padding='same', activation='relu'))
        self.add(Dropout(0.1))
        self.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

        self.add(Conv2D(nfilters[2], kernel_size=(sfilters[2], sfilters[2]), padding='same', activation='relu'))
        self.add(Dropout(0.2))
        self.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

        self.add(Flatten())
        self.add(Dropout(0.2))
        self.add(Dense(128, activation='relu'))
        self.add(Dense(units=1, activation='sigmoid'))
        self.compile(optimizer="adam", loss='binary_crossentropy', metrics=['accuracy'])

# %%
class Genetic:
    def __init__(self, pop_size, nlayers, max_nfilters, max_sfilters):
        self.pop_size = pop_size
        self.nlayers = nlayers
        self.max_nfilters = max_nfilters
        self.max_sfilters = max_sfilters
        self.max_acc = 0
        self.best_arch = np.zeros((1, 6))
        self.gen_acc = []
        

    # def generate_population(self):
    #     np.random.seed(0)

    #     # Membuat partisi untuk nfilter
    #     partition_size_nfilter = self.max_nfilters // self.pop_size
    #     pop_nlayers = np.array([
    #         np.random.randint(1 + i * partition_size_nfilter, (i + 1) * partition_size_nfilter, self.nlayers)
    #         for i in range(self.pop_size)
    #     ])

    #     # Membuat partisi untuk sfilter
    #     partition_size_sfilter = self.max_sfilters // self.pop_size
    #     pop_sfilters = np.array([
    #         np.random.randint(1 + i * partition_size_sfilter, (i + 1) * partition_size_sfilter, self.nlayers)
    #         for i in range(self.pop_size)
    #     ])

    #     # Menggabungkan kedua set parameter
    #     pop_total = np.concatenate((pop_nlayers, pop_sfilters), axis=1)
    #     return pop_total

    def generate_unique_values(self, max_value, taken_values):
        partition_size = max_value // self.nlayers
        unique_values = []
        for j in range(self.nlayers):
            start = j * partition_size + 1
            if j == self.nlayers - 1:  # Ensure the last partition reaches the max value
                end = max_value + 1
            else:
                end = start + partition_size
            
            # Generate a unique value within the partition
            value = np.random.randint(start, end)
            while value in taken_values:  # Ensure uniqueness
                value += 1
                if value >= end:  # Reset if exceeds partition
                    value = start
            
            taken_values.add(value)
            unique_values.append(value)
        
        return unique_values

    def generate_population(self):
        np.random.seed(0)

        # Initialize population array
        pop_total = np.zeros((self.pop_size, self.nlayers * 2), dtype=int)
        
        for i in range(self.pop_size):
            taken_values_nfilters = set()
            taken_values_sfilters = set()

            # Generate unique nfilters and sfilters for each individual
            nfilters = self.generate_unique_values(self.max_nfilters, taken_values_nfilters)
            sfilters = self.generate_unique_values(self.max_sfilters, taken_values_sfilters)
            
            # Combine nfilters and sfilters for the individual
            pop_total[i] = nfilters + sfilters

        return pop_total

    
    def select_parents(self, pop, nparents, fitness):
        parents = np.zeros((nparents, pop.shape[1]))
        for i in range(nparents):
            best = np.argmax(fitness)
            parents[i] = pop[best]
            fitness[best] = -99999
        return parents

    def crossover(self, parents):
        nchild = self.pop_size - parents.shape[0]
        nparents = parents.shape[0]
        child = np.zeros((nchild, parents.shape[1]))
        for i in range(nchild):
            first = i % nparents
            second = (i + 1) % nparents
            child[i, :2] = parents[first][:2]
            child[i, 2] = parents[second][2]
            child[i, 3:5] = parents[first][3:5]
            child[i, 5] = parents[second][5]
        return child

    def mutation(self, child):
        for i in range(child.shape[0]):
            val = np.random.randint(1, 6)
            ind = np.random.randint(1, 4) - 1
            if child[i][ind] + val > 100:
                child[i][ind] -= val
            else:
                child[i][ind] += val
            val = np.random.randint(1, 4)
            ind = np.random.randint(4, 7) - 1
            if child[i][ind] + val > 20:
                child[i][ind] -= val
            else:
                child[i][ind] += val
        return child

    def fitness(self, pop, X, Y, epochs):
        pop_acc = []
        for i in range(pop.shape[0]):
            nfilters = pop[i][0:3]
            sfilters = pop[i][3:]
            model = CNN(nfilters, sfilters)
            learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=2, verbose=1, factor=0.3, min_lr=0.000001)
            history = model.fit(X, Y, batch_size=32, epochs=epochs, validation_data=[x_val, y_val], callbacks=[learning_rate_reduction])
            acc = max(history.history['accuracy'])
            pop_acc.append(acc * 100)
        if max(pop_acc) > self.max_acc:
            self.max_acc = max(pop_acc)
            self.best_arch = pop[np.argmax(pop_acc)]
        self.gen_acc.append(max(pop_acc))
        return pop_acc

    def smooth_curve(self, factor, gen):
        smoothed_points = []
        for point in self.gen_acc:
            if smoothed_points:
                prev = smoothed_points[-1]
                smoothed_points.append(prev * factor + point * (1 - factor))
            else:
                smoothed_points.append(point)
        plt.plot(range(gen + 1), smoothed_points, 'g', label='Smoothed training acc')
        plt.xticks(np.arange(gen + 1))
        plt.legend()
        plt.title('Fitness Accuracy vs Generations')
        plt.xlabel('Generations')
        plt.ylabel('Fitness (%)')
        plt.show()

# %% [markdown]
# ## Generate 1st Population

# %%
# import random
# import numpy as np

# def generate_unique_random_values(num_values, start, end):
#     random_values = []
#     while len(random_values) < num_values:
#         random_value = random.randint(start, end)
#         if random_value not in random_values:
#             random_values.append(random_value)
#     return random_values

# # Example usage:
# list1 = generate_unique_random_values(10, 10, 30)
# list2 = generate_unique_random_values(10, 30, 60)
# list3 = generate_unique_random_values(10, 60, 90)
# list4 = generate_unique_random_values(10, 1, 10)
# list5 = generate_unique_random_values(10, 1, 10)
# list6 = generate_unique_random_values(10, 1, 10)

# result_pop = [[list1[i], list2[i], list3[i], list4[i], list5[i], list6[i]] for i in range(10)]
# print(np.array(result_pop))

# %%
pop_size = 10
nlayers = 3
max_nfilters = 100
max_sfilters = 10
epochs = 10
num_generations = 10

genCNN = Genetic(pop_size, nlayers, max_nfilters, max_sfilters)
# pop = genCNN.generate_population()
pop = np.array([[39, 61, 95,  4, 15, 20],
                [39, 59, 99,  4, 12, 17],
                [52, 64, 99,  5, 17, 17],
                [36, 59, 93,  4,  9, 19],
                [53, 62, 93,  4, 17, 19],
                [39, 66, 99,  4, 15, 19],
                [44, 59, 99,  4, 15, 17],
                [56, 64, 93,  5, 18, 19],
                [36, 59, 97,  6,  9, 19],
                [53, 62, 96,  4, 18, 20]])


# pop = np.array(result_pop)

pop
# Out:
# array([[39, 61, 95,  4, 15, 20],
#        [39, 59, 99,  4, 12, 17],
#        [52, 64, 99,  5, 17, 17],
#        [36, 59, 93,  4,  9, 19],
#        [53, 62, 93,  4, 17, 19],
#        [39, 66, 99,  4, 15, 19],
#        [44, 59, 99,  4, 15, 17],
#        [56, 64, 93,  5, 18, 19],
#        [36, 59, 97,  6,  9, 19],
#        [53, 62, 96,  4, 18, 20]])

# %%
with tf.device('/cpu:0'):
   x = tf.convert_to_tensor(x_train, np.float32)
   y = tf.convert_to_tensor(y_train, np.float32)

bestModelEachGeneration = []

for i in range(num_generations + 1):
    print(pop)
    pop_acc = genCNN.fitness(pop, x, y, epochs)
    print('Best Accuracy at the generation {}: {}'.format(i, genCNN.max_acc))
    parents = genCNN.select_parents(pop, 5, pop_acc.copy())
    child = genCNN.crossover(parents)
    child = genCNN.mutation(child)
    pop = np.concatenate((parents, child), axis=0).astype('int')
    bestModelEachGeneration.append(genCNN.best_arch)
# Out:
# [[39 61 95  4 15 20]
#  [39 59 99  4 12 17]
#  [52 64 99  5 17 17]
#  [36 59 93  4  9 19]
#  [53 62 93  4 17 19]
#  [39 66 99  4 15 19]
#  [44 59 99  4 15 17]
#  [56 64 93  5 18 19]
#  [36 59 97  6  9 19]
#  [53 62 96  4 18 20]]
# Epoch 1/10
# 221/221 [==============================] - 34s 115ms/step - loss: 0.6355 - accuracy: 0.6496 - val_loss: 0.2385 - val_accuracy: 0.9060 - lr: 0.0010
# Epoch 2/10
# 221/221 [==============================] - 19s 87ms/step - loss: 0.1752 - accuracy: 0.9342 - val_loss: 0.1130 - val_accuracy: 0.9641 - lr: 0.0010
# Epoch 3/10
# 221/221 [==============================] - 19s 87ms/step - loss: 0.1261 - accuracy: 0.9570 - val_loss: 0.0866 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 4/10
# 221/221 [==============================] - 19s 87ms/step - loss: 0.0955 - accuracy: 0.9676 - val_loss: 0.0662 - val_accuracy: 0.9932 - lr: 0.0010
# Epoch 5/10
# 221/221 [==============================] - 19s 87ms/step - loss: 0.0734 - accuracy: 0.9728 - val_loss: 0.0647 - val_accuracy: 0.9863 - lr: 0.0010
# Epoch 6/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0752 - accuracy: 0.9744
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 221/221 [==============================] - 19s 87ms/step - loss: 0.0752 - accuracy: 0.9744 - val_loss: 0.0744 - val_accuracy: 0.9726 - lr: 0.0010
# Epoch 7/10
# 221/221 [==============================] - 19s 87ms/step - loss: 0.0461 - accuracy: 0.9823 - val_loss: 0.0673 - val_accuracy: 0.9778 - lr: 3.0000e-04
# Epoch 8/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0401 - accuracy: 0.9847
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 221/221 [==============================] - 19s 87ms/step - loss: 0.0401 - accuracy: 0.9847 - val_loss: 0.0715 - val_accuracy: 0.9778 - lr: 3.0000e-04
# Epoch 9/10
# 221/221 [==============================] - 19s 87ms/step - loss: 0.0280 - accuracy: 0.9890 - val_loss: 0.0607 - val_accuracy: 0.9744 - lr: 9.0000e-05
# Epoch 10/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0268 - accuracy: 0.9900
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 221/221 [==============================] - 19s 87ms/step - loss: 0.0268 - accuracy: 0.9900 - val_loss: 0.0617 - val_accuracy: 0.9829 - lr: 9.0000e-05
# Epoch 1/10
# 221/221 [==============================] - 25s 96ms/step - loss: 0.4375 - accuracy: 0.8335 - val_loss: 0.2307 - val_accuracy: 0.9043 - lr: 0.0010
# Epoch 2/10
# 221/221 [==============================] - 17s 79ms/step - loss: 0.1646 - accuracy: 0.9436 - val_loss: 0.1403 - val_accuracy: 0.9521 - lr: 0.0010
# Epoch 3/10
# 221/221 [==============================] - 17s 79ms/step - loss: 0.1281 - accuracy: 0.9520 - val_loss: 0.1635 - val_accuracy: 0.9470 - lr: 0.0010
# Epoch 4/10
# 221/221 [==============================] - 17s 79ms/step - loss: 0.1076 - accuracy: 0.9638 - val_loss: 0.1158 - val_accuracy: 0.9624 - lr: 0.0010
# Epoch 5/10
# 221/221 [==============================] - 17s 79ms/step - loss: 0.0929 - accuracy: 0.9677 - val_loss: 0.1031 - val_accuracy: 0.9778 - lr: 0.0010
# Epoch 6/10
# 221/221 [==============================] - 17s 79ms/step - loss: 0.1002 - accuracy: 0.9635 - val_loss: 0.1039 - val_accuracy: 0.9538 - lr: 0.0010
# Epoch 7/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0870 - accuracy: 0.9704
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 221/221 [==============================] - 17s 79ms/step - loss: 0.0870 - accuracy: 0.9704 - val_loss: 0.1026 - val_accuracy: 0.9658 - lr: 0.0010
# Epoch 8/10
# 221/221 [==============================] - 17s 79ms/step - loss: 0.0609 - accuracy: 0.9779 - val_loss: 0.0943 - val_accuracy: 0.9641 - lr: 3.0000e-04
# Epoch 9/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0521 - accuracy: 0.9808
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 221/221 [==============================] - 17s 79ms/step - loss: 0.0521 - accuracy: 0.9808 - val_loss: 0.0887 - val_accuracy: 0.9641 - lr: 3.0000e-04
# Epoch 10/10
# 221/221 [==============================] - 17s 79ms/step - loss: 0.0435 - accuracy: 0.9840 - val_loss: 0.0830 - val_accuracy: 0.9692 - lr: 9.0000e-05
# Epoch 1/10
# 221/221 [==============================] - 38s 134ms/step - loss: 0.8099 - accuracy: 0.5685 - val_loss: 0.4759 - val_accuracy: 0.7573 - lr: 0.0010
# Epoch 2/10
# 221/221 [==============================] - 21s 96ms/step - loss: 0.2277 - accuracy: 0.9093 - val_loss: 0.1280 - val_accuracy: 0.9590 - lr: 0.0010
# Epoch 3/10
# 221/221 [==============================] - 21s 97ms/step - loss: 0.1322 - accuracy: 0.9536 - val_loss: 0.0709 - val_accuracy: 0.9812 - lr: 0.0010
# Epoch 4/10
# 221/221 [==============================] - 21s 97ms/step - loss: 0.1028 - accuracy: 0.9652 - val_loss: 0.0892 - val_accuracy: 0.9761 - lr: 0.0010
# Epoch 5/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0940 - accuracy: 0.9644
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 221/221 [==============================] - 21s 96ms/step - loss: 0.0940 - accuracy: 0.9644 - val_loss: 0.0789 - val_accuracy: 0.9744 - lr: 0.0010
# Epoch 6/10
# 221/221 [==============================] - 21s 97ms/step - loss: 0.0650 - accuracy: 0.9779 - val_loss: 0.0648 - val_accuracy: 0.9829 - lr: 3.0000e-04
# Epoch 7/10
# 221/221 [==============================] - 21s 97ms/step - loss: 0.0567 - accuracy: 0.9801 - val_loss: 0.0753 - val_accuracy: 0.9726 - lr: 3.0000e-04
# Epoch 8/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0523 - accuracy: 0.9827
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 221/221 [==============================] - 21s 97ms/step - loss: 0.0523 - accuracy: 0.9827 - val_loss: 0.0780 - val_accuracy: 0.9675 - lr: 3.0000e-04
# Epoch 9/10
# 221/221 [==============================] - 21s 97ms/step - loss: 0.0423 - accuracy: 0.9868 - val_loss: 0.0701 - val_accuracy: 0.9778 - lr: 9.0000e-05
# Epoch 10/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0393 - accuracy: 0.9874
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 221/221 [==============================] - 21s 97ms/step - loss: 0.0393 - accuracy: 0.9874 - val_loss: 0.0744 - val_accuracy: 0.9744 - lr: 9.0000e-05
# Epoch 1/10
# 221/221 [==============================] - 25s 94ms/step - loss: 0.4057 - accuracy: 0.8049 - val_loss: 0.1432 - val_accuracy: 0.9590 - lr: 0.0010
# Epoch 2/10
# 221/221 [==============================] - 17s 76ms/step - loss: 0.1168 - accuracy: 0.9577 - val_loss: 0.0911 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 3/10
# 221/221 [==============================] - 17s 76ms/step - loss: 0.0856 - accuracy: 0.9687 - val_loss: 0.0753 - val_accuracy: 0.9658 - lr: 0.0010
# Epoch 4/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0712 - accuracy: 0.9747
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 221/221 [==============================] - 17s 76ms/step - loss: 0.0712 - accuracy: 0.9747 - val_loss: 0.0872 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 5/10
# 221/221 [==============================] - 17s 76ms/step - loss: 0.0379 - accuracy: 0.9876 - val_loss: 0.0472 - val_accuracy: 0.9829 - lr: 3.0000e-04
# Epoch 6/10
# 221/221 [==============================] - 17s 76ms/step - loss: 0.0290 - accuracy: 0.9904 - val_loss: 0.0618 - val_accuracy: 0.9795 - lr: 3.0000e-04
# Epoch 7/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0214 - accuracy: 0.9936
# Epoch 7: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 221/221 [==============================] - 17s 76ms/step - loss: 0.0214 - accuracy: 0.9936 - val_loss: 0.0907 - val_accuracy: 0.9658 - lr: 3.0000e-04
# Epoch 8/10
# 221/221 [==============================] - 17s 76ms/step - loss: 0.0136 - accuracy: 0.9958 - val_loss: 0.0704 - val_accuracy: 0.9761 - lr: 9.0000e-05
# Epoch 9/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0104 - accuracy: 0.9967
# Epoch 9: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 221/221 [==============================] - 17s 76ms/step - loss: 0.0104 - accuracy: 0.9967 - val_loss: 0.0761 - val_accuracy: 0.9726 - lr: 9.0000e-05
# Epoch 10/10
# 221/221 [==============================] - 17s 76ms/step - loss: 0.0087 - accuracy: 0.9979 - val_loss: 0.0732 - val_accuracy: 0.9778 - lr: 2.7000e-05
# Epoch 1/10
# 221/221 [==============================] - 39s 137ms/step - loss: 0.6163 - accuracy: 0.7338 - val_loss: 0.1717 - val_accuracy: 0.9419 - lr: 0.0010
# Epoch 2/10
# 221/221 [==============================] - 21s 97ms/step - loss: 0.1673 - accuracy: 0.9359 - val_loss: 0.1276 - val_accuracy: 0.9590 - lr: 0.0010
# Epoch 3/10
# 221/221 [==============================] - 21s 97ms/step - loss: 0.1159 - accuracy: 0.9581 - val_loss: 0.0930 - val_accuracy: 0.9658 - lr: 0.0010
# Epoch 4/10
# 221/221 [==============================] - 22s 98ms/step - loss: 0.0969 - accuracy: 0.9665 - val_loss: 0.1004 - val_accuracy: 0.9846 - lr: 0.0010
# Epoch 5/10
# 221/221 [==============================] - 22s 99ms/step - loss: 0.0974 - accuracy: 0.9656 - val_loss: 0.0670 - val_accuracy: 0.9795 - lr: 0.0010
# Epoch 6/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0737 - accuracy: 0.9731
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 221/221 [==============================] - 22s 98ms/step - loss: 0.0737 - accuracy: 0.9731 - val_loss: 0.0849 - val_accuracy: 0.9829 - lr: 0.0010
# Epoch 7/10
# 221/221 [==============================] - 22s 98ms/step - loss: 0.0471 - accuracy: 0.9837 - val_loss: 0.0781 - val_accuracy: 0.9675 - lr: 3.0000e-04
# Epoch 8/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0398 - accuracy: 0.9853
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 221/221 [==============================] - 22s 98ms/step - loss: 0.0398 - accuracy: 0.9853 - val_loss: 0.0673 - val_accuracy: 0.9761 - lr: 3.0000e-04
# Epoch 9/10
# 221/221 [==============================] - 22s 98ms/step - loss: 0.0295 - accuracy: 0.9892 - val_loss: 0.0744 - val_accuracy: 0.9709 - lr: 9.0000e-05
# Epoch 10/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.9905
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 221/221 [==============================] - 22s 98ms/step - loss: 0.0263 - accuracy: 0.9905 - val_loss: 0.0669 - val_accuracy: 0.9761 - lr: 9.0000e-05
# Epoch 1/10
# 221/221 [==============================] - 37s 132ms/step - loss: 0.5561 - accuracy: 0.8254 - val_loss: 0.4250 - val_accuracy: 0.8188 - lr: 0.0010
# Epoch 2/10
# 221/221 [==============================] - 22s 98ms/step - loss: 0.1722 - accuracy: 0.9338 - val_loss: 0.1863 - val_accuracy: 0.9299 - lr: 0.0010
# Epoch 3/10
# 221/221 [==============================] - 22s 98ms/step - loss: 0.1256 - accuracy: 0.9550 - val_loss: 0.1764 - val_accuracy: 0.9350 - lr: 0.0010
# Epoch 4/10
# 221/221 [==============================] - 22s 98ms/step - loss: 0.1147 - accuracy: 0.9594 - val_loss: 0.1511 - val_accuracy: 0.9470 - lr: 0.0010
# Epoch 5/10
# 221/221 [==============================] - 22s 98ms/step - loss: 0.1034 - accuracy: 0.9624 - val_loss: 0.1137 - val_accuracy: 0.9607 - lr: 0.0010
# Epoch 6/10
# 221/221 [==============================] - 22s 98ms/step - loss: 0.0865 - accuracy: 0.9686 - val_loss: 0.1025 - val_accuracy: 0.9692 - lr: 0.0010
# Epoch 7/10
# 221/221 [==============================] - 22s 98ms/step - loss: 0.0811 - accuracy: 0.9704 - val_loss: 0.1389 - val_accuracy: 0.9470 - lr: 0.0010
# Epoch 8/10
# 221/221 [==============================] - 22s 98ms/step - loss: 0.0795 - accuracy: 0.9706 - val_loss: 0.1172 - val_accuracy: 0.9744 - lr: 0.0010
# Epoch 9/10
# 221/221 [==============================] - 22s 98ms/step - loss: 0.0671 - accuracy: 0.9738 - val_loss: 0.1130 - val_accuracy: 0.9709 - lr: 0.0010
# Epoch 10/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0777 - accuracy: 0.9728
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 221/221 [==============================] - 22s 98ms/step - loss: 0.0777 - accuracy: 0.9728 - val_loss: 0.1237 - val_accuracy: 0.9624 - lr: 0.0010
# Epoch 1/10
# 221/221 [==============================] - 28s 108ms/step - loss: 0.5620 - accuracy: 0.7960 - val_loss: 0.1648 - val_accuracy: 0.9385 - lr: 0.0010
# Epoch 2/10
# 221/221 [==============================] - 20s 89ms/step - loss: 0.1565 - accuracy: 0.9382 - val_loss: 0.0992 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 3/10
# 221/221 [==============================] - 20s 89ms/step - loss: 0.1090 - accuracy: 0.9614 - val_loss: 0.0756 - val_accuracy: 0.9709 - lr: 0.0010
# Epoch 4/10
# 221/221 [==============================] - 20s 89ms/step - loss: 0.0844 - accuracy: 0.9699 - val_loss: 0.0854 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 5/10
# 221/221 [==============================] - 20s 89ms/step - loss: 0.0684 - accuracy: 0.9752 - val_loss: 0.0580 - val_accuracy: 0.9778 - lr: 0.0010
# Epoch 6/10
# 221/221 [==============================] - 20s 89ms/step - loss: 0.0658 - accuracy: 0.9775 - val_loss: 0.0927 - val_accuracy: 0.9624 - lr: 0.0010
# Epoch 7/10
# 221/221 [==============================] - 20s 89ms/step - loss: 0.0567 - accuracy: 0.9801 - val_loss: 0.0527 - val_accuracy: 0.9812 - lr: 0.0010
# Epoch 8/10
# 221/221 [==============================] - 20s 89ms/step - loss: 0.0461 - accuracy: 0.9839 - val_loss: 0.1961 - val_accuracy: 0.9333 - lr: 0.0010
# Epoch 9/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0336 - accuracy: 0.9881
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 221/221 [==============================] - 20s 89ms/step - loss: 0.0336 - accuracy: 0.9881 - val_loss: 0.1218 - val_accuracy: 0.9590 - lr: 0.0010
# Epoch 10/10
# 221/221 [==============================] - 20s 89ms/step - loss: 0.0152 - accuracy: 0.9952 - val_loss: 0.0665 - val_accuracy: 0.9675 - lr: 3.0000e-04
# Epoch 1/10
# 221/221 [==============================] - 44s 151ms/step - loss: 0.7506 - accuracy: 0.6397 - val_loss: 0.3342 - val_accuracy: 0.8752 - lr: 0.0010
# Epoch 2/10
# 221/221 [==============================] - 23s 105ms/step - loss: 0.2572 - accuracy: 0.8919 - val_loss: 0.1896 - val_accuracy: 0.9368 - lr: 0.0010
# Epoch 3/10
# 221/221 [==============================] - 23s 105ms/step - loss: 0.1567 - accuracy: 0.9399 - val_loss: 0.1149 - val_accuracy: 0.9607 - lr: 0.0010
# Epoch 4/10
# 221/221 [==============================] - 23s 105ms/step - loss: 0.1276 - accuracy: 0.9513 - val_loss: 0.0946 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 5/10
# 221/221 [==============================] - 23s 105ms/step - loss: 0.0978 - accuracy: 0.9649 - val_loss: 0.0848 - val_accuracy: 0.9726 - lr: 0.0010
# Epoch 6/10
# 221/221 [==============================] - 23s 105ms/step - loss: 0.0906 - accuracy: 0.9666 - val_loss: 0.1115 - val_accuracy: 0.9556 - lr: 0.0010
# Epoch 7/10
# 221/221 [==============================] - 23s 105ms/step - loss: 0.0752 - accuracy: 0.9728 - val_loss: 0.0577 - val_accuracy: 0.9795 - lr: 0.0010
# Epoch 8/10
# 221/221 [==============================] - 23s 105ms/step - loss: 0.0678 - accuracy: 0.9774 - val_loss: 0.1529 - val_accuracy: 0.9419 - lr: 0.0010
# Epoch 9/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0631 - accuracy: 0.9765
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 221/221 [==============================] - 23s 105ms/step - loss: 0.0631 - accuracy: 0.9765 - val_loss: 0.0645 - val_accuracy: 0.9761 - lr: 0.0010
# Epoch 10/10
# 221/221 [==============================] - 23s 105ms/step - loss: 0.0353 - accuracy: 0.9897 - val_loss: 0.0737 - val_accuracy: 0.9726 - lr: 3.0000e-04
# Epoch 1/10
# 221/221 [==============================] - 24s 96ms/step - loss: 0.4318 - accuracy: 0.7937 - val_loss: 0.1470 - val_accuracy: 0.9538 - lr: 0.0010
# Epoch 2/10
# 221/221 [==============================] - 18s 82ms/step - loss: 0.1358 - accuracy: 0.9491 - val_loss: 0.0920 - val_accuracy: 0.9726 - lr: 0.0010
# Epoch 3/10
# 221/221 [==============================] - 18s 82ms/step - loss: 0.1005 - accuracy: 0.9641 - val_loss: 0.0716 - val_accuracy: 0.9744 - lr: 0.0010
# Epoch 4/10
# 221/221 [==============================] - 18s 82ms/step - loss: 0.0919 - accuracy: 0.9685 - val_loss: 0.0760 - val_accuracy: 0.9863 - lr: 0.0010
# Epoch 5/10
# 221/221 [==============================] - 18s 82ms/step - loss: 0.0761 - accuracy: 0.9734 - val_loss: 0.0566 - val_accuracy: 0.9812 - lr: 0.0010
# Epoch 6/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0623 - accuracy: 0.9784
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 221/221 [==============================] - 18s 82ms/step - loss: 0.0623 - accuracy: 0.9784 - val_loss: 0.0974 - val_accuracy: 0.9624 - lr: 0.0010
# Epoch 7/10
# 221/221 [==============================] - 18s 82ms/step - loss: 0.0408 - accuracy: 0.9850 - val_loss: 0.0815 - val_accuracy: 0.9658 - lr: 3.0000e-04
# Epoch 8/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0345 - accuracy: 0.9888
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 221/221 [==============================] - 18s 82ms/step - loss: 0.0345 - accuracy: 0.9888 - val_loss: 0.0746 - val_accuracy: 0.9692 - lr: 3.0000e-04
# Epoch 9/10
# 221/221 [==============================] - 18s 82ms/step - loss: 0.0236 - accuracy: 0.9924 - val_loss: 0.0679 - val_accuracy: 0.9709 - lr: 9.0000e-05
# Epoch 10/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0206 - accuracy: 0.9935
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 221/221 [==============================] - 18s 82ms/step - loss: 0.0206 - accuracy: 0.9935 - val_loss: 0.0677 - val_accuracy: 0.9709 - lr: 9.0000e-05
# Epoch 1/10
# 221/221 [==============================] - 43s 144ms/step - loss: 0.8344 - accuracy: 0.6540 - val_loss: 0.3619 - val_accuracy: 0.8701 - lr: 0.0010
# Epoch 2/10
# 221/221 [==============================] - 23s 106ms/step - loss: 0.1923 - accuracy: 0.9267 - val_loss: 0.1434 - val_accuracy: 0.9487 - lr: 0.0010
# Epoch 3/10
# 221/221 [==============================] - 23s 106ms/step - loss: 0.1155 - accuracy: 0.9567 - val_loss: 0.1406 - val_accuracy: 0.9487 - lr: 0.0010
# Epoch 4/10
# 221/221 [==============================] - 23s 106ms/step - loss: 0.0899 - accuracy: 0.9682 - val_loss: 0.0765 - val_accuracy: 0.9641 - lr: 0.0010
# Epoch 5/10
# 221/221 [==============================] - 23s 106ms/step - loss: 0.0666 - accuracy: 0.9734 - val_loss: 0.0647 - val_accuracy: 0.9761 - lr: 0.0010
# Epoch 6/10
# 221/221 [==============================] - 23s 106ms/step - loss: 0.0572 - accuracy: 0.9792 - val_loss: 0.0733 - val_accuracy: 0.9726 - lr: 0.0010
# Epoch 7/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0475 - accuracy: 0.9827
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 221/221 [==============================] - 23s 106ms/step - loss: 0.0475 - accuracy: 0.9827 - val_loss: 0.1089 - val_accuracy: 0.9573 - lr: 0.0010
# Epoch 8/10
# 221/221 [==============================] - 23s 106ms/step - loss: 0.0262 - accuracy: 0.9907 - val_loss: 0.0653 - val_accuracy: 0.9726 - lr: 3.0000e-04
# Epoch 9/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0181 - accuracy: 0.9938
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 221/221 [==============================] - 23s 106ms/step - loss: 0.0181 - accuracy: 0.9938 - val_loss: 0.0654 - val_accuracy: 0.9744 - lr: 3.0000e-04
# Epoch 10/10
# 221/221 [==============================] - 23s 106ms/step - loss: 0.0123 - accuracy: 0.9959 - val_loss: 0.0724 - val_accuracy: 0.9675 - lr: 9.0000e-05
# Best Accuracy at the generation 0: 99.78780746459961
# [[36 59 93  4  9 19]
#  [53 62 96  4 18 20]
#  [44 59 99  4 15 17]
#  [36 59 97  6  9 19]
#  [53 62 93  4 17 19]
#  [36 64 96  4  9 18]
#  [58 62 99  4 19 17]
#  [46 59 97  4 16 19]
#  [39 59 93  8  9 19]
#  [53 63 93  4 18 19]]
# Epoch 1/10
# 221/221 [==============================] - 18s 77ms/step - loss: 0.7585 - accuracy: 0.5214 - val_loss: 0.5189 - val_accuracy: 0.7641 - lr: 0.0010
# Epoch 2/10
# 221/221 [==============================] - 17s 76ms/step - loss: 0.3616 - accuracy: 0.8307 - val_loss: 0.1805 - val_accuracy: 0.9248 - lr: 0.0010
# Epoch 3/10
# 221/221 [==============================] - 17s 77ms/step - loss: 0.1482 - accuracy: 0.9440 - val_loss: 0.1192 - val_accuracy: 0.9556 - lr: 0.0010
# Epoch 4/10
# 221/221 [==============================] - 17s 76ms/step - loss: 0.1094 - accuracy: 0.9614 - val_loss: 0.1055 - val_accuracy: 0.9573 - lr: 0.0010
# Epoch 5/10
# 221/221 [==============================] - 17s 76ms/step - loss: 0.0849 - accuracy: 0.9680 - val_loss: 0.0726 - val_accuracy: 0.9778 - lr: 0.0010
# Epoch 6/10
# 221/221 [==============================] - 17s 76ms/step - loss: 0.0803 - accuracy: 0.9707 - val_loss: 0.1095 - val_accuracy: 0.9556 - lr: 0.0010
# Epoch 7/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0733 - accuracy: 0.9740
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 221/221 [==============================] - 17s 77ms/step - loss: 0.0733 - accuracy: 0.9740 - val_loss: 0.1035 - val_accuracy: 0.9521 - lr: 0.0010
# Epoch 8/10
# 221/221 [==============================] - 17s 76ms/step - loss: 0.0497 - accuracy: 0.9825 - val_loss: 0.0826 - val_accuracy: 0.9658 - lr: 3.0000e-04
# Epoch 9/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0367 - accuracy: 0.9877
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 221/221 [==============================] - 17s 76ms/step - loss: 0.0367 - accuracy: 0.9877 - val_loss: 0.0726 - val_accuracy: 0.9726 - lr: 3.0000e-04
# Epoch 10/10
# 221/221 [==============================] - 17s 76ms/step - loss: 0.0298 - accuracy: 0.9895 - val_loss: 0.0731 - val_accuracy: 0.9692 - lr: 9.0000e-05
# Epoch 1/10
# 221/221 [==============================] - 24s 107ms/step - loss: 0.6796 - accuracy: 0.7759 - val_loss: 0.1899 - val_accuracy: 0.9282 - lr: 0.0010
# Epoch 2/10
# 221/221 [==============================] - 23s 106ms/step - loss: 0.1455 - accuracy: 0.9458 - val_loss: 0.1493 - val_accuracy: 0.9521 - lr: 0.0010
# Epoch 3/10
# 221/221 [==============================] - 23s 106ms/step - loss: 0.1091 - accuracy: 0.9602 - val_loss: 0.1393 - val_accuracy: 0.9487 - lr: 0.0010
# Epoch 4/10
# 221/221 [==============================] - 23s 106ms/step - loss: 0.0953 - accuracy: 0.9638 - val_loss: 0.1390 - val_accuracy: 0.9641 - lr: 0.0010
# Epoch 5/10
# 221/221 [==============================] - 23s 106ms/step - loss: 0.0875 - accuracy: 0.9697 - val_loss: 0.1039 - val_accuracy: 0.9624 - lr: 0.0010
# Epoch 6/10
# 221/221 [==============================] - 23s 106ms/step - loss: 0.0802 - accuracy: 0.9724 - val_loss: 0.1039 - val_accuracy: 0.9709 - lr: 0.0010
# Epoch 7/10
# 221/221 [==============================] - 23s 105ms/step - loss: 0.0663 - accuracy: 0.9764 - val_loss: 0.0808 - val_accuracy: 0.9692 - lr: 0.0010
# Epoch 8/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0687 - accuracy: 0.9757
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 221/221 [==============================] - 23s 106ms/step - loss: 0.0687 - accuracy: 0.9757 - val_loss: 0.1513 - val_accuracy: 0.9368 - lr: 0.0010
# Epoch 9/10
# 221/221 [==============================] - 23s 106ms/step - loss: 0.0429 - accuracy: 0.9851 - val_loss: 0.0701 - val_accuracy: 0.9726 - lr: 3.0000e-04
# Epoch 10/10
# 221/221 [==============================] - 24s 107ms/step - loss: 0.0337 - accuracy: 0.9891 - val_loss: 0.0828 - val_accuracy: 0.9641 - lr: 3.0000e-04
# Epoch 1/10
# 221/221 [==============================] - 21s 91ms/step - loss: 0.4501 - accuracy: 0.8005 - val_loss: 0.2849 - val_accuracy: 0.8786 - lr: 0.0010
# Epoch 2/10
# 221/221 [==============================] - 20s 89ms/step - loss: 0.1459 - accuracy: 0.9444 - val_loss: 0.1120 - val_accuracy: 0.9538 - lr: 0.0010
# Epoch 3/10
# 221/221 [==============================] - 20s 89ms/step - loss: 0.1099 - accuracy: 0.9604 - val_loss: 0.0744 - val_accuracy: 0.9795 - lr: 0.0010
# Epoch 4/10
# 221/221 [==============================] - 20s 89ms/step - loss: 0.0894 - accuracy: 0.9692 - val_loss: 0.1536 - val_accuracy: 0.9709 - lr: 0.0010
# Epoch 5/10
# 221/221 [==============================] - 20s 89ms/step - loss: 0.0755 - accuracy: 0.9735 - val_loss: 0.0685 - val_accuracy: 0.9846 - lr: 0.0010
# Epoch 6/10
# 221/221 [==============================] - 20s 89ms/step - loss: 0.0666 - accuracy: 0.9751 - val_loss: 0.0706 - val_accuracy: 0.9761 - lr: 0.0010
# Epoch 7/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0624 - accuracy: 0.9769
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 221/221 [==============================] - 20s 89ms/step - loss: 0.0624 - accuracy: 0.9769 - val_loss: 0.0909 - val_accuracy: 0.9658 - lr: 0.0010
# Epoch 8/10
# 221/221 [==============================] - 20s 89ms/step - loss: 0.0361 - accuracy: 0.9876 - val_loss: 0.0636 - val_accuracy: 0.9761 - lr: 3.0000e-04
# Epoch 9/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0245 - accuracy: 0.9909
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 221/221 [==============================] - 20s 89ms/step - loss: 0.0245 - accuracy: 0.9909 - val_loss: 0.0669 - val_accuracy: 0.9709 - lr: 3.0000e-04
# Epoch 10/10
# 221/221 [==============================] - 20s 89ms/step - loss: 0.0177 - accuracy: 0.9936 - val_loss: 0.0674 - val_accuracy: 0.9744 - lr: 9.0000e-05
# Epoch 1/10
# 221/221 [==============================] - 19s 82ms/step - loss: 0.7541 - accuracy: 0.5132 - val_loss: 0.6962 - val_accuracy: 0.2701 - lr: 0.0010
# Epoch 2/10
# 221/221 [==============================] - 18s 81ms/step - loss: 0.6928 - accuracy: 0.5165 - val_loss: 0.7068 - val_accuracy: 0.2701 - lr: 0.0010
# Epoch 3/10
# 221/221 [==============================] - ETA: 0s - loss: 0.6927 - accuracy: 0.5165
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 221/221 [==============================] - 18s 81ms/step - loss: 0.6927 - accuracy: 0.5165 - val_loss: 0.7073 - val_accuracy: 0.2701 - lr: 0.0010
# Epoch 4/10
# 221/221 [==============================] - 18s 81ms/step - loss: 0.6926 - accuracy: 0.5165 - val_loss: 0.7077 - val_accuracy: 0.2701 - lr: 3.0000e-04
# Epoch 5/10
# 221/221 [==============================] - ETA: 0s - loss: 0.6926 - accuracy: 0.5165
# Epoch 5: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 221/221 [==============================] - 18s 81ms/step - loss: 0.6926 - accuracy: 0.5165 - val_loss: 0.7075 - val_accuracy: 0.2701 - lr: 3.0000e-04
# Epoch 6/10
# 221/221 [==============================] - 18s 81ms/step - loss: 0.6926 - accuracy: 0.5165 - val_loss: 0.7078 - val_accuracy: 0.2701 - lr: 9.0000e-05
# Epoch 7/10
# 221/221 [==============================] - ETA: 0s - loss: 0.6926 - accuracy: 0.5165
# Epoch 7: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 221/221 [==============================] - 18s 81ms/step - loss: 0.6926 - accuracy: 0.5165 - val_loss: 0.7077 - val_accuracy: 0.2701 - lr: 9.0000e-05
# Epoch 8/10
# 221/221 [==============================] - 18s 81ms/step - loss: 0.6926 - accuracy: 0.5165 - val_loss: 0.7078 - val_accuracy: 0.2701 - lr: 2.7000e-05
# Epoch 9/10
# 221/221 [==============================] - ETA: 0s - loss: 0.6926 - accuracy: 0.5165
# Epoch 9: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 221/221 [==============================] - 18s 81ms/step - loss: 0.6926 - accuracy: 0.5165 - val_loss: 0.7078 - val_accuracy: 0.2701 - lr: 2.7000e-05
# Epoch 10/10
# 221/221 [==============================] - 18s 81ms/step - loss: 0.6926 - accuracy: 0.5165 - val_loss: 0.7079 - val_accuracy: 0.2701 - lr: 8.1000e-06
# Epoch 1/10
# 221/221 [==============================] - 22s 99ms/step - loss: 0.5820 - accuracy: 0.7560 - val_loss: 0.2818 - val_accuracy: 0.8684 - lr: 0.0010
# Epoch 2/10
# 221/221 [==============================] - 22s 98ms/step - loss: 0.1562 - accuracy: 0.9378 - val_loss: 0.1054 - val_accuracy: 0.9709 - lr: 0.0010
# Epoch 3/10
# 221/221 [==============================] - 22s 98ms/step - loss: 0.1108 - accuracy: 0.9604 - val_loss: 0.0932 - val_accuracy: 0.9692 - lr: 0.0010
# Epoch 4/10
# 221/221 [==============================] - 22s 98ms/step - loss: 0.0850 - accuracy: 0.9713 - val_loss: 0.0800 - val_accuracy: 0.9880 - lr: 0.0010
# Epoch 5/10
# 221/221 [==============================] - 22s 98ms/step - loss: 0.0768 - accuracy: 0.9717 - val_loss: 0.0476 - val_accuracy: 0.9880 - lr: 0.0010
# Epoch 6/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0627 - accuracy: 0.9782
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 221/221 [==============================] - 22s 98ms/step - loss: 0.0627 - accuracy: 0.9782 - val_loss: 0.1146 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 7/10
# 221/221 [==============================] - 22s 98ms/step - loss: 0.0453 - accuracy: 0.9849 - val_loss: 0.0926 - val_accuracy: 0.9641 - lr: 3.0000e-04
# Epoch 8/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0338 - accuracy: 0.9874
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 221/221 [==============================] - 22s 98ms/step - loss: 0.0338 - accuracy: 0.9874 - val_loss: 0.0559 - val_accuracy: 0.9846 - lr: 3.0000e-04
# Epoch 9/10
# 221/221 [==============================] - 22s 98ms/step - loss: 0.0250 - accuracy: 0.9912 - val_loss: 0.0551 - val_accuracy: 0.9829 - lr: 9.0000e-05
# Epoch 10/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0227 - accuracy: 0.9915
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 221/221 [==============================] - 22s 98ms/step - loss: 0.0227 - accuracy: 0.9915 - val_loss: 0.0533 - val_accuracy: 0.9829 - lr: 9.0000e-05
# Epoch 1/10
# 221/221 [==============================] - 23s 93ms/step - loss: 0.4344 - accuracy: 0.7998 - val_loss: 0.1083 - val_accuracy: 0.9624 - lr: 0.0010
# Epoch 2/10
# 221/221 [==============================] - 17s 78ms/step - loss: 0.1280 - accuracy: 0.9537 - val_loss: 0.0964 - val_accuracy: 0.9761 - lr: 0.0010
# Epoch 3/10
# 221/221 [==============================] - 17s 78ms/step - loss: 0.0932 - accuracy: 0.9675 - val_loss: 0.0706 - val_accuracy: 0.9795 - lr: 0.0010
# Epoch 4/10
# 221/221 [==============================] - 17s 78ms/step - loss: 0.0793 - accuracy: 0.9735 - val_loss: 0.0719 - val_accuracy: 0.9846 - lr: 0.0010
# Epoch 5/10
# 221/221 [==============================] - 17s 78ms/step - loss: 0.0581 - accuracy: 0.9785 - val_loss: 0.0540 - val_accuracy: 0.9812 - lr: 0.0010
# Epoch 6/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0528 - accuracy: 0.9813
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 221/221 [==============================] - 17s 78ms/step - loss: 0.0528 - accuracy: 0.9813 - val_loss: 0.0617 - val_accuracy: 0.9829 - lr: 0.0010
# Epoch 7/10
# 221/221 [==============================] - 17s 78ms/step - loss: 0.0238 - accuracy: 0.9918 - val_loss: 0.0581 - val_accuracy: 0.9812 - lr: 3.0000e-04
# Epoch 8/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0173 - accuracy: 0.9943
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 221/221 [==============================] - 17s 78ms/step - loss: 0.0173 - accuracy: 0.9943 - val_loss: 0.0583 - val_accuracy: 0.9795 - lr: 3.0000e-04
# Epoch 9/10
# 221/221 [==============================] - 17s 78ms/step - loss: 0.0099 - accuracy: 0.9970 - val_loss: 0.0538 - val_accuracy: 0.9829 - lr: 9.0000e-05
# Epoch 10/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0084 - accuracy: 0.9980
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 221/221 [==============================] - 17s 78ms/step - loss: 0.0084 - accuracy: 0.9980 - val_loss: 0.0639 - val_accuracy: 0.9812 - lr: 9.0000e-05
# Epoch 1/10
# 221/221 [==============================] - 45s 158ms/step - loss: 0.5121 - accuracy: 0.7885 - val_loss: 0.1972 - val_accuracy: 0.9385 - lr: 0.0010
# Epoch 2/10
# 221/221 [==============================] - 25s 113ms/step - loss: 0.1853 - accuracy: 0.9267 - val_loss: 0.1945 - val_accuracy: 0.9231 - lr: 0.0010
# Epoch 3/10
# 221/221 [==============================] - 25s 113ms/step - loss: 0.1366 - accuracy: 0.9508 - val_loss: 0.1006 - val_accuracy: 0.9709 - lr: 0.0010
# Epoch 4/10
# 221/221 [==============================] - 25s 113ms/step - loss: 0.0920 - accuracy: 0.9687 - val_loss: 0.1064 - val_accuracy: 0.9538 - lr: 0.0010
# Epoch 5/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0777 - accuracy: 0.9703
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 221/221 [==============================] - 25s 113ms/step - loss: 0.0777 - accuracy: 0.9703 - val_loss: 0.1124 - val_accuracy: 0.9624 - lr: 0.0010
# Epoch 6/10
# 221/221 [==============================] - 25s 113ms/step - loss: 0.0460 - accuracy: 0.9837 - val_loss: 0.0793 - val_accuracy: 0.9641 - lr: 3.0000e-04
# Epoch 7/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0327 - accuracy: 0.9885
# Epoch 7: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 221/221 [==============================] - 25s 113ms/step - loss: 0.0327 - accuracy: 0.9885 - val_loss: 0.0807 - val_accuracy: 0.9692 - lr: 3.0000e-04
# Epoch 8/10
# 221/221 [==============================] - 25s 113ms/step - loss: 0.0228 - accuracy: 0.9909 - val_loss: 0.0815 - val_accuracy: 0.9675 - lr: 9.0000e-05
# Epoch 9/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0199 - accuracy: 0.9936
# Epoch 9: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 221/221 [==============================] - 25s 113ms/step - loss: 0.0199 - accuracy: 0.9936 - val_loss: 0.0779 - val_accuracy: 0.9692 - lr: 9.0000e-05
# Epoch 10/10
# 221/221 [==============================] - 25s 113ms/step - loss: 0.0163 - accuracy: 0.9945 - val_loss: 0.0763 - val_accuracy: 0.9709 - lr: 2.7000e-05
# Epoch 1/10
# 221/221 [==============================] - 30s 115ms/step - loss: 0.5708 - accuracy: 0.7906 - val_loss: 0.1459 - val_accuracy: 0.9521 - lr: 0.0010
# Epoch 2/10
# 221/221 [==============================] - 21s 94ms/step - loss: 0.1438 - accuracy: 0.9468 - val_loss: 0.1359 - val_accuracy: 0.9453 - lr: 0.0010
# Epoch 3/10
# 221/221 [==============================] - ETA: 0s - loss: 0.1173 - accuracy: 0.9580
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 221/221 [==============================] - 21s 94ms/step - loss: 0.1173 - accuracy: 0.9580 - val_loss: 0.1306 - val_accuracy: 0.9470 - lr: 0.0010
# Epoch 4/10
# 221/221 [==============================] - 21s 94ms/step - loss: 0.0775 - accuracy: 0.9738 - val_loss: 0.0764 - val_accuracy: 0.9761 - lr: 3.0000e-04
# Epoch 5/10
# 221/221 [==============================] - 21s 94ms/step - loss: 0.0645 - accuracy: 0.9772 - val_loss: 0.0631 - val_accuracy: 0.9778 - lr: 3.0000e-04
# Epoch 6/10
# 221/221 [==============================] - 21s 94ms/step - loss: 0.0584 - accuracy: 0.9820 - val_loss: 0.0701 - val_accuracy: 0.9812 - lr: 3.0000e-04
# Epoch 7/10
# 221/221 [==============================] - 21s 94ms/step - loss: 0.0518 - accuracy: 0.9830 - val_loss: 0.0850 - val_accuracy: 0.9709 - lr: 3.0000e-04
# Epoch 8/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0480 - accuracy: 0.9834
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 221/221 [==============================] - 21s 94ms/step - loss: 0.0480 - accuracy: 0.9834 - val_loss: 0.0657 - val_accuracy: 0.9795 - lr: 3.0000e-04
# Epoch 9/10
# 221/221 [==============================] - 21s 94ms/step - loss: 0.0338 - accuracy: 0.9892 - val_loss: 0.0735 - val_accuracy: 0.9709 - lr: 9.0000e-05
# Epoch 10/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0285 - accuracy: 0.9900
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 221/221 [==============================] - 21s 94ms/step - loss: 0.0285 - accuracy: 0.9900 - val_loss: 0.0653 - val_accuracy: 0.9778 - lr: 9.0000e-05
# Epoch 1/10
# 221/221 [==============================] - 22s 90ms/step - loss: 0.5218 - accuracy: 0.7432 - val_loss: 0.3560 - val_accuracy: 0.8547 - lr: 0.0010
# Epoch 2/10
# 221/221 [==============================] - 18s 83ms/step - loss: 0.1682 - accuracy: 0.9349 - val_loss: 0.1119 - val_accuracy: 0.9709 - lr: 0.0010
# Epoch 3/10
# 221/221 [==============================] - 18s 83ms/step - loss: 0.1123 - accuracy: 0.9591 - val_loss: 0.1111 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 4/10
# 221/221 [==============================] - 18s 83ms/step - loss: 0.0854 - accuracy: 0.9697 - val_loss: 0.0687 - val_accuracy: 0.9795 - lr: 0.0010
# Epoch 5/10
# 221/221 [==============================] - 18s 83ms/step - loss: 0.0721 - accuracy: 0.9738 - val_loss: 0.0666 - val_accuracy: 0.9744 - lr: 0.0010
# Epoch 6/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0562 - accuracy: 0.9791
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 221/221 [==============================] - 18s 83ms/step - loss: 0.0562 - accuracy: 0.9791 - val_loss: 0.0877 - val_accuracy: 0.9658 - lr: 0.0010
# Epoch 7/10
# 221/221 [==============================] - 18s 83ms/step - loss: 0.0317 - accuracy: 0.9878 - val_loss: 0.0560 - val_accuracy: 0.9795 - lr: 3.0000e-04
# Epoch 8/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0223 - accuracy: 0.9917
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 221/221 [==============================] - 18s 83ms/step - loss: 0.0223 - accuracy: 0.9917 - val_loss: 0.0552 - val_accuracy: 0.9778 - lr: 3.0000e-04
# Epoch 9/10
# 221/221 [==============================] - 18s 83ms/step - loss: 0.0140 - accuracy: 0.9956 - val_loss: 0.0513 - val_accuracy: 0.9744 - lr: 9.0000e-05
# Epoch 10/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0117 - accuracy: 0.9960
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 221/221 [==============================] - 18s 83ms/step - loss: 0.0117 - accuracy: 0.9960 - val_loss: 0.0527 - val_accuracy: 0.9778 - lr: 9.0000e-05
# Epoch 1/10
# 221/221 [==============================] - 42s 147ms/step - loss: 0.5232 - accuracy: 0.7894 - val_loss: 0.1460 - val_accuracy: 0.9504 - lr: 0.0010
# Epoch 2/10
# 221/221 [==============================] - 23s 105ms/step - loss: 0.1444 - accuracy: 0.9458 - val_loss: 0.1076 - val_accuracy: 0.9658 - lr: 0.0010
# Epoch 3/10
# 221/221 [==============================] - 23s 105ms/step - loss: 0.1190 - accuracy: 0.9564 - val_loss: 0.0973 - val_accuracy: 0.9744 - lr: 0.0010
# Epoch 4/10
# 221/221 [==============================] - 23s 105ms/step - loss: 0.0926 - accuracy: 0.9680 - val_loss: 0.0947 - val_accuracy: 0.9761 - lr: 0.0010
# Epoch 5/10
# 221/221 [==============================] - 23s 105ms/step - loss: 0.0742 - accuracy: 0.9727 - val_loss: 0.0642 - val_accuracy: 0.9812 - lr: 0.0010
# Epoch 6/10
# 221/221 [==============================] - 23s 106ms/step - loss: 0.0707 - accuracy: 0.9751 - val_loss: 0.0808 - val_accuracy: 0.9709 - lr: 0.0010
# Epoch 7/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0649 - accuracy: 0.9752
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 221/221 [==============================] - 23s 105ms/step - loss: 0.0649 - accuracy: 0.9752 - val_loss: 0.0951 - val_accuracy: 0.9658 - lr: 0.0010
# Epoch 8/10
# 221/221 [==============================] - 23s 105ms/step - loss: 0.0417 - accuracy: 0.9851 - val_loss: 0.0751 - val_accuracy: 0.9778 - lr: 3.0000e-04
# Epoch 9/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0314 - accuracy: 0.9890
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 221/221 [==============================] - 23s 106ms/step - loss: 0.0314 - accuracy: 0.9890 - val_loss: 0.0650 - val_accuracy: 0.9795 - lr: 3.0000e-04
# Epoch 10/10
# 221/221 [==============================] - 23s 105ms/step - loss: 0.0263 - accuracy: 0.9901 - val_loss: 0.0687 - val_accuracy: 0.9744 - lr: 9.0000e-05
# Best Accuracy at the generation 1: 99.80195164680481
# [[36 64 96  4  9 18]
#  [39 59 93  8  9 19]
#  [58 62 99  4 19 17]
#  [44 59 99  4 15 17]
#  [53 62 93  4 17 19]
#  [36 65 93  6  9 19]
#  [43 59 99 10  9 17]
#  [59 62 99  4 17 17]
#  [44 60 93  4 18 19]
#  [53 62 98  4 19 18]]
# Epoch 1/10
# 221/221 [==============================] - 18s 79ms/step - loss: 0.4154 - accuracy: 0.8065 - val_loss: 0.1213 - val_accuracy: 0.9607 - lr: 0.0010
# Epoch 2/10
# 221/221 [==============================] - 17s 78ms/step - loss: 0.1267 - accuracy: 0.9508 - val_loss: 0.1141 - val_accuracy: 0.9556 - lr: 0.0010
# Epoch 3/10
# 221/221 [==============================] - 17s 78ms/step - loss: 0.0958 - accuracy: 0.9668 - val_loss: 0.1063 - val_accuracy: 0.9624 - lr: 0.0010
# Epoch 4/10
# 221/221 [==============================] - 17s 78ms/step - loss: 0.0748 - accuracy: 0.9741 - val_loss: 0.0632 - val_accuracy: 0.9846 - lr: 0.0010
# Epoch 5/10
# 221/221 [==============================] - 17s 78ms/step - loss: 0.0583 - accuracy: 0.9791 - val_loss: 0.0557 - val_accuracy: 0.9795 - lr: 0.0010
# Epoch 6/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0499 - accuracy: 0.9796
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 221/221 [==============================] - 17s 78ms/step - loss: 0.0499 - accuracy: 0.9796 - val_loss: 0.0594 - val_accuracy: 0.9829 - lr: 0.0010
# Epoch 7/10
# 221/221 [==============================] - 17s 78ms/step - loss: 0.0250 - accuracy: 0.9905 - val_loss: 0.0748 - val_accuracy: 0.9761 - lr: 3.0000e-04
# Epoch 8/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0173 - accuracy: 0.9935
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 221/221 [==============================] - 17s 78ms/step - loss: 0.0173 - accuracy: 0.9935 - val_loss: 0.0536 - val_accuracy: 0.9812 - lr: 3.0000e-04
# Epoch 9/10
# 221/221 [==============================] - 17s 78ms/step - loss: 0.0095 - accuracy: 0.9976 - val_loss: 0.0653 - val_accuracy: 0.9795 - lr: 9.0000e-05
# Epoch 10/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.9977
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 221/221 [==============================] - 17s 78ms/step - loss: 0.0080 - accuracy: 0.9977 - val_loss: 0.0736 - val_accuracy: 0.9812 - lr: 9.0000e-05
# Epoch 1/10
# 221/221 [==============================] - 19s 84ms/step - loss: 0.4432 - accuracy: 0.7799 - val_loss: 0.1452 - val_accuracy: 0.9487 - lr: 0.0010
# Epoch 2/10
# 221/221 [==============================] - 18s 83ms/step - loss: 0.1702 - accuracy: 0.9368 - val_loss: 0.1476 - val_accuracy: 0.9419 - lr: 0.0010
# Epoch 3/10
# 221/221 [==============================] - 18s 83ms/step - loss: 0.1232 - accuracy: 0.9518 - val_loss: 0.1166 - val_accuracy: 0.9556 - lr: 0.0010
# Epoch 4/10
# 221/221 [==============================] - 18s 83ms/step - loss: 0.0967 - accuracy: 0.9642 - val_loss: 0.1229 - val_accuracy: 0.9726 - lr: 0.0010
# Epoch 5/10
# 221/221 [==============================] - 18s 83ms/step - loss: 0.0840 - accuracy: 0.9689 - val_loss: 0.1425 - val_accuracy: 0.9556 - lr: 0.0010
# Epoch 6/10
# 221/221 [==============================] - 18s 83ms/step - loss: 0.0873 - accuracy: 0.9665 - val_loss: 0.0999 - val_accuracy: 0.9744 - lr: 0.0010
# Epoch 7/10
# 221/221 [==============================] - 18s 83ms/step - loss: 0.0724 - accuracy: 0.9738 - val_loss: 0.0864 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 8/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0718 - accuracy: 0.9748
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 221/221 [==============================] - 18s 83ms/step - loss: 0.0718 - accuracy: 0.9748 - val_loss: 0.0944 - val_accuracy: 0.9726 - lr: 0.0010
# Epoch 9/10
# 221/221 [==============================] - 18s 83ms/step - loss: 0.0429 - accuracy: 0.9843 - val_loss: 0.0711 - val_accuracy: 0.9726 - lr: 3.0000e-04
# Epoch 10/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0332 - accuracy: 0.9866
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 221/221 [==============================] - 18s 83ms/step - loss: 0.0332 - accuracy: 0.9866 - val_loss: 0.0889 - val_accuracy: 0.9709 - lr: 3.0000e-04
# Epoch 1/10
# 221/221 [==============================] - 26s 114ms/step - loss: 0.4553 - accuracy: 0.7980 - val_loss: 0.1439 - val_accuracy: 0.9521 - lr: 0.0010
# Epoch 2/10
# 221/221 [==============================] - 25s 114ms/step - loss: 0.1637 - accuracy: 0.9448 - val_loss: 0.1230 - val_accuracy: 0.9624 - lr: 0.0010
# Epoch 3/10
# 221/221 [==============================] - 25s 113ms/step - loss: 0.1122 - accuracy: 0.9614 - val_loss: 0.0871 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 4/10
# 221/221 [==============================] - 25s 113ms/step - loss: 0.0829 - accuracy: 0.9718 - val_loss: 0.0822 - val_accuracy: 0.9692 - lr: 0.0010
# Epoch 5/10
# 221/221 [==============================] - 25s 114ms/step - loss: 0.0746 - accuracy: 0.9737 - val_loss: 0.0700 - val_accuracy: 0.9778 - lr: 0.0010
# Epoch 6/10
# 221/221 [==============================] - 25s 113ms/step - loss: 0.0678 - accuracy: 0.9741 - val_loss: 0.1066 - val_accuracy: 0.9590 - lr: 0.0010
# Epoch 7/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0641 - accuracy: 0.9755
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 221/221 [==============================] - 25s 113ms/step - loss: 0.0641 - accuracy: 0.9755 - val_loss: 0.0972 - val_accuracy: 0.9624 - lr: 0.0010
# Epoch 8/10
# 221/221 [==============================] - 25s 113ms/step - loss: 0.0337 - accuracy: 0.9887 - val_loss: 0.0564 - val_accuracy: 0.9761 - lr: 3.0000e-04
# Epoch 9/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0259 - accuracy: 0.9914
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 221/221 [==============================] - 25s 113ms/step - loss: 0.0259 - accuracy: 0.9914 - val_loss: 0.0508 - val_accuracy: 0.9778 - lr: 3.0000e-04
# Epoch 10/10
# 221/221 [==============================] - 25s 114ms/step - loss: 0.0188 - accuracy: 0.9932 - val_loss: 0.0571 - val_accuracy: 0.9761 - lr: 9.0000e-05
# Epoch 1/10
# 221/221 [==============================] - 20s 90ms/step - loss: 0.5499 - accuracy: 0.7915 - val_loss: 0.1531 - val_accuracy: 0.9504 - lr: 0.0010
# Epoch 2/10
# 221/221 [==============================] - 20s 89ms/step - loss: 0.1603 - accuracy: 0.9385 - val_loss: 0.1864 - val_accuracy: 0.9333 - lr: 0.0010
# Epoch 3/10
# 221/221 [==============================] - 20s 89ms/step - loss: 0.1219 - accuracy: 0.9530 - val_loss: 0.0989 - val_accuracy: 0.9692 - lr: 0.0010
# Epoch 4/10
# 221/221 [==============================] - 20s 89ms/step - loss: 0.1032 - accuracy: 0.9652 - val_loss: 0.0735 - val_accuracy: 0.9795 - lr: 0.0010
# Epoch 5/10
# 221/221 [==============================] - 20s 89ms/step - loss: 0.1322 - accuracy: 0.9505 - val_loss: 0.0842 - val_accuracy: 0.9709 - lr: 0.0010
# Epoch 6/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0789 - accuracy: 0.9716
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 221/221 [==============================] - 20s 89ms/step - loss: 0.0789 - accuracy: 0.9716 - val_loss: 0.0754 - val_accuracy: 0.9726 - lr: 0.0010
# Epoch 7/10
# 221/221 [==============================] - 20s 89ms/step - loss: 0.0474 - accuracy: 0.9829 - val_loss: 0.0736 - val_accuracy: 0.9709 - lr: 3.0000e-04
# Epoch 8/10
# 221/221 [==============================] - 20s 89ms/step - loss: 0.0383 - accuracy: 0.9867 - val_loss: 0.0621 - val_accuracy: 0.9812 - lr: 3.0000e-04
# Epoch 9/10
# 221/221 [==============================] - 20s 89ms/step - loss: 0.0318 - accuracy: 0.9884 - val_loss: 0.0709 - val_accuracy: 0.9709 - lr: 3.0000e-04
# Epoch 10/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0277 - accuracy: 0.9901
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# ...
# 221/221 [==============================] - ETA: 0s - loss: 0.0139 - accuracy: 0.9955
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 221/221 [==============================] - 21s 97ms/step - loss: 0.0139 - accuracy: 0.9955 - val_loss: 0.0543 - val_accuracy: 0.9812 - lr: 9.0000e-05
# Epoch 1/10
# 221/221 [==============================] - 19s 82ms/step - loss: 0.4455 - accuracy: 0.7973 - val_loss: 0.1351 - val_accuracy: 0.9538 - lr: 0.0010
# Epoch 2/10
# 221/221 [==============================] - 18s 82ms/step - loss: 0.1129 - accuracy: 0.9597 - val_loss: 0.1289 - val_accuracy: 0.9538 - lr: 0.0010
# Epoch 3/10
# 221/221 [==============================] - 18s 81ms/step - loss: 0.0845 - accuracy: 0.9693 - val_loss: 0.0802 - val_accuracy: 0.9726 - lr: 0.0010
# Epoch 4/10
# 221/221 [==============================] - 18s 81ms/step - loss: 0.0735 - accuracy: 0.9745 - val_loss: 0.0794 - val_accuracy: 0.9761 - lr: 0.0010
# Epoch 5/10
# 221/221 [==============================] - 18s 81ms/step - loss: 0.0560 - accuracy: 0.9793 - val_loss: 0.0504 - val_accuracy: 0.9829 - lr: 0.0010
# Epoch 6/10
# 221/221 [==============================] - 18s 81ms/step - loss: 0.0502 - accuracy: 0.9829 - val_loss: 0.0776 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 7/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0403 - accuracy: 0.9856
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 221/221 [==============================] - 18s 81ms/step - loss: 0.0403 - accuracy: 0.9856 - val_loss: 0.0564 - val_accuracy: 0.9795 - lr: 0.0010
# Epoch 8/10
# 221/221 [==============================] - 18s 81ms/step - loss: 0.0202 - accuracy: 0.9919 - val_loss: 0.0549 - val_accuracy: 0.9778 - lr: 3.0000e-04
# Epoch 9/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0132 - accuracy: 0.9948
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 221/221 [==============================] - 18s 81ms/step - loss: 0.0132 - accuracy: 0.9948 - val_loss: 0.0615 - val_accuracy: 0.9744 - lr: 3.0000e-04
# Epoch 10/10
# 221/221 [==============================] - 18s 81ms/step - loss: 0.0083 - accuracy: 0.9975 - val_loss: 0.0663 - val_accuracy: 0.9726 - lr: 9.0000e-05
# Epoch 1/10
# 221/221 [==============================] - 23s 99ms/step - loss: 0.3490 - accuracy: 0.8441 - val_loss: 0.1218 - val_accuracy: 0.9692 - lr: 0.0010
# Epoch 2/10
# 221/221 [==============================] - 22s 97ms/step - loss: 0.1146 - accuracy: 0.9578 - val_loss: 0.1309 - val_accuracy: 0.9590 - lr: 0.0010
# Epoch 3/10
# 221/221 [==============================] - 22s 98ms/step - loss: 0.0974 - accuracy: 0.9628 - val_loss: 0.1084 - val_accuracy: 0.9709 - lr: 0.0010
# Epoch 4/10
# 221/221 [==============================] - 22s 98ms/step - loss: 0.0773 - accuracy: 0.9731 - val_loss: 0.0840 - val_accuracy: 0.9709 - lr: 0.0010
# Epoch 5/10
# 221/221 [==============================] - 22s 98ms/step - loss: 0.0582 - accuracy: 0.9798 - val_loss: 0.0716 - val_accuracy: 0.9744 - lr: 0.0010
# Epoch 6/10
# 221/221 [==============================] - 22s 98ms/step - loss: 0.0601 - accuracy: 0.9792 - val_loss: 0.1068 - val_accuracy: 0.9573 - lr: 0.0010
# Epoch 7/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0494 - accuracy: 0.9812
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 221/221 [==============================] - 22s 98ms/step - loss: 0.0494 - accuracy: 0.9812 - val_loss: 0.0740 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 8/10
# 221/221 [==============================] - 22s 98ms/step - loss: 0.0269 - accuracy: 0.9892 - val_loss: 0.0766 - val_accuracy: 0.9675 - lr: 3.0000e-04
# Epoch 9/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0162 - accuracy: 0.9942
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 221/221 [==============================] - 22s 98ms/step - loss: 0.0162 - accuracy: 0.9942 - val_loss: 0.0798 - val_accuracy: 0.9641 - lr: 3.0000e-04
# Epoch 10/10
# 221/221 [==============================] - 22s 98ms/step - loss: 0.0098 - accuracy: 0.9966 - val_loss: 0.0741 - val_accuracy: 0.9692 - lr: 9.0000e-05
# Epoch 1/10
# 221/221 [==============================] - 24s 107ms/step - loss: 0.4659 - accuracy: 0.7803 - val_loss: 0.1660 - val_accuracy: 0.9436 - lr: 0.0010
# Epoch 2/10
# 221/221 [==============================] - 23s 106ms/step - loss: 0.1284 - accuracy: 0.9544 - val_loss: 0.1208 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 3/10
# 221/221 [==============================] - 23s 106ms/step - loss: 0.1108 - accuracy: 0.9591 - val_loss: 0.1165 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 4/10
# 221/221 [==============================] - 23s 106ms/step - loss: 0.0944 - accuracy: 0.9655 - val_loss: 0.0918 - val_accuracy: 0.9709 - lr: 0.0010
# Epoch 5/10
# 221/221 [==============================] - 23s 106ms/step - loss: 0.0792 - accuracy: 0.9704 - val_loss: 0.0812 - val_accuracy: 0.9778 - lr: 0.0010
# Epoch 6/10
# 221/221 [==============================] - 23s 106ms/step - loss: 0.0712 - accuracy: 0.9750 - val_loss: 0.1304 - val_accuracy: 0.9419 - lr: 0.0010
# Epoch 7/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0755 - accuracy: 0.9726
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 221/221 [==============================] - 23s 106ms/step - loss: 0.0755 - accuracy: 0.9726 - val_loss: 0.2067 - val_accuracy: 0.9214 - lr: 0.0010
# Epoch 8/10
# 221/221 [==============================] - 23s 106ms/step - loss: 0.0722 - accuracy: 0.9734 - val_loss: 0.0713 - val_accuracy: 0.9726 - lr: 3.0000e-04
# Epoch 9/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0415 - accuracy: 0.9843
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 221/221 [==============================] - 23s 106ms/step - loss: 0.0415 - accuracy: 0.9843 - val_loss: 0.0850 - val_accuracy: 0.9709 - lr: 3.0000e-04
# Epoch 10/10
# 221/221 [==============================] - 23s 106ms/step - loss: 0.0286 - accuracy: 0.9890 - val_loss: 0.0777 - val_accuracy: 0.9709 - lr: 9.0000e-05
# Epoch 1/10
# 221/221 [==============================] - 37s 130ms/step - loss: 0.7650 - accuracy: 0.6964 - val_loss: 0.3700 - val_accuracy: 0.8872 - lr: 0.0010
# Epoch 2/10
# 221/221 [==============================] - 21s 96ms/step - loss: 0.2460 - accuracy: 0.8962 - val_loss: 0.1488 - val_accuracy: 0.9436 - lr: 0.0010
# Epoch 3/10
# 221/221 [==============================] - 21s 96ms/step - loss: 0.1370 - accuracy: 0.9492 - val_loss: 0.1326 - val_accuracy: 0.9573 - lr: 0.0010
# Epoch 4/10
# 221/221 [==============================] - 21s 96ms/step - loss: 0.1108 - accuracy: 0.9617 - val_loss: 0.0869 - val_accuracy: 0.9692 - lr: 0.0010
# Epoch 5/10
# 221/221 [==============================] - 21s 96ms/step - loss: 0.0947 - accuracy: 0.9655 - val_loss: 0.0860 - val_accuracy: 0.9641 - lr: 0.0010
# Epoch 6/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0849 - accuracy: 0.9694
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 221/221 [==============================] - 21s 96ms/step - loss: 0.0849 - accuracy: 0.9694 - val_loss: 0.1144 - val_accuracy: 0.9556 - lr: 0.0010
# Epoch 7/10
# 221/221 [==============================] - 21s 96ms/step - loss: 0.0531 - accuracy: 0.9812 - val_loss: 0.0943 - val_accuracy: 0.9658 - lr: 3.0000e-04
# Epoch 8/10
# 221/221 [==============================] - 21s 96ms/step - loss: 0.0463 - accuracy: 0.9830 - val_loss: 0.0617 - val_accuracy: 0.9795 - lr: 3.0000e-04
# Epoch 9/10
# 221/221 [==============================] - 21s 96ms/step - loss: 0.0380 - accuracy: 0.9863 - val_loss: 0.0608 - val_accuracy: 0.9778 - lr: 3.0000e-04
# Epoch 10/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0355 - accuracy: 0.9866
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 221/221 [==============================] - 21s 96ms/step - loss: 0.0355 - accuracy: 0.9866 - val_loss: 0.0851 - val_accuracy: 0.9675 - lr: 3.0000e-04
# Epoch 1/10
# 221/221 [==============================] - 27s 108ms/step - loss: 0.4860 - accuracy: 0.7860 - val_loss: 0.2266 - val_accuracy: 0.8906 - lr: 0.0010
# Epoch 2/10
# 221/221 [==============================] - 22s 98ms/step - loss: 0.1414 - accuracy: 0.9440 - val_loss: 0.0923 - val_accuracy: 0.9692 - lr: 0.0010
# Epoch 3/10
# 221/221 [==============================] - 22s 97ms/step - loss: 0.1054 - accuracy: 0.9615 - val_loss: 0.0913 - val_accuracy: 0.9624 - lr: 0.0010
# Epoch 4/10
# 221/221 [==============================] - ETA: 0s - loss: 0.1024 - accuracy: 0.9642
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 221/221 [==============================] - 22s 98ms/step - loss: 0.1024 - accuracy: 0.9642 - val_loss: 0.1073 - val_accuracy: 0.9624 - lr: 0.0010
# Epoch 5/10
# 221/221 [==============================] - 22s 97ms/step - loss: 0.0627 - accuracy: 0.9764 - val_loss: 0.0647 - val_accuracy: 0.9829 - lr: 3.0000e-04
# Epoch 6/10
# 221/221 [==============================] - 22s 98ms/step - loss: 0.0522 - accuracy: 0.9829 - val_loss: 0.0779 - val_accuracy: 0.9744 - lr: 3.0000e-04
# Epoch 7/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0455 - accuracy: 0.9846
# Epoch 7: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 221/221 [==============================] - 22s 97ms/step - loss: 0.0455 - accuracy: 0.9846 - val_loss: 0.1001 - val_accuracy: 0.9607 - lr: 3.0000e-04
# Epoch 8/10
# 221/221 [==============================] - 22s 97ms/step - loss: 0.0368 - accuracy: 0.9878 - val_loss: 0.0879 - val_accuracy: 0.9658 - lr: 9.0000e-05
# Epoch 9/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0295 - accuracy: 0.9901
# Epoch 9: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 221/221 [==============================] - 22s 98ms/step - loss: 0.0295 - accuracy: 0.9901 - val_loss: 0.0951 - val_accuracy: 0.9641 - lr: 9.0000e-05
# Epoch 10/10
# 221/221 [==============================] - 22s 97ms/step - loss: 0.0267 - accuracy: 0.9901 - val_loss: 0.0815 - val_accuracy: 0.9675 - lr: 2.7000e-05
# Epoch 1/10
# 221/221 [==============================] - 20s 86ms/step - loss: 0.5291 - accuracy: 0.7587 - val_loss: 0.2197 - val_accuracy: 0.9453 - lr: 0.0010
# Epoch 2/10
# 221/221 [==============================] - 19s 85ms/step - loss: 0.1387 - accuracy: 0.9460 - val_loss: 0.1231 - val_accuracy: 0.9641 - lr: 0.0010
# Epoch 3/10
# 221/221 [==============================] - 19s 85ms/step - loss: 0.0893 - accuracy: 0.9673 - val_loss: 0.0918 - val_accuracy: 0.9658 - lr: 0.0010
# Epoch 4/10
# 221/221 [==============================] - 19s 85ms/step - loss: 0.0653 - accuracy: 0.9795 - val_loss: 0.0893 - val_accuracy: 0.9607 - lr: 0.0010
# Epoch 5/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0480 - accuracy: 0.9833
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 221/221 [==============================] - 19s 85ms/step - loss: 0.0480 - accuracy: 0.9833 - val_loss: 0.0886 - val_accuracy: 0.9658 - lr: 0.0010
# Epoch 6/10
# 221/221 [==============================] - 19s 85ms/step - loss: 0.0302 - accuracy: 0.9895 - val_loss: 0.0786 - val_accuracy: 0.9726 - lr: 3.0000e-04
# Epoch 7/10
# 221/221 [==============================] - 19s 85ms/step - loss: 0.0162 - accuracy: 0.9953 - val_loss: 0.1112 - val_accuracy: 0.9658 - lr: 3.0000e-04
# Epoch 8/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0115 - accuracy: 0.9967
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 221/221 [==============================] - 19s 85ms/step - loss: 0.0115 - accuracy: 0.9967 - val_loss: 0.0960 - val_accuracy: 0.9658 - lr: 3.0000e-04
# Epoch 9/10
# 221/221 [==============================] - 19s 85ms/step - loss: 0.0066 - accuracy: 0.9983 - val_loss: 0.0858 - val_accuracy: 0.9726 - lr: 9.0000e-05
# Epoch 10/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9992
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 221/221 [==============================] - 19s 84ms/step - loss: 0.0046 - accuracy: 0.9992 - val_loss: 0.0927 - val_accuracy: 0.9692 - lr: 9.0000e-05
# Epoch 1/10
# 221/221 [==============================] - 34s 126ms/step - loss: 0.7601 - accuracy: 0.5326 - val_loss: 0.4122 - val_accuracy: 0.7761 - lr: 0.0010
# Epoch 2/10
# 221/221 [==============================] - 22s 101ms/step - loss: 0.3339 - accuracy: 0.8544 - val_loss: 0.2617 - val_accuracy: 0.9009 - lr: 0.0010
# Epoch 3/10
# 221/221 [==============================] - 22s 101ms/step - loss: 0.1744 - accuracy: 0.9342 - val_loss: 0.1071 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 4/10
# 221/221 [==============================] - 22s 101ms/step - loss: 0.1087 - accuracy: 0.9612 - val_loss: 0.0897 - val_accuracy: 0.9726 - lr: 0.0010
# Epoch 5/10
# 221/221 [==============================] - 22s 101ms/step - loss: 0.0751 - accuracy: 0.9726 - val_loss: 0.0707 - val_accuracy: 0.9812 - lr: 0.0010
# Epoch 6/10
# 221/221 [==============================] - 22s 101ms/step - loss: 0.0635 - accuracy: 0.9758 - val_loss: 0.0666 - val_accuracy: 0.9812 - lr: 0.0010
# Epoch 7/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0467 - accuracy: 0.9840
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 221/221 [==============================] - 22s 101ms/step - loss: 0.0467 - accuracy: 0.9840 - val_loss: 0.0552 - val_accuracy: 0.9778 - lr: 0.0010
# Epoch 8/10
# 221/221 [==============================] - 22s 101ms/step - loss: 0.0221 - accuracy: 0.9911 - val_loss: 0.0574 - val_accuracy: 0.9829 - lr: 3.0000e-04
# Epoch 9/10
# 221/221 [==============================] - 22s 101ms/step - loss: 0.0150 - accuracy: 0.9949 - val_loss: 0.0449 - val_accuracy: 0.9863 - lr: 3.0000e-04
# Epoch 10/10
# 221/221 [==============================] - 22s 101ms/step - loss: 0.0106 - accuracy: 0.9967 - val_loss: 0.0513 - val_accuracy: 0.9812 - lr: 3.0000e-04
# Epoch 1/10
# 221/221 [==============================] - 36s 134ms/step - loss: 0.4425 - accuracy: 0.8252 - val_loss: 0.1269 - val_accuracy: 0.9556 - lr: 0.0010
# Epoch 2/10
# 221/221 [==============================] - 23s 106ms/step - loss: 0.1298 - accuracy: 0.9512 - val_loss: 0.0945 - val_accuracy: 0.9778 - lr: 0.0010
# Epoch 3/10
# 221/221 [==============================] - 23s 106ms/step - loss: 0.0927 - accuracy: 0.9666 - val_loss: 0.1018 - val_accuracy: 0.9641 - lr: 0.0010
# Epoch 4/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0923 - accuracy: 0.9677
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 221/221 [==============================] - 23s 105ms/step - loss: 0.0923 - accuracy: 0.9677 - val_loss: 0.0873 - val_accuracy: 0.9726 - lr: 0.0010
# Epoch 5/10
# 221/221 [==============================] - 23s 105ms/step - loss: 0.0519 - accuracy: 0.9822 - val_loss: 0.0451 - val_accuracy: 0.9863 - lr: 3.0000e-04
# Epoch 6/10
# 221/221 [==============================] - 23s 106ms/step - loss: 0.0437 - accuracy: 0.9844 - val_loss: 0.0514 - val_accuracy: 0.9880 - lr: 3.0000e-04
# Epoch 7/10
# 221/221 [==============================] - 23s 105ms/step - loss: 0.0328 - accuracy: 0.9884 - val_loss: 0.0814 - val_accuracy: 0.9761 - lr: 3.0000e-04
# Epoch 8/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0294 - accuracy: 0.9885
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 221/221 [==============================] - 23s 106ms/step - loss: 0.0294 - accuracy: 0.9885 - val_loss: 0.0593 - val_accuracy: 0.9795 - lr: 3.0000e-04
# Epoch 9/10
# 221/221 [==============================] - 23s 106ms/step - loss: 0.0171 - accuracy: 0.9948 - val_loss: 0.0601 - val_accuracy: 0.9778 - lr: 9.0000e-05
# Epoch 10/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0139 - accuracy: 0.9960
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 221/221 [==============================] - 23s 105ms/step - loss: 0.0139 - accuracy: 0.9960 - val_loss: 0.0624 - val_accuracy: 0.9778 - lr: 9.0000e-05
# Best Accuracy at the generation 10: 99.91512298583984

# %%
genCNN.smooth_curve(0.5,num_generations)

# %%
genCNN.best_arch
# Out:
# array([38, 64, 99,  4,  9, 20])

# %%
genCNN.max_acc
# Out:
# 99.91512298583984

# %%
genCNN.gen_acc
# Out:
# [99.78780746459961,
#  99.80195164680481,
#  99.77365732192993,
#  99.4200050830841,
#  99.84439015388489,
#  99.87268447875977,
#  99.87268447875977,
#  99.81609582901001,
#  99.70293045043945,
#  99.78780746459961,
#  99.91512298583984]

# %%
bestModelEachGeneration
# Out:
# [array([36, 59, 93,  4,  9, 19]),
#  array([36, 64, 96,  4,  9, 18]),
#  array([36, 64, 96,  4,  9, 18]),
#  array([36, 64, 96,  4,  9, 18]),
#  array([41, 64, 99,  4,  9, 20]),
#  array([36, 64, 96,  4,  9, 18]),
#  array([36, 64, 96,  4,  9, 18]),
#  array([36, 64, 96,  4,  9, 18]),
#  array([36, 64, 96,  4,  9, 18]),
#  array([36, 64, 96,  4,  9, 18]),
#  array([38, 64, 99,  4,  9, 20])]

# %%
# Next pop
# for gen 11
# array([[38, 47, 79,  4,  5, 13],
#        [37, 47, 77,  4,  4, 11],
#        [32, 52, 79,  4,  4, 12],
#        [32, 47, 78,  4,  4,  6],
#        [40, 51, 77,  5,  9, 11],
#        [40, 47, 77,  4,  5, 13],
#        [37, 47, 81,  7,  4, 12],
#        [32, 52, 83,  4,  4,  7],
#        [32, 47, 79,  7,  4, 11],
#        [40, 51, 82,  5,  9, 14]])

# for gen 21
pop
# Out:
# array([[38, 64, 99,  4,  9, 20],
#        [38, 64, 96,  4,  9, 16],
#        [41, 71, 96,  6, 11, 20],
#        [41, 71, 96,  6,  9, 17],
#        [45, 74, 96,  6, 14, 16],
#        [38, 66, 96,  4,  9, 19],
#        [38, 64, 91,  4,  9, 18],
#        [46, 71, 96,  7, 11, 17],
#        [41, 75, 96,  9,  9, 16],
#        [47, 74, 99,  6, 16, 20]])

# %% [markdown]
# ## Optimized Model

# %%
bestParam = genCNN.best_arch
# bestParam = [35, 64, 98,  7,  8, 17]
# array([38, 47, 79,  4,  5, 13]) Gen 1 ~ 10
# array([35, 64, 98,  7,  8, 17]) Gen 21 ~ 30
bestParam
# Out:
# array([38, 64, 99,  4,  9, 20])

# %%
model = Sequential()
model.add(Conv2D(bestParam[0] , (bestParam[3],bestParam[3]) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = (150,150,1)))
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model.add(Conv2D(bestParam[1] , (bestParam[4],bestParam[4]) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.1))
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model.add(Conv2D(bestParam[2] , (bestParam[5],bestParam[5]) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.2))
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model.add(Flatten())
model.add(Dense(units = 128 , activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(units = 1 , activation = 'sigmoid'))
model.compile(optimizer = "adam" , loss = 'binary_crossentropy' , metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_330 (Conv2D)         (None, 150, 150, 38)      646
#
#  max_pooling2d_330 (MaxPooli  (None, 75, 75, 38)       0
#  ng2D)
#
#  conv2d_331 (Conv2D)         (None, 75, 75, 64)        197056
#
#  dropout_330 (Dropout)       (None, 75, 75, 64)        0
#
#  max_pooling2d_331 (MaxPooli  (None, 38, 38, 64)       0
#  ng2D)
#
#  conv2d_332 (Conv2D)         (None, 38, 38, 99)        2534499
#
#  dropout_331 (Dropout)       (None, 38, 38, 99)        0
#
#  max_pooling2d_332 (MaxPooli  (None, 19, 19, 99)       0
#  ng2D)
#
#  flatten_110 (Flatten)       (None, 35739)             0
#
#  dense_220 (Dense)           (None, 128)               4574720
#
#  dropout_332 (Dropout)       (None, 128)               0
#
#  dense_221 (Dense)           (None, 1)                 129
#
# =================================================================
# Total params: 7,307,050
# Trainable params: 7,307,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 2, verbose=1,factor=0.3, min_lr=0.000001)

# %%
history = model.fit(x,y, batch_size = 32 ,epochs = 10 , validation_data = [x_val, y_val] ,callbacks = [learning_rate_reduction])
# Out:
# Epoch 1/10
# 221/221 [==============================] - 20s 83ms/step - loss: 0.0249 - accuracy: 0.9921 - val_loss: 0.0527 - val_accuracy: 0.9829 - lr: 2.7000e-05
# Epoch 2/10
# 221/221 [==============================] - 18s 81ms/step - loss: 0.0222 - accuracy: 0.9924 - val_loss: 0.0523 - val_accuracy: 0.9812 - lr: 2.7000e-05
# Epoch 3/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 0.9929
# Epoch 3: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 221/221 [==============================] - 18s 82ms/step - loss: 0.0213 - accuracy: 0.9929 - val_loss: 0.0577 - val_accuracy: 0.9812 - lr: 2.7000e-05
# Epoch 4/10
# 221/221 [==============================] - 18s 82ms/step - loss: 0.0193 - accuracy: 0.9939 - val_loss: 0.0551 - val_accuracy: 0.9829 - lr: 8.1000e-06
# Epoch 5/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0184 - accuracy: 0.9943
# Epoch 5: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# 221/221 [==============================] - 18s 83ms/step - loss: 0.0184 - accuracy: 0.9943 - val_loss: 0.0535 - val_accuracy: 0.9812 - lr: 8.1000e-06
# Epoch 6/10
# 221/221 [==============================] - 18s 83ms/step - loss: 0.0185 - accuracy: 0.9938 - val_loss: 0.0542 - val_accuracy: 0.9812 - lr: 2.4300e-06
# Epoch 7/10
# 221/221 [==============================] - ETA: 0s - loss: 0.0192 - accuracy: 0.9939
# Epoch 7: ReduceLROnPlateau reducing learning rate to 1e-06.
# 221/221 [==============================] - 18s 83ms/step - loss: 0.0192 - accuracy: 0.9939 - val_loss: 0.0549 - val_accuracy: 0.9812 - lr: 2.4300e-06
# Epoch 8/10
# 221/221 [==============================] - 18s 84ms/step - loss: 0.0185 - accuracy: 0.9936 - val_loss: 0.0547 - val_accuracy: 0.9812 - lr: 1.0000e-06
# Epoch 9/10
# 221/221 [==============================] - 19s 84ms/step - loss: 0.0211 - accuracy: 0.9919 - val_loss: 0.0545 - val_accuracy: 0.9812 - lr: 1.0000e-06
# Epoch 10/10
# 221/221 [==============================] - 19s 84ms/step - loss: 0.0185 - accuracy: 0.9946 - val_loss: 0.0543 - val_accuracy: 0.9812 - lr: 1.0000e-06

# %%
# Adjust the range to match the number of epochs in your history data
epochs = [i for i in range(len(history.history['accuracy']))]

fig, ax = plt.subplots(1, 2, figsize=(20, 10))

train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

ax[0].plot(epochs, train_acc, 'go-', label='Training Accuracy')
ax[0].plot(epochs, val_acc, 'ro-', label='Validation Accuracy')
ax[0].set_title('Training & Validation Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs, train_loss, 'g-o', label='Training Loss')
ax[1].plot(epochs, val_loss, 'r-o', label='Validation Loss')
ax[1].set_title('Training & Validation Loss')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Loss")

plt.show()

# %%
predictions = model.predict(x_test)
predictions = predictions.reshape(1,-1)[0]
predictions[:15]
# Out:
# 19/19 [==============================] - 0s 20ms/step
# array([1.3915561e-03, 2.1268038e-01, 5.0145981e-04, 1.2484243e-05,
#        1.2484229e-05, 3.4744923e-03, 1.5802788e-02, 3.3339190e-03,
#        2.4986262e-03, 8.0501335e-03, 6.1011733e-04, 2.1185675e-05,
#        4.5926711e-03, 2.0671270e-05, 6.3549572e-07], dtype=float32)

# %%
from sklearn.metrics import classification_report

# Assuming predictions are probabilities, convert them to binary labels
binary_predictions = [1 if i > 0.5 else 0 for i in predictions]

# Generate a classification report
print(classification_report(y_test, binary_predictions, target_names=['Pneumonia (Class 0)', 'Normal (Class 1)']))
# Out:
#                      precision    recall  f1-score   support
#
# Pneumonia (Class 0)       0.99      0.98      0.98       428
#    Normal (Class 1)       0.95      0.97      0.96       159
#
#            accuracy                           0.98       587
#           macro avg       0.97      0.98      0.97       587
#        weighted avg       0.98      0.98      0.98       587

# %%
print(classification_report(y_test, binary_predictions, target_names = ['Pneumonia (Class 0)','Normal (Class 1)']))
# Out:
#                      precision    recall  f1-score   support
#
# Pneumonia (Class 0)       0.99      0.98      0.98       428
#    Normal (Class 1)       0.95      0.97      0.96       159
#
#            accuracy                           0.98       587
#           macro avg       0.97      0.98      0.97       587
#        weighted avg       0.98      0.98      0.98       587

# %%
cm = confusion_matrix(y_test,binary_predictions)
cm
# Out:
# array([[419,   9],
#        [  4, 155]], dtype=int64)

# %%
cm = pd.DataFrame(cm , index = ['0','1'] , columns = ['0','1'])

# %%
plt.figure(figsize = (10,10))
sns.heatmap(cm,cmap= "Blues", linecolor = 'black' , linewidth = 1 , annot = True, fmt='',xticklabels = labels,yticklabels = labels)
# Out:
# <Axes: >
