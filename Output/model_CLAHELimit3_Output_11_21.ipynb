# %%
pip install numpy==1.23.3
# Out:
# Collecting numpy==1.23.3
#   Downloading numpy-1.23.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 56.0 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.2
#     Uninstalling numpy-1.25.2:
#       Successfully uninstalled numpy-1.25.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# chex 0.1.86 requires numpy>=1.24.1, but you have numpy 1.23.3 which is incompatible.
# pandas-stubs 2.0.3.230814 requires numpy>=1.25.0; python_version >= "3.9", but you have numpy 1.23.3 which is incompatible.
# tensorflow 2.15.0 requires numpy<2.0.0,>=1.23.5, but you have numpy 1.23.3 which is incompatible.
# Successfully installed numpy-1.23.3

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print(np.__version__)
# Out:
# 1.23.3

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import os

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau

# %%
print(tf.config.list_physical_devices())
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
print(tf.__version__)
# Out:
# 2.15.0

# %%
labels = ['PNEUMONIA', 'NORMAL']
img_size = 150
def get_training_data(data_dir):
    data = []
    for label in labels:
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data,dtype="object")

# %%
train = get_training_data('/content/drive/MyDrive/pneumonia_data/train_CLAHE_limit3')
test = get_training_data('/content/drive/MyDrive/pneumonia_data/test_CLAHE_limit3')
val = get_training_data('/content/drive/MyDrive/pneumonia_data/val_CLAHE_limit3')

# %%
import seaborn as sns

# %%
print(sns.__version__)
# Out:
# 0.13.1

# %%
l = []
for i in train:
    if(i[1] == 0):
        l.append("Pneumonia")
    else:
        l.append("Normal")
sns.set_style('darkgrid')
sns.countplot(l)
# Out:
# <Axes: xlabel='count'>

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[0][0], cmap='gray')
plt.title(labels[train[0][1]])

plt.figure(figsize = (5,5))
plt.imshow(train[-1][0], cmap='gray')
plt.title(labels[train[-1][1]])
# Out:
# Text(0.5, 1.0, 'NORMAL')

# %%
x_train = []
y_train = []

x_val = []
y_val = []

x_test = []
y_test = []

for feature, label in train:
    x_train.append(feature)
    y_train.append(label)

for feature, label in test:
    x_test.append(feature)
    y_test.append(label)

for feature, label in val:
    x_val.append(feature)
    y_val.append(label)

# %%
# Normalize the data
x_train = np.array(x_train) / 255
x_val = np.array(x_val) / 255
x_test = np.array(x_test) / 255

# %%
# resize data for deep learning
x_train = x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)

x_val = x_val.reshape(-1, img_size, img_size, 1)
y_val = np.array(y_val)

x_test = x_test.reshape(-1, img_size, img_size, 1)
y_test = np.array(y_test)

# %%
print("Count before augmentation:", len(x_train))
# Out:
# Count before augmentation: 4684

# %%
def load_augmented_data(augmented_dir, label, img_size):
    augmented_data = []
    for img in os.listdir(augmented_dir):
        try:
            img_arr = cv2.imread(os.path.join(augmented_dir, img), cv2.IMREAD_GRAYSCALE)
            resized_arr = cv2.resize(img_arr, (img_size, img_size))
            augmented_data.append([resized_arr, label])
        except Exception as e:
            print(e)
    return np.array(augmented_data)

# Define parameters
# Define parameters
save_dir = '/content/drive/MyDrive/pneumonia_data/augmented_CLAHE_limit3/NORMAL'  # Directory to save augmented images
label = 'NORMAL'  # Class label to augment
img_size = 150  # Image size (adjust if different)
additional_images_needed = 2690  # Number of additional images needed
batch_size = 32  # Number of images to generate per original image

# Load augmented 'Normal' images (assuming label for 'Normal' is 1)
augmented_normal_data = load_augmented_data(save_dir, label=1, img_size=img_size)

# Convert to appropriate format and normalize
x_augmented_normal = np.array([i[0] for i in augmented_normal_data]) / 255
x_augmented_normal = x_augmented_normal.reshape(-1, img_size, img_size, 1)
y_augmented_normal = np.array([i[1] for i in augmented_normal_data])

# Append to existing training data
x_train = np.concatenate((x_train, x_augmented_normal), axis=0)
y_train = np.concatenate((y_train, y_augmented_normal), axis=0)

# Shuffle the dataset
indices = np.arange(x_train.shape[0])
np.random.shuffle(indices)
x_train = x_train[indices]
y_train = y_train[indices]

# Count after augmentation
print("Count after augmentation:", len(x_train))
# Out:
# <ipython-input-17-83f794ec0b6f>:10: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(augmented_data)
# Count after augmentation: 7069

# %% [markdown]
# # Optimized Optimization

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

class CNN(Sequential):
    def __init__(self, nfilters, sfilters):
        super().__init__()
        tf.random.set_seed(0)
        self.add(Conv2D(nfilters[0], kernel_size=(sfilters[0], sfilters[0]), padding='same', activation='relu', input_shape=(150, 150, 1)))
        self.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

        self.add(Conv2D(nfilters[1], kernel_size=(sfilters[1], sfilters[1]), padding='same', activation='relu'))
        self.add(Dropout(0.1))
        self.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

        self.add(Conv2D(nfilters[2], kernel_size=(sfilters[2], sfilters[2]), padding='same', activation='relu'))
        self.add(Dropout(0.2))
        self.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

        self.add(Flatten())
        self.add(Dropout(0.2))
        self.add(Dense(128, activation='relu'))
        self.add(Dense(units=1, activation='sigmoid'))
        self.compile(optimizer="adam", loss='binary_crossentropy', metrics=['accuracy'])

# %%
class Genetic:
    def __init__(self, pop_size, nlayers, max_nfilters, max_sfilters):
        self.pop_size = pop_size
        self.nlayers = nlayers
        self.max_nfilters = max_nfilters
        self.max_sfilters = max_sfilters
        self.max_acc = 0
        self.best_arch = np.zeros((1, 6))
        self.gen_acc = []


    # def generate_population(self):
    #     np.random.seed(0)

    #     # Membuat partisi untuk nfilter
    #     partition_size_nfilter = self.max_nfilters // self.pop_size
    #     pop_nlayers = np.array([
    #         np.random.randint(1 + i * partition_size_nfilter, (i + 1) * partition_size_nfilter, self.nlayers)
    #         for i in range(self.pop_size)
    #     ])

    #     # Membuat partisi untuk sfilter
    #     partition_size_sfilter = self.max_sfilters // self.pop_size
    #     pop_sfilters = np.array([
    #         np.random.randint(1 + i * partition_size_sfilter, (i + 1) * partition_size_sfilter, self.nlayers)
    #         for i in range(self.pop_size)
    #     ])

    #     # Menggabungkan kedua set parameter
    #     pop_total = np.concatenate((pop_nlayers, pop_sfilters), axis=1)
    #     return pop_total

    def generate_unique_values(self, max_value, taken_values):
        partition_size = max_value // self.nlayers
        unique_values = []
        for j in range(self.nlayers):
            start = j * partition_size + 1
            if j == self.nlayers - 1:  # Ensure the last partition reaches the max value
                end = max_value + 1
            else:
                end = start + partition_size

            # Generate a unique value within the partition
            value = np.random.randint(start, end)
            while value in taken_values:  # Ensure uniqueness
                value += 1
                if value >= end:  # Reset if exceeds partition
                    value = start

            taken_values.add(value)
            unique_values.append(value)

        return unique_values

    def generate_population(self):
        np.random.seed(0)

        # Initialize population array
        pop_total = np.zeros((self.pop_size, self.nlayers * 2), dtype=int)

        for i in range(self.pop_size):
            taken_values_nfilters = set()
            taken_values_sfilters = set()

            # Generate unique nfilters and sfilters for each individual
            nfilters = self.generate_unique_values(self.max_nfilters, taken_values_nfilters)
            sfilters = self.generate_unique_values(self.max_sfilters, taken_values_sfilters)

            # Combine nfilters and sfilters for the individual
            pop_total[i] = nfilters + sfilters

        return pop_total


    def select_parents(self, pop, nparents, fitness):
        parents = np.zeros((nparents, pop.shape[1]))
        for i in range(nparents):
            best = np.argmax(fitness)
            parents[i] = pop[best]
            fitness[best] = -99999
        return parents

    def crossover(self, parents):
        nchild = self.pop_size - parents.shape[0]
        nparents = parents.shape[0]
        child = np.zeros((nchild, parents.shape[1]))
        for i in range(nchild):
            first = i % nparents
            second = (i + 1) % nparents
            child[i, :2] = parents[first][:2]
            child[i, 2] = parents[second][2]
            child[i, 3:5] = parents[first][3:5]
            child[i, 5] = parents[second][5]
        return child

    def mutation(self, child):
        for i in range(child.shape[0]):
            val = np.random.randint(1, 6)
            ind = np.random.randint(1, 4) - 1
            if child[i][ind] + val > 100:
                child[i][ind] -= val
            else:
                child[i][ind] += val
            val = np.random.randint(1, 4)
            ind = np.random.randint(4, 7) - 1
            if child[i][ind] + val > 20:
                child[i][ind] -= val
            else:
                child[i][ind] += val
        return child

    def fitness(self, pop, X, Y, epochs):
        pop_acc = []
        for i in range(pop.shape[0]):
            nfilters = pop[i][0:3]
            sfilters = pop[i][3:]
            model = CNN(nfilters, sfilters)
            learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=2, verbose=1, factor=0.3, min_lr=0.000001)
            history = model.fit(X, Y, batch_size=64, epochs=epochs, validation_data=[x_val, y_val], callbacks=[learning_rate_reduction])
            acc = max(history.history['accuracy'])
            pop_acc.append(acc * 100)
        if max(pop_acc) > self.max_acc:
            self.max_acc = max(pop_acc)
            self.best_arch = pop[np.argmax(pop_acc)]
        self.gen_acc.append(max(pop_acc))
        return pop_acc

    def smooth_curve(self, factor, gen):
        smoothed_points = []
        for point in self.gen_acc:
            if smoothed_points:
                prev = smoothed_points[-1]
                smoothed_points.append(prev * factor + point * (1 - factor))
            else:
                smoothed_points.append(point)
        plt.plot(range(gen + 1), smoothed_points, 'g', label='Smoothed training acc')
        plt.xticks(np.arange(gen + 1))
        plt.legend()
        plt.title('Fitness Accuracy vs Generations')
        plt.xlabel('Generations')
        plt.ylabel('Fitness (%)')
        plt.show()

# %%
pop_size = 10
nlayers = 3
max_nfilters = 100
max_sfilters = 10
epochs = 10
num_generations = 10

genCNN = Genetic(pop_size, nlayers, max_nfilters, max_sfilters)
# pop = genCNN.generate_population()
pop = np.array([[35, 45, 94,  6,  5, 14],
                [35, 45, 86,  5,  4, 11],
                [35, 45, 96,  5,  5, 14],
                [41, 45, 91,  5,  4, 17],
                [38, 50, 93,  6,  8, 17],
                [35, 45, 91,  9,  5, 11],
                [35, 45, 98,  8,  4, 14],
                [35, 45, 95,  5,  6, 17],
                [43, 45, 93,  5,  5, 17],
                [43, 50, 94,  7,  8, 14]])

# pop = np.array(result_pop)

pop
# Out:
# array([[17, 51, 90,  5,  8, 10],
#        [18, 46, 92,  7,  7, 12],
#        [22, 46, 86,  5,  7, 11],
#        [31, 45, 86,  5,  4, 11],
#        [29, 45, 91,  4,  4, 12],
#        [19, 51, 92,  5,  9, 12],
#        [19, 46, 86,  7,  9, 11],
#        [22, 51, 86,  5,  9, 11],
#        [34, 45, 91,  7,  4, 12],
#        [29, 45, 93,  6,  4, 10]])

# %%
with tf.device('/cpu:0'):
   x = tf.convert_to_tensor(x_train, np.float32)
   y = tf.convert_to_tensor(y_train, np.float32)

with tf.device('/cpu:0'):
   x_t = tf.convert_to_tensor(x_test, np.float32)
   y_t = tf.convert_to_tensor(y_test, np.float32)

bestModelEachGeneration = []

True_Positive = []
True_Negative = []
False_Positive = []
False_negative = []
acc = []
error = []
precision = []
recall = []
TP_rate = []
FP_rate = []
specificity = []
wrong_prediction = []
F1 = []

for i in range(num_generations + 1):
    print(pop)
    pop_acc = genCNN.fitness(pop, x, y, epochs)
    print('Best Accuracy at the generation {}: {}'.format(i, genCNN.max_acc))
    parents = genCNN.select_parents(pop, 5, pop_acc.copy())
    child = genCNN.crossover(parents)
    child = genCNN.mutation(child)
    pop = np.concatenate((parents, child), axis=0).astype('int')
    bestModelEachGeneration.append(genCNN.best_arch)

    model = Sequential([
            Conv2D(genCNN.best_arch[0], (genCNN.best_arch[3], genCNN.best_arch[3]), strides=1, padding='same', activation='relu', input_shape=(150, 150, 1)),
            MaxPool2D((2, 2), strides=2, padding='same'),
            Conv2D(genCNN.best_arch[1], (genCNN.best_arch[4], genCNN.best_arch[4]), strides=1, padding='same', activation='relu'),
            Dropout(0.1),
            MaxPool2D((2, 2), strides=2, padding='same'),
            Conv2D(genCNN.best_arch[2], (genCNN.best_arch[5], genCNN.best_arch[5]), strides=1, padding='same', activation='relu'),
            Dropout(0.2),
            MaxPool2D((2, 2), strides=2, padding='same'),
            Flatten(),
            Dense(128, activation='relu'),
            Dropout(0.2),
            Dense(1, activation='sigmoid')
         ])
    model.compile(optimizer="adam", loss='binary_crossentropy', metrics=['accuracy'])
    model.summary()
    learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=2, verbose=1, factor=0.3, min_lr=0.000001)
    model.fit(x, y, batch_size=64, epochs=10, validation_data=(x_val, y_val), callbacks=[learning_rate_reduction])
    predictions = model.predict(x_t)
    predictions = predictions.reshape(1,-1)[0]
    predictions[:15]
    # Predictions are probabilities, convert them to binary labels
    binary_predictions = [1 if i > 0.5 else 0 for i in predictions]
    cm = confusion_matrix(y_t,binary_predictions)
    TP = cm[0][0]  # True Positives
    TN = cm[1][1]  # True Negatives
    FP = cm[0][1]  # False Positives
    FN = cm[1][0]  # False Negatives
    classification_accuracy = (TP + TN) / float(TP + TN + FP + FN)
    classification_error = (FP + FN) / float(TP + TN + FP + FN)
    precision_calc = TP / float(TP + FP)
    recall_calc = TP / float(TP + FN)
    true_positive_rate = TP / float(TP + FN)
    false_positive_rate = FP / float(FP + TN)
    specificity_calc = TN / (TN + FP)
    F1_score = 2 * (precision_calc * recall_calc) / (precision_calc + recall_calc)
    wrong_calc = FN + FP

    True_Positive.append(TP)
    True_Negative.append(TN)
    False_Positive.append(FP)
    False_negative.append(FN)
    acc.append(classification_accuracy)
    error.append(classification_error)
    precision.append(precision_calc)
    recall.append(recall_calc)
    TP_rate.append(true_positive_rate)
    FP_rate.append(false_positive_rate)
    specificity.append(specificity_calc)
    F1.append(F1_score)
    wrong_prediction.append(wrong_calc)

    df = {
    'TP': True_Positive,
    'TN': True_Negative,
    'FP': False_Positive,
    'FN': False_negative,
    'acc': acc,
    'error': error,
    'precision': precision,
    'recall': recall,
    'TP_rate': TP_rate,
    'FP_rate': FP_rate,
    'specificity': specificity,
    'F1_score': F1,
    'wrong_prediction' : wrong_prediction
    }

    df = pd.DataFrame(df)
    df.to_csv('CLAHE_metrics_limit3.csv', index=False)
# Out:
# [[17 51 90  5  8 10]
#  [18 46 92  7  7 12]
#  [22 46 86  5  7 11]
#  [31 45 86  5  4 11]
#  [29 45 91  4  4 12]
#  [19 51 92  5  9 12]
#  [19 46 86  7  9 11]
#  [22 51 86  5  9 11]
#  [34 45 91  7  4 12]
#  [29 45 93  6  4 10]]
# Epoch 1/10
# 111/111 [==============================] - 17s 60ms/step - loss: 0.3644 - accuracy: 0.8138 - val_loss: 0.1787 - val_accuracy: 0.9333 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 4s 40ms/step - loss: 0.1492 - accuracy: 0.9450 - val_loss: 0.1497 - val_accuracy: 0.9470 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 4s 40ms/step - loss: 0.1164 - accuracy: 0.9595 - val_loss: 0.1678 - val_accuracy: 0.9350 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 4s 40ms/step - loss: 0.1027 - accuracy: 0.9646 - val_loss: 0.1139 - val_accuracy: 0.9556 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 4s 40ms/step - loss: 0.0910 - accuracy: 0.9687 - val_loss: 0.1685 - val_accuracy: 0.9419 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0834 - accuracy: 0.9714
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 4s 40ms/step - loss: 0.0834 - accuracy: 0.9714 - val_loss: 0.1424 - val_accuracy: 0.9521 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 4s 40ms/step - loss: 0.0631 - accuracy: 0.9775 - val_loss: 0.0829 - val_accuracy: 0.9658 - lr: 3.0000e-04
# Epoch 8/10
# 111/111 [==============================] - 4s 40ms/step - loss: 0.0537 - accuracy: 0.9816 - val_loss: 0.0797 - val_accuracy: 0.9675 - lr: 3.0000e-04
# Epoch 9/10
# 111/111 [==============================] - 4s 40ms/step - loss: 0.0477 - accuracy: 0.9851 - val_loss: 0.0827 - val_accuracy: 0.9726 - lr: 3.0000e-04
# Epoch 10/10
# 111/111 [==============================] - 4s 40ms/step - loss: 0.0489 - accuracy: 0.9818 - val_loss: 0.0736 - val_accuracy: 0.9761 - lr: 3.0000e-04
# Epoch 1/10
# 111/111 [==============================] - 13s 59ms/step - loss: 0.5159 - accuracy: 0.8239 - val_loss: 0.2016 - val_accuracy: 0.9265 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 4s 39ms/step - loss: 0.1627 - accuracy: 0.9396 - val_loss: 0.1639 - val_accuracy: 0.9350 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 4s 39ms/step - loss: 0.1233 - accuracy: 0.9577 - val_loss: 0.1371 - val_accuracy: 0.9504 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 4s 39ms/step - loss: 0
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_30 (Conv2D)          (None, 150, 150, 29)      1073
#
#  max_pooling2d_30 (MaxPooli  (None, 75, 75, 29)        0
#  ng2D)
#
#  conv2d_31 (Conv2D)          (None, 75, 75, 45)        20925
#
#  dropout_30 (Dropout)        (None, 75, 75, 45)        0
#
#  max_pooling2d_31 (MaxPooli  (None, 38, 38, 45)        0
#  ng2D)
#
#  conv2d_32 (Conv2D)          (None, 38, 38, 93)        418593
#
#  dropout_31 (Dropout)        (None, 38, 38, 93)        0
#
#  max_pooling2d_32 (MaxPooli  (None, 19, 19, 93)        0
#  ng2D)
#
#  flatten_10 (Flatten)        (None, 33573)             0
#
#  dense_20 (Dense)            (None, 128)               4297472
#
#  dropout_32 (Dropout)        (None, 128)               0
#
#  dense_21 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 4738192 (18.07 MB)
# Trainable params: 4738192 (18.07 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 111/111 [==============================] - 8s 50ms/step - loss: 0.3814 - accuracy: 0.8160 - val_loss: 0.1689 - val_accuracy: 0.9265 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 5s 42ms/step - loss: 0.1207 - accuracy: 0.9570 - val_loss: 0.1203 - val_accuracy: 0.9573 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 5s 43ms/step - loss: 0.0916 - accuracy: 0.9677 - val_loss: 0.1043 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 5s 42ms/step - loss: 0.0805 - accuracy: 0.9728 - val_loss: 0.1046 - val_accuracy: 0.9487 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 5s 43ms/step - loss: 0.0647 - accuracy: 0.9762 - val_loss: 0.0804 - val_accuracy: 0.9795 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 5s 43ms/step - loss: 0.0522 - accuracy: 0.9815 - val_loss: 0.1007 - val_accuracy: 0.9624 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0437 - accuracy: 0.9825
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 5s 43ms/step - loss: 0.0437 - accuracy: 0.9825 - val_loss: 0.0735 - val_accuracy: 0.9761 - lr: 0.0010
# Epoch 8/10
# 111/111 [==============================] - 5s 43ms/step - loss: 0.0237 - accuracy: 0.9909 - val_loss: 0.0601 - val_accuracy: 0.9795 - lr: 3.0000e-04
# Epoch 9/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0191 - accuracy: 0.9935
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 111/111 [==============================] - 5s 42ms/step - loss: 0.0191 - accuracy: 0.9935 - val_loss: 0.0636 - val_accuracy: 0.9761 - lr: 3.0000e-04
# Epoch 10/10
# 111/111 [==============================] - 5s 43ms/step - loss: 0.0138 - accuracy: 0.9958 - val_loss: 0.0621 - val_accuracy: 0.9795 - lr: 9.0000e-05
# 19/19 [==============================] - 1s 11ms/step
# [[29 45 93  6  4 10]
#  [29 45 91  4  4 12]
#  [31 45 86  5  4 11]
#  [34 45 91  7  4 12]
#  [19 46 86  7  9 11]
#  [29 45 93  6  4 13]
#  [29 45 87  4  4 14]
#  [36 45 91  5  4 14]
#  [34 47 86  7  7 11]
#  [24 46 93  8  9 10]]
# Epoch 1/10
# 111/111 [==============================] - 6s 44ms/step - loss: 0.3955 - accuracy: 0.8421 - val_loss: 0.1780 - val_accuracy: 0.9368 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 5s 42ms/step - loss: 0.1439 - accuracy: 0.9470 - val_loss: 0.1449 - val_accuracy: 0.9453 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 5s 42ms/step - loss: 0.1125 - accuracy: 0.9615 - val_loss: 0.1503 - val_accuracy: 0.9436 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 5s 42ms/step - loss: 0.0995 - accuracy: 0.9659 - val_loss: 0.1046 - val_accuracy: 0.9692 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 5s 42ms/step - loss: 0.0939 - accuracy: 0.9672 - val_loss: 0.1561 - val_accuracy: 0.9368 - lr: 0.0010
# Epoch 6/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0762 - accuracy: 0.9729
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 5s 42ms/step - loss: 0.0760 - accuracy: 0.9728 - val_loss: 0.1207 - val_accuracy: 0.9402 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 5s 42ms/step - loss: 0.0572 - accuracy: 0.9809 - val_loss: 0.0820 - val_accuracy: 0.9692 - lr: 3.0000e-04
# Epoch 8/10
# 111/111 [==============================] - 5s 42ms/step - loss: 0.0500 - accuracy: 0.9819 - val_loss: 0.0658 - val_accuracy: 0.9761 - lr: 3.0000e-04
# Epoch 9/10
# 111/111 [==============================] - 5s 42ms/step - loss: 0.0412 - accuracy: 0.9849 - val_loss: 0.0738 - val_accuracy: 0.9658 - lr: 3.0000e-04
# Epoch 10/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0412 - accuracy: 0.9850
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 111/111 [==============================] - 5s 42ms/step - loss: 0.0412 - accuracy: 0.9850 - val_loss: 0.0586 - val_accuracy: 0.9761 - lr: 3.0000e-04
# Epoch 1/10
# 111/111 [==============================] - 7s 45ms/step - loss: 0.3799 - accuracy: 0.8348 - val_loss: 0.1543 - val_accuracy: 0.9350 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 5s 43ms/step - loss: 0.1162 - accuracy: 0.9591 - val_loss: 0.1103 - val_accuracy: 0.9590 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 5s 43ms/step - loss: 0.0898 - accuracy: 0.9702 - val_loss: 0.1086 - val_accuracy: 0.9590 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 5s 43ms/step - loss: 0.0812 - accuracy: 0.9733 - val_loss: 0.1058 - val_accuracy: 0.9658 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 5s 43ms/step - loss: 0.0773 - accuracy: 0.9737 - val_loss: 0.0862 - val_accuracy: 0.9829 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 5s 43ms/step - loss: 0.0548 - accuracy: 0.9820 - val_loss: 0.1166 - val_accuracy: 0.9436 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0442 - accuracy: 0.9836
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 5s 43ms/step - loss: 0.0442 - accuracy: 0.9836 - val_loss: 0.0834 - val_accuracy: 0.9607 - lr: 0.0010
# Epoch 8/10
# 111/111 [==============================] - 5s 43ms/step - loss: 0.0236 - accuracy: 0.9925 - val_loss: 0.0668 - val_accuracy: 0.9692 - lr: 3.0000e-04
# Epoch 9/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0189 - accuracy: 0.9932
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 111/111 [==============================] - 5s 43ms/step - loss: 0.0189 - accuracy: 0.9932 - val_loss: 0.0520 - val_accuracy: 0.9812 - lr: 3.0000e-04
# Epoch 10/10
# 111/111 [==============================] - 5s 43ms/step - loss: 0.0151 - accuracy: 0.9952 - val_loss: 0.0591 - val_accuracy: 0.9744 - lr: 9.0000e-05
# Epoch 1/10
# 111/111 [==============================] - 7s 45ms/step - loss: 0.3016 - accuracy: 0.8653 - val_loss: 0.1796 - val_accuracy: 0.9265 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 5s 43ms/step - loss: 0.1263 - accuracy: 0.9566 - val_loss: 0.0986 - val_accuracy: 0.9709 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 5s 42ms/step - loss: 0.1025 - accuracy: 0.9635 - val_loss: 0.1579 - val_accuracy: 0.9385 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 5s 42ms/step - loss: 0.0963 - accuracy: 0.9669 - val_loss: 0.0856 - val_accuracy: 0.9778 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 5s 42ms/step - loss: 0.0842 - accuracy: 0.9693 - val_loss: 0.1254 - val_accuracy: 0.9538 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - ETA: 0s - loss: 0.
- val_accuracy: 0.9709 - lr: 3.0000e-04
# Epoch 10/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0489 - accuracy: 0.9820
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 111/111 [==============================] - 5s 44ms/step - loss: 0.0489 - accuracy: 0.9820 - val_loss: 0.0725 - val_accuracy: 0.9726 - lr: 3.0000e-04
# Epoch 1/10
# 111/111 [==============================] - 14s 68ms/step - loss: 0.4227 - accuracy: 0.8390 - val_loss: 0.1777 - val_accuracy: 0.9419 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 5s 48ms/step - loss: 0.1238 - accuracy: 0.9550 - val_loss: 0.1413 - val_accuracy: 0.9436 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 5s 48ms/step - loss: 0.1060 - accuracy: 0.9622 - val_loss: 0.1387 - val_accuracy: 0.9419 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 5s 48ms/step - loss: 0.0945 - accuracy: 0.9648 - val_loss: 0.0978 - val_accuracy: 0.9624 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 5s 48ms/step - loss: 0.0764 - accuracy: 0.9744 - val_loss: 0.1217 - val_accuracy: 0.9504 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0683 - accuracy: 0.9741
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 5s 48ms/step - loss: 0.0683 - accuracy: 0.9741 - val_loss: 0.1376 - val_accuracy: 0.9402 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 5s 48ms/step - loss: 0.0463 - accuracy: 0.9827 - val_loss: 0.0752 - val_accuracy: 0.9692 - lr: 3.0000e-04
# Epoch 8/10
# 111/111 [==============================] - 5s 48ms/step - loss: 0.0385 - accuracy: 0.9863 - val_loss: 0.0646 - val_accuracy: 0.9744 - lr: 3.0000e-04
# Epoch 9/10
# 111/111 [==============================] - 5s 48ms/step - loss: 0.0326 - accuracy: 0.9884 - val_loss: 0.0674 - val_accuracy: 0.9778 - lr: 3.0000e-04
# Epoch 10/10
# 111/111 [==============================] - 5s 48ms/step - loss: 0.0314 - accuracy: 0.9885 - val_loss: 0.0606 - val_accuracy: 0.9761 - lr: 3.0000e-04
# Epoch 1/10
# 111/111 [==============================] - 17s 73ms/step - loss: 0.3197 - accuracy: 0.8551 - val_loss: 0.1710 - val_accuracy: 0.9368 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 5s 48ms/step - loss: 0.1356 - accuracy: 0.9518 - val_loss: 0.1481 - val_accuracy: 0.9453 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 5s 48ms/step - loss: 0.1029 - accuracy: 0.9632 - val_loss: 0.1330 - val_accuracy: 0.9470 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 5s 47ms/step - loss: 0.0977 - accuracy: 0.9658 - val_loss: 0.0873 - val_accuracy: 0.9658 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 5s 47ms/step - loss: 0.0796 - accuracy: 0.9718 - val_loss: 0.1265 - val_accuracy: 0.9487 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0658 - accuracy: 0.9765
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 5s 47ms/step - loss: 0.0658 - accuracy: 0.9765 - val_loss: 0.1814 - val_accuracy: 0.9162 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 5s 47ms/step - loss: 0.0515 - accuracy: 0.9818 - val_loss: 0.0751 - val_accuracy: 0.9726 - lr: 3.0000e-04
# Epoch 8/10
# 111/111 [==============================] - 5s 47ms/step - loss: 0.0397 - accuracy: 0.9859 - val_loss: 0.0549 - val_accuracy: 0.9829 - lr: 3.0000e-04
# Epoch 9/10
# 111/111 [==============================] - 5s 47ms/step - loss: 0.0364 - accuracy: 0.9877 - val_loss: 0.0680 - val_accuracy: 0.9812 - lr: 3.0000e-04
# Epoch 10/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0327 - accuracy: 0.9871
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 111/111 [==============================] - 5s 47ms/step - loss: 0.0327 - accuracy: 0.9871 - val_loss: 0.0611 - val_accuracy: 0.9761 - lr: 3.0000e-04
# Epoch 1/10
# 111/111 [==============================] - 17s 71ms/step - loss: 0.3138 - accuracy: 0.8633 - val_loss: 0.1641 - val_accuracy: 0.9368 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 5s 44ms/step - loss: 0.1355 - accuracy: 0.9489 - val_loss: 0.1957 - val_accuracy: 0.9299 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 5s 44ms/step - loss: 0.1091 - accuracy: 0.9645 - val_loss: 0.1328 - val_accuracy: 0.9538 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 5s 44ms/step - loss: 0.0980 - accuracy: 0.9646 - val_loss: 0.1277 - val_accuracy: 0.9607 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 5s 44ms/step - loss: 0.0885 - accuracy: 0.9683 - val_loss: 0.1254 - val_accuracy: 0.9521 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0755 - accuracy: 0.9733
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 5s 44ms/step - loss: 0.0755 - accuracy: 0.9733 - val_loss: 0.1303 - val_accuracy: 0.9504 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 5s 44ms/step - loss: 0.0576 - accuracy: 0.9778 - val_loss: 0.0825 - val_accuracy: 0.9658 - lr: 3.0000e-04
# Epoch 8/10
# 111/111 [==============================] - 5s 44ms/step - loss: 0.0466 - accuracy: 0.9829 - val_loss: 0.0675 - val_accuracy: 0.9726 - lr: 3.0000e-04
# Epoch 9/10
# 111/111 [==============================] - 5s 44ms/step - loss: 0.0450 - accuracy: 0.9840 - val_loss: 0.0736 - val_accuracy: 0.9726 - lr: 3.0000e-04
# Epoch 10/10
# 111/111 [==============================] - 5s 44ms/step - loss: 0.0412 - accuracy: 0.9844 - val_loss: 0.0588 - val_accuracy: 0.9778 - lr: 3.0000e-04
# Best Accuracy at the generation 1: 99.51902627944946
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_63 (Conv2D)          (None, 150, 150, 29)      493
#
#  max_pooling2d_63 (MaxPooli  (None, 75, 75, 29)        0
#  ng2D)
#
#  conv2d_64 (Conv2D)          (None, 75, 75, 45)        20925
#
#  dropout_63 (Dropout)        (None, 75, 75, 45)        0
#
#  max_pooling2d_64 (MaxPooli  (None, 38, 38, 45)        0
#  ng2D)
#
#  conv2d_65 (Conv2D)          (None, 38, 38, 91)        589771
#
#  dropout_64 (Dropout)        (None, 38, 38, 91)        0
#
#  max_pooling2d_65 (MaxPooli  (None, 19, 19, 91)        0
#  ng2D)
#
#  flatten_21 (Flatten)        (None, 32851)             0
#
#  dense_42 (Dense)            (None, 128)               4205056
#
#  dropout_65 (Dropout)        (None, 128)               0
#
#  dense_43 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 4816374 (18.37 MB)
# Trainable params: 4816374 (18.37 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 111/111 [==============================] - 9s 54ms/step - loss: 0.3709 - accuracy: 0.8318 - val_loss: 0.1611 - val_accuracy: 0.9402 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 5s 43ms/step - loss: 0.1297 - accuracy: 0.9532 - val_loss: 0.1267 - val_accuracy: 0.9504 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 5s 44ms/step - loss: 0.
- val_accuracy: 0.9487 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 7s 67ms/step - loss: 0.1122 - accuracy: 0.9588 - val_loss: 0.1141 - val_accuracy: 0.9624 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 7s 67ms/step - loss: 0.0982 - accuracy: 0.9679 - val_loss: 0.0975 - val_accuracy: 0.9709 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 7s 67ms/step - loss: 0.0916 - accuracy: 0.9659 - val_loss: 0.1462 - val_accuracy: 0.9436 - lr: 0.0010
# Epoch 6/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0710 - accuracy: 0.9736
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 7s 67ms/step - loss: 0.0707 - accuracy: 0.9737 - val_loss: 0.1336 - val_accuracy: 0.9419 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 7s 67ms/step - loss: 0.0526 - accuracy: 0.9813 - val_loss: 0.0687 - val_accuracy: 0.9761 - lr: 3.0000e-04
# Epoch 8/10
# 111/111 [==============================] - 7s 67ms/step - loss: 0.0455 - accuracy: 0.9842 - val_loss: 0.0741 - val_accuracy: 0.9761 - lr: 3.0000e-04
# Epoch 9/10
# 111/111 [==============================] - 7s 67ms/step - loss: 0.0426 - accuracy: 0.9856 - val_loss: 0.0613 - val_accuracy: 0.9812 - lr: 3.0000e-04
# Epoch 10/10
# 111/111 [==============================] - 7s 67ms/step - loss: 0.0400 - accuracy: 0.9859 - val_loss: 0.0634 - val_accuracy: 0.9812 - lr: 3.0000e-04
# Best Accuracy at the generation 10: 99.56146478652954
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_360 (Conv2D)         (None, 150, 150, 35)      1295
#
#  max_pooling2d_360 (MaxPool  (None, 75, 75, 35)        0
#  ing2D)
#
#  conv2d_361 (Conv2D)         (None, 75, 75, 45)        39420
#
#  dropout_360 (Dropout)       (None, 75, 75, 45)        0
#
#  max_pooling2d_361 (MaxPool  (None, 38, 38, 45)        0
#  ing2D)
#
#  conv2d_362 (Conv2D)         (None, 38, 38, 94)        829174
#
#  dropout_361 (Dropout)       (None, 38, 38, 94)        0
#
#  max_pooling2d_362 (MaxPool  (None, 19, 19, 94)        0
#  ing2D)
#
#  flatten_120 (Flatten)       (None, 33934)             0
#
#  dense_240 (Dense)           (None, 128)               4343680
#
#  dropout_362 (Dropout)       (None, 128)               0
#
#  dense_241 (Dense)           (None, 1)                 129
#
# =================================================================
# Total params: 5213698 (19.89 MB)
# Trainable params: 5213698 (19.89 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 111/111 [==============================] - 11s 65ms/step - loss: 0.3757 - accuracy: 0.8136 - val_loss: 0.1630 - val_accuracy: 0.9368 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 6s 52ms/step - loss: 0.1342 - accuracy: 0.9484 - val_loss: 0.1144 - val_accuracy: 0.9487 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 6s 52ms/step - loss: 0.0984 - accuracy: 0.9662 - val_loss: 0.1188 - val_accuracy: 0.9556 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 6s 52ms/step - loss: 0.0879 - accuracy: 0.9699 - val_loss: 0.0909 - val_accuracy: 0.9709 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 6s 52ms/step - loss: 0.0741 - accuracy: 0.9735 - val_loss: 0.0929 - val_accuracy: 0.9658 - lr: 0.0010
# Epoch 6/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0668 - accuracy: 0.9754
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 6s 52ms/step - loss: 0.0668 - accuracy: 0.9754 - val_loss: 0.1326 - val_accuracy: 0.9368 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 6s 52ms/step - loss: 0.0464 - accuracy: 0.9833 - val_loss: 0.0613 - val_accuracy: 0.9795 - lr: 3.0000e-04
# Epoch 8/10
# 111/111 [==============================] - 6s 52ms/step - loss: 0.0335 - accuracy: 0.9880 - val_loss: 0.0511 - val_accuracy: 0.9846 - lr: 3.0000e-04
# Epoch 9/10
# 111/111 [==============================] - 6s 52ms/step - loss: 0.0287 - accuracy: 0.9892 - val_loss: 0.0547 - val_accuracy: 0.9829 - lr: 3.0000e-04
# Epoch 10/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0272 - accuracy: 0.9896
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 111/111 [==============================] - 6s 52ms/step - loss: 0.0271 - accuracy: 0.9897 - val_loss: 0.0435 - val_accuracy: 0.9846 - lr: 3.0000e-04
# 19/19 [==============================] - 1s 15ms/step

# %%
genCNN.smooth_curve(0.5,num_generations)

# %%
genCNN.best_arch
# Out:
# array([35, 45, 94,  6,  5, 14])

# %%
genCNN.max_acc
# Out:
# 99.56146478652954

# %%
genCNN.gen_acc
# Out:
# [99.264395236969,
#  99.51902627944946,
#  99.264395236969,
#  99.49073195457458,
#  99.46244359016418,
#  99.32097792625427,
#  99.15122389793396,
#  99.34927225112915,
#  99.25024509429932,
#  99.4482934474945,
#  99.56146478652954]

# %%
bestModelEachGeneration
# Out:
# [array([29, 45, 93,  6,  4, 10]),
#  array([29, 45, 91,  4,  4, 12]),
#  array([29, 45, 91,  4,  4, 12]),
#  array([29, 45, 91,  4,  4, 12]),
#  array([29, 45, 91,  4,  4, 12]),
#  array([29, 45, 91,  4,  4, 12]),
#  array([29, 45, 91,  4,  4, 12]),
#  array([29, 45, 91,  4,  4, 12]),
#  array([29, 45, 91,  4,  4, 12]),
#  array([29, 45, 91,  4,  4, 12]),
#  array([35, 45, 94,  6,  5, 14])]

# %%
# Next pop
# array([[38, 47, 79,  4,  5, 13],
#        [37, 47, 77,  4,  4, 11],
#        [32, 52, 79,  4,  4, 12],
#        [32, 47, 78,  4,  4,  6],
#        [40, 51, 77,  5,  9, 11],
#        [40, 47, 77,  4,  5, 13],
#        [37, 47, 81,  7,  4, 12],
#        [32, 52, 83,  4,  4,  7],
#        [32, 47, 79,  7,  4, 11],
#        [40, 51, 82,  5,  9, 14]])

pop
# Out:
# array([[35, 45, 94,  6,  5, 14],
#        [35, 45, 86,  5,  4, 11],
#        [35, 45, 96,  5,  5, 14],
#        [41, 45, 91,  5,  4, 17],
#        [38, 50, 93,  6,  8, 17],
#        [35, 45, 91,  9,  5, 11],
#        [35, 45, 98,  8,  4, 14],
#        [35, 45, 95,  5,  6, 17],
#        [43, 45, 93,  5,  5, 17],
#        [43, 50, 94,  7,  8, 14]])

# %% [markdown]
# ## Optimized Model

# %%
bestParam = genCNN.best_arch
# array([38, 47, 79,  4,  5, 13])
bestParam
# Out:
# array([35, 45, 94,  6,  5, 14])

# %%
model = Sequential()
model.add(Conv2D(bestParam[0] , (bestParam[3],bestParam[3]) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = (150,150,1)))
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model.add(Conv2D(bestParam[1] , (bestParam[4],bestParam[4]) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.1))
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model.add(Conv2D(bestParam[2] , (bestParam[5],bestParam[5]) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.2))
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model.add(Flatten())
model.add(Dense(units = 128 , activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(units = 1 , activation = 'sigmoid'))
model.compile(optimizer = "adam" , loss = 'binary_crossentropy' , metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_363 (Conv2D)         (None, 150, 150, 35)      1295
#
#  max_pooling2d_363 (MaxPool  (None, 75, 75, 35)        0
#  ing2D)
#
#  conv2d_364 (Conv2D)         (None, 75, 75, 45)        39420
#
#  dropout_363 (Dropout)       (None, 75, 75, 45)        0
#
#  max_pooling2d_364 (MaxPool  (None, 38, 38, 45)        0
#  ing2D)
#
#  conv2d_365 (Conv2D)         (None, 38, 38, 94)        829174
#
#  dropout_364 (Dropout)       (None, 38, 38, 94)        0
#
#  max_pooling2d_365 (MaxPool  (None, 19, 19, 94)        0
#  ing2D)
#
#  flatten_121 (Flatten)       (None, 33934)             0
#
#  dense_242 (Dense)           (None, 128)               4343680
#
#  dropout_365 (Dropout)       (None, 128)               0
#
#  dense_243 (Dense)           (None, 1)                 129
#
# =================================================================
# Total params: 5213698 (19.89 MB)
# Trainable params: 5213698 (19.89 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 2, verbose=1,factor=0.3, min_lr=0.000001)

# %%
history = model.fit(x_train,y_train, batch_size = 64 ,epochs = 10 , validation_data = [x_val, y_val] ,callbacks = [learning_rate_reduction])
# Out:
# Epoch 1/10
# 111/111 [==============================] - 8s 55ms/step - loss: 0.3134 - accuracy: 0.8568 - val_loss: 0.1648 - val_accuracy: 0.9453 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 6s 52ms/step - loss: 0.1373 - accuracy: 0.9495 - val_loss: 0.1226 - val_accuracy: 0.9538 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 6s 52ms/step - loss: 0.1020 - accuracy: 0.9628 - val_loss: 0.1684 - val_accuracy: 0.9436 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 6s 52ms/step - loss: 0.0886 - accuracy: 0.9687 - val_loss: 0.0855 - val_accuracy: 0.9761 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 6s 52ms/step - loss: 0.0761 - accuracy: 0.9721 - val_loss: 0.1672 - val_accuracy: 0.9299 - lr: 0.0010
# Epoch 6/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0643 - accuracy: 0.9786
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 6s 52ms/step - loss: 0.0642 - accuracy: 0.9785 - val_loss: 0.0963 - val_accuracy: 0.9709 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 6s 52ms/step - loss: 0.0423 - accuracy: 0.9836 - val_loss: 0.0764 - val_accuracy: 0.9726 - lr: 3.0000e-04
# Epoch 8/10
# 111/111 [==============================] - 6s 52ms/step - loss: 0.0348 - accuracy: 0.9880 - val_loss: 0.0569 - val_accuracy: 0.9778 - lr: 3.0000e-04
# Epoch 9/10
# 111/111 [==============================] - 6s 52ms/step - loss: 0.0318 - accuracy: 0.9888 - val_loss: 0.0688 - val_accuracy: 0.9675 - lr: 3.0000e-04
# Epoch 10/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0259 - accuracy: 0.9909
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 111/111 [==============================] - 6s 52ms/step - loss: 0.0258 - accuracy: 0.9909 - val_loss: 0.0575 - val_accuracy: 0.9778 - lr: 3.0000e-04

# %%
# Adjust the range to match the number of epochs in your history data
epochs = [i for i in range(len(history.history['accuracy']))]

fig, ax = plt.subplots(1, 2, figsize=(20, 10))

train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

ax[0].plot(epochs, train_acc, 'go-', label='Training Accuracy')
ax[0].plot(epochs, val_acc, 'ro-', label='Validation Accuracy')
ax[0].set_title('Training & Validation Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs, train_loss, 'g-o', label='Training Loss')
ax[1].plot(epochs, val_loss, 'r-o', label='Validation Loss')
ax[1].set_title('Training & Validation Loss')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Loss")

plt.show()

# %%
predictions = model.predict(x_test)
predictions = predictions.reshape(1,-1)[0]
predictions[:15]
# Out:
# 19/19 [==============================] - 0s 6ms/step
# array([2.3681903e-03, 5.2601997e-02, 2.1290909e-08, 6.0916587e-04,
#        4.6599976e-04, 6.1350446e-03, 4.4982135e-03, 1.6294980e-05,
#        2.4914834e-06, 4.7084924e-07, 1.3806728e-04, 1.9324891e-04,
#        6.3928492e-05, 7.2410699e-06, 4.2000776e-03], dtype=float32)

# %%
from sklearn.metrics import classification_report

# Assuming predictions are probabilities, convert them to binary labels
binary_predictions = [1 if i > 0.5 else 0 for i in predictions]

# Generate a classification report
print(classification_report(y_test, binary_predictions, target_names=['Pneumonia (Class 0)', 'Normal (Class 1)']))
# Out:
#                      precision    recall  f1-score   support
#
# Pneumonia (Class 0)       0.99      0.97      0.98       428
#    Normal (Class 1)       0.92      0.97      0.95       159
#
#            accuracy                           0.97       587
#           macro avg       0.96      0.97      0.96       587
#        weighted avg       0.97      0.97      0.97       587

# %%
print(classification_report(y_test, binary_predictions, target_names = ['Pneumonia (Class 0)','Normal (Class 1)']))
# Out:
#                      precision    recall  f1-score   support
#
# Pneumonia (Class 0)       0.99      0.97      0.98       428
#    Normal (Class 1)       0.92      0.97      0.95       159
#
#            accuracy                           0.97       587
#           macro avg       0.96      0.97      0.96       587
#        weighted avg       0.97      0.97      0.97       587

# %%
cm = confusion_matrix(y_test,binary_predictions)
cm
# Out:
# array([[415,  13],
#        [  4, 155]])

# %%
cm = pd.DataFrame(cm , index = ['0','1'] , columns = ['0','1'])

# %%
plt.figure(figsize = (10,10))
sns.heatmap(cm,cmap= "Blues", linecolor = 'black' , linewidth = 1 , annot = True, fmt='',xticklabels = labels,yticklabels = labels)
# Out:
# <Axes: >
