# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import os

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau

# %%
print(tf.config.list_physical_devices())
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
print(tf.__version__)
# Out:
# 2.10.0

# %%
labels = ['PNEUMONIA', 'NORMAL']
img_size = 150
def get_training_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data,dtype="object")

# %%
train = get_training_data('../data/train_CLAHE')      
test = get_training_data('../data/test_CLAHE')
val = get_training_data('../data/val_CLAHE')

# %%
import seaborn as sns

# %%
print(sns.__version__)
# Out:
# 0.11.1

# %%
l = []
for i in train:
    if(i[1] == 0):
        l.append("Pneumonia")
    else:
        l.append("Normal")
sns.set_style('darkgrid')
sns.countplot(l)
# Out:
# g:\Anaconda\envs\tensorflowgpu\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# g:\Anaconda\envs\tensorflowgpu\lib\site-packages\seaborn\_core.py:1478: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
# <Axes: ylabel='count'>

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[0][0], cmap='gray')
plt.title(labels[train[0][1]])

plt.figure(figsize = (5,5))
plt.imshow(train[-1][0], cmap='gray')
plt.title(labels[train[-1][1]])
# Out:
# Text(0.5, 1.0, 'NORMAL')

# %%
x_train = []
y_train = []

x_val = []
y_val = []

x_test = []
y_test = []

for feature, label in train:
    x_train.append(feature)
    y_train.append(label)

for feature, label in test:
    x_test.append(feature)
    y_test.append(label)
    
for feature, label in val:
    x_val.append(feature)
    y_val.append(label)

# %%
# Normalize the data
x_train = np.array(x_train) / 255
x_val = np.array(x_val) / 255
x_test = np.array(x_test) / 255

# %%
# resize data for deep learning 
x_train = x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)

x_val = x_val.reshape(-1, img_size, img_size, 1)
y_val = np.array(y_val)

x_test = x_test.reshape(-1, img_size, img_size, 1)
y_test = np.array(y_test)

# %%
print("Count before augmentation:", len(x_train))
# Out:
# Count before augmentation: 4684

# %%
def load_augmented_data(augmented_dir, label, img_size):
    augmented_data = []
    for img in os.listdir(augmented_dir):
        try:
            img_arr = cv2.imread(os.path.join(augmented_dir, img), cv2.IMREAD_GRAYSCALE)
            resized_arr = cv2.resize(img_arr, (img_size, img_size))
            augmented_data.append([resized_arr, label])
        except Exception as e:
            print(e)
    return np.array(augmented_data)

# Define parameters
data_dir = '../data/train_CLAHE'  # Adjust this path to your dataset
save_dir = '../data/augmented_CLAHE/NORMAL'  # Directory to save augmented images
label = 'NORMAL'  # Class label to augment
img_size = 150  # Image size (adjust if different)
additional_images_needed = 2690  # Number of additional images needed
batch_size = 32  # Number of images to generate per original image

# Load augmented 'Normal' images (assuming label for 'Normal' is 1)
augmented_normal_data = load_augmented_data(save_dir, label=1, img_size=img_size)

# Convert to appropriate format and normalize
x_augmented_normal = np.array([i[0] for i in augmented_normal_data]) / 255
x_augmented_normal = x_augmented_normal.reshape(-1, img_size, img_size, 1)
y_augmented_normal = np.array([i[1] for i in augmented_normal_data])

# Append to existing training data
x_train = np.concatenate((x_train, x_augmented_normal), axis=0)
y_train = np.concatenate((y_train, y_augmented_normal), axis=0)

# Shuffle the dataset
indices = np.arange(x_train.shape[0])
np.random.shuffle(indices)
x_train = x_train[indices]
y_train = y_train[indices]

# Count after augmentation
print("Count after augmentation:", len(x_train))
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_20584\680744385.py:10: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(augmented_data)
# Count after augmentation: 7069

# %%
# model = Sequential()
# model.add(Conv2D(32 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = (150,150,1)))
# model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

# model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
# model.add(Dropout(0.1))
# model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

# model.add(Conv2D(100 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
# model.add(Dropout(0.2))
# model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

# model.add(Flatten())
# model.add(Dense(units = 128 , activation = 'relu'))
# model.add(Dropout(0.2))
# model.add(Dense(units = 1 , activation = 'sigmoid'))
# model.compile(optimizer = "adam" , loss = 'binary_crossentropy' , metrics = ['accuracy'])
# model.summary()


# model = Sequential()
# model.add(Conv2D(24 , (1,1) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = (150,150,1)))
# model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

# model.add(Conv2D(40 , (4,4) , strides = 1 , padding = 'same' , activation = 'relu'))
# model.add(Dropout(0.1))
# model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

# model.add(Conv2D(91 , (9,9) , strides = 1 , padding = 'same' , activation = 'relu'))
# model.add(Dropout(0.2))
# model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

# model.add(Flatten())
# model.add(Dense(units = 128 , activation = 'relu'))
# model.add(Dropout(0.2))
# model.add(Dense(units = 1 , activation = 'sigmoid'))
# model.compile(optimizer = "adam" , loss = 'binary_crossentropy' , metrics = ['accuracy'])
# model.summary()

# 15, 67, 98,  4,  6, 10 Best 5 Generation

model = Sequential()
model.add(Conv2D(15 , (4,4) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = (150,150,1)))
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model.add(Conv2D(67 , (6,6) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.1))
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model.add(Conv2D(98 , (10,10) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.2))
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model.add(Flatten())
model.add(Dense(units = 128 , activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(units = 1 , activation = 'sigmoid'))
model.compile(optimizer = "adam" , loss = 'binary_crossentropy' , metrics = ['accuracy'])
model.summary()

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 2, verbose=1,factor=0.3, min_lr=0.000001)

# %%
history = model.fit(x_train,y_train, batch_size = 64 ,epochs = 10 , validation_data = [x_val, y_val] ,callbacks = [learning_rate_reduction])

# %%
# Adjust the range to match the number of epochs in your history data
epochs = [i for i in range(len(history.history['accuracy']))]

fig, ax = plt.subplots(1, 2, figsize=(20, 10))

train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

ax[0].plot(epochs, train_acc, 'go-', label='Training Accuracy')
ax[0].plot(epochs, val_acc, 'ro-', label='Validation Accuracy')
ax[0].set_title('Training & Validation Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs, train_loss, 'g-o', label='Training Loss')
ax[1].plot(epochs, val_loss, 'r-o', label='Validation Loss')
ax[1].set_title('Training & Validation Loss')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Loss")

plt.show()

# %%
predictions = model.predict(x_test)
predictions = predictions.reshape(1,-1)[0]
predictions[:15]

# %%
from sklearn.metrics import classification_report

# Assuming predictions are probabilities, convert them to binary labels
binary_predictions = [1 if i > 0.5 else 0 for i in predictions]

# Generate a classification report
print(classification_report(y_test, binary_predictions, target_names=['Pneumonia (Class 0)', 'Normal (Class 1)']))

# %%
array([[418,  10],
       [  5, 154]], dtype=int64)

# %%
cm = confusion_matrix(y_test,binary_predictions)
cm

# %%
cm = pd.DataFrame(cm , index = ['0','1'] , columns = ['0','1'])

# %%
plt.figure(figsize = (10,10))
sns.heatmap(cm,cmap= "Blues", linecolor = 'black' , linewidth = 1 , annot = True, fmt='',xticklabels = labels,yticklabels = labels)

# %% [markdown]
# ### 4 Conv Layer

# %%
model = Sequential()
model.add(Conv2D(24 , (1,1) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = (150,150,1)))
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model.add(Conv2D(40 , (4,4) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.1))
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model.add(Conv2D(91 , (9,9) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.2))
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model.add(Flatten())
model.add(Dense(units = 128 , activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(units = 1 , activation = 'sigmoid'))
model.compile(optimizer = "adam" , loss = 'binary_crossentropy' , metrics = ['accuracy'])
model.summary()

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 2, verbose=1,factor=0.3, min_lr=0.000001)

history = model.fit(x_train,y_train, batch_size = 64 ,epochs = 10 , validation_data = [x_val, y_val] ,callbacks = [learning_rate_reduction])

# %%
# Adjust the range to match the number of epochs in your history data
epochs = [i for i in range(len(history.history['accuracy']))]

fig, ax = plt.subplots(1, 2, figsize=(20, 10))

train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

ax[0].plot(epochs, train_acc, 'go-', label='Training Accuracy')
ax[0].plot(epochs, val_acc, 'ro-', label='Validation Accuracy')
ax[0].set_title('Training & Validation Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs, train_loss, 'g-o', label='Training Loss')
ax[1].plot(epochs, val_loss, 'r-o', label='Validation Loss')
ax[1].set_title('Training & Validation Loss')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Loss")

plt.show()

# %%
predictions = model.predict(x_test)
predictions = predictions.reshape(1,-1)[0]
predictions[:15]

# %%
from sklearn.metrics import classification_report

# Assuming predictions are probabilities, convert them to binary labels
binary_predictions = [1 if i > 0.5 else 0 for i in predictions]

# Generate a classification report
print(classification_report(y_test, binary_predictions, target_names=['Pneumonia (Class 0)', 'Normal (Class 1)']))

# %%
cm = confusion_matrix(y_test,binary_predictions)
cm

# %%
cm = pd.DataFrame(cm , index = ['0','1'] , columns = ['0','1'])

plt.figure(figsize = (10,10))
sns.heatmap(cm,cmap= "Blues", linecolor = 'black' , linewidth = 1 , annot = True, fmt='',xticklabels = labels,yticklabels = labels)

# %% [markdown]
# # Optimized Optimization

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

class CNN(Sequential):
    def __init__(self, nfilters, sfilters):
        super().__init__()
        tf.random.set_seed(0)
        self.add(Conv2D(nfilters[0], kernel_size=(sfilters[0], sfilters[0]), padding='same', activation='relu', input_shape=(150, 150, 1)))
        self.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

        self.add(Conv2D(nfilters[1], kernel_size=(sfilters[1], sfilters[1]), padding='same', activation='relu'))
        self.add(Dropout(0.1))
        self.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

        self.add(Conv2D(nfilters[2], kernel_size=(sfilters[2], sfilters[2]), padding='same', activation='relu'))
        self.add(Dropout(0.2))
        self.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

        self.add(Flatten())
        self.add(Dropout(0.2))
        self.add(Dense(128, activation='relu'))
        self.add(Dense(units=1, activation='sigmoid'))
        self.compile(optimizer="adam", loss='binary_crossentropy', metrics=['accuracy'])

# %%
class Genetic:
    def __init__(self, pop_size, nlayers, max_nfilters, max_sfilters):
        self.pop_size = pop_size
        self.nlayers = nlayers
        self.max_nfilters = max_nfilters
        self.max_sfilters = max_sfilters
        self.max_acc = 0
        self.best_arch = np.zeros((1, 6))
        self.gen_acc = []
        

    # def generate_population(self):
    #     np.random.seed(0)

    #     # Membuat partisi untuk nfilter
    #     partition_size_nfilter = self.max_nfilters // self.pop_size
    #     pop_nlayers = np.array([
    #         np.random.randint(1 + i * partition_size_nfilter, (i + 1) * partition_size_nfilter, self.nlayers)
    #         for i in range(self.pop_size)
    #     ])

    #     # Membuat partisi untuk sfilter
    #     partition_size_sfilter = self.max_sfilters // self.pop_size
    #     pop_sfilters = np.array([
    #         np.random.randint(1 + i * partition_size_sfilter, (i + 1) * partition_size_sfilter, self.nlayers)
    #         for i in range(self.pop_size)
    #     ])

    #     # Menggabungkan kedua set parameter
    #     pop_total = np.concatenate((pop_nlayers, pop_sfilters), axis=1)
    #     return pop_total

    def generate_unique_values(self, max_value, taken_values):
        partition_size = max_value // self.nlayers
        unique_values = []
        for j in range(self.nlayers):
            start = j * partition_size + 1
            if j == self.nlayers - 1:  # Ensure the last partition reaches the max value
                end = max_value + 1
            else:
                end = start + partition_size
            
            # Generate a unique value within the partition
            value = np.random.randint(start, end)
            while value in taken_values:  # Ensure uniqueness
                value += 1
                if value >= end:  # Reset if exceeds partition
                    value = start
            
            taken_values.add(value)
            unique_values.append(value)
        
        return unique_values

    def generate_population(self):
        np.random.seed(0)

        # Initialize population array
        pop_total = np.zeros((self.pop_size, self.nlayers * 2), dtype=int)
        
        for i in range(self.pop_size):
            taken_values_nfilters = set()
            taken_values_sfilters = set()

            # Generate unique nfilters and sfilters for each individual
            nfilters = self.generate_unique_values(self.max_nfilters, taken_values_nfilters)
            sfilters = self.generate_unique_values(self.max_sfilters, taken_values_sfilters)
            
            # Combine nfilters and sfilters for the individual
            pop_total[i] = nfilters + sfilters

        return pop_total

    
    def select_parents(self, pop, nparents, fitness):
        parents = np.zeros((nparents, pop.shape[1]))
        for i in range(nparents):
            best = np.argmax(fitness)
            parents[i] = pop[best]
            fitness[best] = -99999
        return parents

    def crossover(self, parents):
        nchild = self.pop_size - parents.shape[0]
        nparents = parents.shape[0]
        child = np.zeros((nchild, parents.shape[1]))
        for i in range(nchild):
            first = i % nparents
            second = (i + 1) % nparents
            child[i, :2] = parents[first][:2]
            child[i, 2] = parents[second][2]
            child[i, 3:5] = parents[first][3:5]
            child[i, 5] = parents[second][5]
        return child

    def mutation(self, child):
        for i in range(child.shape[0]):
            val = np.random.randint(1, 6)
            ind = np.random.randint(1, 4) - 1
            if child[i][ind] + val > 100:
                child[i][ind] -= val
            else:
                child[i][ind] += val
            val = np.random.randint(1, 4)
            ind = np.random.randint(4, 7) - 1
            if child[i][ind] + val > 20:
                child[i][ind] -= val
            else:
                child[i][ind] += val
        return child

    def fitness(self, pop, X, Y, epochs):
        pop_acc = []
        for i in range(pop.shape[0]):
            nfilters = pop[i][0:3]
            sfilters = pop[i][3:]
            model = CNN(nfilters, sfilters)
            learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=2, verbose=1, factor=0.3, min_lr=0.000001)
            history = model.fit(X, Y, batch_size=64, epochs=epochs, validation_data=[x_val, y_val], callbacks=[learning_rate_reduction])
            acc = max(history.history['accuracy'])
            pop_acc.append(acc * 100)
        if max(pop_acc) > self.max_acc:
            self.max_acc = max(pop_acc)
            self.best_arch = pop[np.argmax(pop_acc)]
        self.gen_acc.append(max(pop_acc))
        return pop_acc

    def smooth_curve(self, factor, gen):
        smoothed_points = []
        for point in self.gen_acc:
            if smoothed_points:
                prev = smoothed_points[-1]
                smoothed_points.append(prev * factor + point * (1 - factor))
            else:
                smoothed_points.append(point)
        plt.plot(range(gen + 1), smoothed_points, 'g', label='Smoothed training acc')
        plt.xticks(np.arange(gen + 1))
        plt.legend()
        plt.title('Fitness Accuracy vs Generations')
        plt.xlabel('Generations')
        plt.ylabel('Fitness (%)')
        plt.show()

# %% [markdown]
# ## Generate 1st Population

# %%
import random
import numpy as np

def generate_unique_random_values(num_values, start, end):
    random_values = []
    while len(random_values) < num_values:
        random_value = random.randint(start, end)
        if random_value not in random_values:
            random_values.append(random_value)
    return random_values

# Example usage:
list1 = generate_unique_random_values(10, 10, 30) #number of filter in the 1st conv layer
list2 = generate_unique_random_values(10, 30, 60) #number of filter in the 2nd conv layer
list3 = generate_unique_random_values(10, 60, 90) #number of filter in the 3rd conv layer
list4 = generate_unique_random_values(10, 1, 10) #size  of filter in the 1st conv layer
list5 = generate_unique_random_values(10, 1, 10) #size of filter in the 2nd conv layer
list6 = generate_unique_random_values(10, 1, 10) #size of filter in the 3rd conv layer

result_pop = [[list1[i], list2[i], list3[i], list4[i], list5[i], list6[i]] for i in range(10)]
print(np.array(result_pop))
# Out:
# [[29 45 75  4  4  5]
#  [27 51 85  6  2  2]
#  [26 44 61  9  9  4]
#  [21 36 80  3  6  6]
#  [24 43 68 10  1  1]
#  [16 55 84  5  7  3]
#  [14 46 62  2  5  7]
#  [23 38 83  1  8  8]
#  [13 32 67  8  3 10]
#  [22 40 77  7 10  9]]

# %%
pop_size = 10
nlayers = 3
max_nfilters = 100
max_sfilters = 10
epochs = 10
num_generations = 10

genCNN = Genetic(pop_size, nlayers, max_nfilters, max_sfilters)
# pop = genCNN.generate_population()
# pop = np.array([[1, 37, 70, 2, 5, 9],
#                 [24, 40, 91, 1, 4, 9],
#                 [2, 57, 91, 2, 5, 8],
#                 [14, 42, 76, 1, 4, 10],
#                 [6, 49, 67, 3, 4, 8],
#                 [30, 53, 86, 3, 4, 8],
#                 [10, 66, 98, 3, 4, 10],
#                 [12, 62, 67, 1, 4, 8]])

pop = np.array(result_pop)

pop
# Out:
# array([[29, 45, 75,  4,  4,  5],
#        [27, 51, 85,  6,  2,  2],
#        [26, 44, 61,  9,  9,  4],
#        [21, 36, 80,  3,  6,  6],
#        [24, 43, 68, 10,  1,  1],
#        [16, 55, 84,  5,  7,  3],
#        [14, 46, 62,  2,  5,  7],
#        [23, 38, 83,  1,  8,  8],
#        [13, 32, 67,  8,  3, 10],
#        [22, 40, 77,  7, 10,  9]])

# %%
with tf.device('/cpu:0'):
   x = tf.convert_to_tensor(x_train, np.float32)
   y = tf.convert_to_tensor(y_train, np.float32)

bestModelEachGeneration = []

for i in range(num_generations + 1):
    print(pop)
    pop_acc = genCNN.fitness(pop, x, y, epochs)
    print('Best Accuracy at the generation {}: {}'.format(i, genCNN.max_acc))
    parents = genCNN.select_parents(pop, 5, pop_acc.copy())
    child = genCNN.crossover(parents)
    child = genCNN.mutation(child)
    pop = np.concatenate((parents, child), axis=0).astype('int')
    bestModelEachGeneration.append(genCNN.best_arch)
# Out:
# [[29 45 75  4  4  5]
#  [27 51 85  6  2  2]
#  [26 44 61  9  9  4]
#  [21 36 80  3  6  6]
#  [24 43 68 10  1  1]
#  [16 55 84  5  7  3]
#  [14 46 62  2  5  7]
#  [23 38 83  1  8  8]
#  [13 32 67  8  3 10]
#  [22 40 77  7 10  9]]
# Epoch 1/10
# 111/111 [==============================] - 14s 81ms/step - loss: 0.3243 - accuracy: 0.8387 - val_loss: 0.1866 - val_accuracy: 0.9350 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 8s 72ms/step - loss: 0.1452 - accuracy: 0.9453 - val_loss: 0.1368 - val_accuracy: 0.9538 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 8s 73ms/step - loss: 0.1074 - accuracy: 0.9608 - val_loss: 0.1032 - val_accuracy: 0.9692 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 8s 72ms/step - loss: 0.0883 - accuracy: 0.9704 - val_loss: 0.1046 - val_accuracy: 0.9726 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 8s 73ms/step - loss: 0.0719 - accuracy: 0.9752 - val_loss: 0.1414 - val_accuracy: 0.9538 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 8s 72ms/step - loss: 0.0661 - accuracy: 0.9771 - val_loss: 0.0777 - val_accuracy: 0.9761 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 8s 72ms/step - loss: 0.0610 - accuracy: 0.9792 - val_loss: 0.0802 - val_accuracy: 0.9709 - lr: 0.0010
# Epoch 8/10
# 111/111 [==============================] - 8s 72ms/step - loss: 0.0459 - accuracy: 0.9832 - val_loss: 0.0516 - val_accuracy: 0.9812 - lr: 0.0010
# Epoch 9/10
# 111/111 [==============================] - 8s 72ms/step - loss: 0.0420 - accuracy: 0.9849 - val_loss: 0.0724 - val_accuracy: 0.9726 - lr: 0.0010
# Epoch 10/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0510 - accuracy: 0.9808
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 8s 72ms/step - loss: 0.0510 - accuracy: 0.9809 - val_loss: 0.1005 - val_accuracy: 0.9709 - lr: 0.0010
# Epoch 1/10
# 111/111 [==============================] - 10s 72ms/step - loss: 0.3192 - accuracy: 0.8489 - val_loss: 0.1888 - val_accuracy: 0.9487 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 7s 65ms/step - loss: 0.1453 - accuracy: 0.9454 - val_loss: 0.1574 - val_accuracy: 0.9419 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 7s 64ms/step - loss: 0.1140 - accuracy: 0.9614 - val_loss: 0.1252 - val_accuracy: 0.9521 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 7s 64ms/step - loss: 0.0977 - accuracy: 0.9675 - val_loss: 0.1396 - val_accuracy: 0.9538 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 8s 70ms/step - loss: 0.0834 - accuracy: 0.9711 - val_loss: 0.1196 - val_accuracy: 0.9521 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 7s 64ms/step - loss: 0.0771 - accuracy: 0.9734 - val_loss: 0.0987 - val_accuracy: 0.9658 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 7s 63ms/step - loss: 0.0663 - accuracy: 0.9748 - val_loss: 0.1035 - val_accuracy: 0.9658 - lr: 0.0010
# Epoch 8/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0641 - accuracy: 0.9761
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 7s 63ms/step - loss: 0.0639 - accuracy: 0.9762 - val_loss: 0.1362 - val_accuracy: 0.9436 - lr: 0.0010
# Epoch 9/10
# 111/111 [==============================] - 7s 64ms/step - loss: 0.0442 - accuracy: 0.9846 - val_loss: 0.0954 - val_accuracy: 0.9624 - lr: 3.0000e-04
# Epoch 10/10
# 111/111 [==============================] - 7s 65ms/step - loss: 0.0384 - accuracy: 0.9868 - val_loss: 0.0743 - val_accuracy: 0.9692 - lr: 3.0000e-04
# Epoch 1/10
# 111/111 [==============================] - 13s 101ms/step - loss: 0.3964 - accuracy: 0.7928 - val_loss: 0.2250 - val_accuracy: 0.9060 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 10s 87ms/step - loss: 0.1339 - accuracy: 0.9506 - val_loss: 0.1390 - val_accuracy: 0.9453 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 10s 86ms/step - loss: 0.1170 - accuracy: 0.9588 - val_loss: 0.1023 - val_accuracy: 0.9641 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 10s 87ms/step - loss: 0.0960 - accuracy: 0.9651 - val_loss: 0.1329 - val_accuracy: 0.9487 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0923 - accuracy: 0.9689
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 10s 87ms/step - loss: 0.0923 - accuracy: 0.9689 - val_loss: 0.1258 - val_accuracy: 0.9453 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 10s 86ms/step - loss: 0.0639 - accuracy: 0.9779 - val_loss: 0.0920 - val_accuracy: 0.9624 - lr: 3.0000e-04
# Epoch 7/10
# 111/111 [==============================] - 10s 86ms/step - loss: 0.0580 - accuracy: 0.9786 - val_loss: 0.0699 - val_accuracy: 0.9778 - lr: 3.0000e-04
# Epoch 8/10
# 111/111 [==============================] - 10s 88ms/step - loss: 0.0521 - accuracy: 0.9808 - val_loss: 0.0615 - val_accuracy: 0.9778 - lr: 3.0000e-04
# Epoch 9/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0503 - accuracy: 0.9815
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 111/111 [==============================] - 10s 89ms/step - loss: 0.0505 - accuracy: 0.9815 - val_loss: 0.0810 - val_accuracy: 0.9709 - lr: 3.0000e-04
# Epoch 10/10
# 111/111 [==============================] - 10s 87ms/step - loss: 0.0429 - accuracy: 0.9849 - val_loss: 0.0718 - val_accuracy: 0.9744 - lr: 9.0000e-05
# Epoch 1/10
# 111/111 [==============================] - 11s 83ms/step - loss: 0.3267 - accuracy: 0.8447 - val_loss: 0.1592 - val_accuracy: 0.9436 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 8s 73ms/step - loss: 0.1336 - accuracy: 0.9485 - val_loss: 0.1484 - val_accuracy: 0.9453 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 8s 74ms/step - loss: 0.1114 - accuracy: 0.9608 - val_loss: 0.1114 - val_accuracy: 0.9761 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 8s 73ms/step - loss: 0.0979 - accuracy: 0.9656 - val_loss: 0.1080 - val_accuracy: 0.9658 - lr: 0.0010
# Epoch 5/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0794 - accuracy: 0.9724
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 8s 75ms/step - loss: 0.0791 - accuracy: 0.9726 - val_loss: 0.1119 - val_accuracy: 0.9590 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 8s 73ms/step - loss: 0.0587 - accuracy: 0.9813 - val_loss: 0.1049 - val_accuracy: 0.9538 - lr: 3.0000e-04
# Epoch 7/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0548 - accuracy: 0.9804
# Epoch 7: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 111/111 [==============================] - 8s 73ms/step - loss: 0.0547 - accuracy: 0.9805 - val_loss: 0.0948 - val_accuracy: 0.9658 - lr: 3.0000e-04
# Epoch 8/10
# 111/111 [==============================] - 8s 73ms/step - loss: 0.0451 - accuracy: 0.9859 - val_loss: 0.0782 - val_accuracy: 0.9709 - lr: 9.0000e-05
# Epoch 9/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0453 - accuracy: 0.9849
# Epoch 9: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 111/111 [==============================] - 8s 74ms/step - loss: 0.0453 - accuracy: 0.9850 - val_loss: 0.0916 - val_accuracy: 0.9658 - lr: 9.0000e-05
# Epoch 10/10
# 111/111 [==============================] - 8s 73ms/step - loss: 0.0418 - accuracy: 0.9856 - val_loss: 0.0942 - val_accuracy: 0.9641 - lr: 2.7000e-05
# Epoch 1/10
# 111/111 [==============================] - 8s 59ms/step - loss: 0.3959 - accuracy: 0.8038 - val_loss: 0.2599 - val_accuracy: 0.9077 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 6s 54ms/step - loss: 0
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 11s 100ms/step - loss: 0.0874 - accuracy: 0.9690 - val_loss: 0.1231 - val_accuracy: 0.9521 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 11s 100ms/step - loss: 0.0612 - accuracy: 0.9772 - val_loss: 0.1081 - val_accuracy: 0.9504 - lr: 3.0000e-04
# Epoch 7/10
# 111/111 [==============================] - 11s 100ms/step - loss: 0.0570 - accuracy: 0.9803 - val_loss: 0.0823 - val_accuracy: 0.9658 - lr: 3.0000e-04
# Epoch 8/10
# 111/111 [==============================] - 11s 100ms/step - loss: 0.0490 - accuracy: 0.9820 - val_loss: 0.0883 - val_accuracy: 0.9675 - lr: 3.0000e-04
# Epoch 9/10
# 111/111 [==============================] - 11s 100ms/step - loss: 0.0449 - accuracy: 0.9844 - val_loss: 0.1047 - val_accuracy: 0.9556 - lr: 3.0000e-04
# Epoch 10/10
# 111/111 [==============================] - 11s 101ms/step - loss: 0.0442 - accuracy: 0.9844 - val_loss: 0.0642 - val_accuracy: 0.9744 - lr: 3.0000e-04
# Epoch 1/10
# 111/111 [==============================] - 14s 102ms/step - loss: 0.3144 - accuracy: 0.8383 - val_loss: 0.1699 - val_accuracy: 0.9453 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 10s 88ms/step - loss: 0.1230 - accuracy: 0.9537 - val_loss: 0.1329 - val_accuracy: 0.9607 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 10s 88ms/step - loss: 0.0925 - accuracy: 0.9690 - val_loss: 0.0733 - val_accuracy: 0.9846 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 10s 88ms/step - loss: 0.0831 - accuracy: 0.9700 - val_loss: 0.1272 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 5/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0609 - accuracy: 0.9778
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 10s 88ms/step - loss: 0.0607 - accuracy: 0.9779 - val_loss: 0.0966 - val_accuracy: 0.9692 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 10s 88ms/step - loss: 0.0446 - accuracy: 0.9849 - val_loss: 0.0869 - val_accuracy: 0.9675 - lr: 3.0000e-04
# Epoch 7/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0358 - accuracy: 0.9869
# Epoch 7: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 111/111 [==============================] - 10s 89ms/step - loss: 0.0358 - accuracy: 0.9870 - val_loss: 0.0690 - val_accuracy: 0.9744 - lr: 3.0000e-04
# Epoch 8/10
# 111/111 [==============================] - 10s 88ms/step - loss: 0.0288 - accuracy: 0.9892 - val_loss: 0.0576 - val_accuracy: 0.9778 - lr: 9.0000e-05
# Epoch 9/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0285 - accuracy: 0.9902
# Epoch 9: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 111/111 [==============================] - 10s 88ms/step - loss: 0.0286 - accuracy: 0.9901 - val_loss: 0.0780 - val_accuracy: 0.9709 - lr: 9.0000e-05
# Epoch 10/10
# 111/111 [==============================] - 10s 88ms/step - loss: 0.0246 - accuracy: 0.9915 - val_loss: 0.0744 - val_accuracy: 0.9709 - lr: 2.7000e-05
# Epoch 1/10
# 111/111 [==============================] - 19s 135ms/step - loss: 0.3962 - accuracy: 0.8189 - val_loss: 0.2020 - val_accuracy: 0.9299 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 13s 114ms/step - loss: 0.1491 - accuracy: 0.9450 - val_loss: 0.2217 - val_accuracy: 0.9162 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 13s 114ms/step - loss: 0.1201 - accuracy: 0.9553 - val_loss: 0.1470 - val_accuracy: 0.9436 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 13s 114ms/step - loss: 0.1022 - accuracy: 0.9663 - val_loss: 0.1254 - val_accuracy: 0.9538 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 13s 114ms/step - loss: 0.0857 - accuracy: 0.9703 - val_loss: 0.1324 - val_accuracy: 0.9521 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 13s 113ms/step - loss: 0.0806 - accuracy: 0.9707 - val_loss: 0.0946 - val_accuracy: 0.9709 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 13s 114ms/step - loss: 0.0734 - accuracy: 0.9751 - val_loss: 0.1022 - val_accuracy: 0.9692 - lr: 0.0010
# Epoch 8/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0640 - accuracy: 0.9769
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 13s 114ms/step - loss: 0.0640 - accuracy: 0.9769 - val_loss: 0.0799 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 9/10
# 111/111 [==============================] - 13s 114ms/step - loss: 0.0421 - accuracy: 0.9839 - val_loss: 0.0787 - val_accuracy: 0.9675 - lr: 3.0000e-04
# Epoch 10/10
# 111/111 [==============================] - 13s 113ms/step - loss: 0.0354 - accuracy: 0.9874 - val_loss: 0.0662 - val_accuracy: 0.9726 - lr: 3.0000e-04
# Epoch 1/10
# 111/111 [==============================] - 14s 99ms/step - loss: 0.3859 - accuracy: 0.7963 - val_loss: 0.1534 - val_accuracy: 0.9521 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 10s 86ms/step - loss: 0.1227 - accuracy: 0.9537 - val_loss: 0.1022 - val_accuracy: 0.9590 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 9s 85ms/step - loss: 0.0920 - accuracy: 0.9670 - val_loss: 0.0786 - val_accuracy: 0.9812 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 9s 85ms/step - loss: 0.0835 - accuracy: 0.9723 - val_loss: 0.0860 - val_accuracy: 0.9795 - lr: 0.0010
# Epoch 5/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0612 - accuracy: 0.9793
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 9s 85ms/step - loss: 0.0611 - accuracy: 0.9792 - val_loss: 0.0733 - val_accuracy: 0.9726 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 9s 86ms/step - loss: 0.0440 - accuracy: 0.9847 - val_loss: 0.0747 - val_accuracy: 0.9675 - lr: 3.0000e-04
# Epoch 7/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0340 - accuracy: 0.9869
# Epoch 7: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 111/111 [==============================] - 9s 86ms/step - loss: 0.0339 - accuracy: 0.9870 - val_loss: 0.0630 - val_accuracy: 0.9778 - lr: 3.0000e-04
# Epoch 8/10
# 111/111 [==============================] - 9s 85ms/step - loss: 0.0244 - accuracy: 0.9914 - val_loss: 0.0566 - val_accuracy: 0.9795 - lr: 9.0000e-05
# Epoch 9/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0226 - accuracy: 0.9919
# Epoch 9: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 111/111 [==============================] - 9s 85ms/step - loss: 0.0226 - accuracy: 0.9919 - val_loss: 0.0590 - val_accuracy: 0.9778 - lr: 9.0000e-05
# Epoch 10/10
# 111/111 [==============================] - 9s 85ms/step - loss: 0.0189 - accuracy: 0.9931 - val_loss: 0.0613 - val_accuracy: 0.9744 - lr: 2.7000e-05
# Best Accuracy at the generation 10: 99.30683374404907

# %%
genCNN.smooth_curve(0.5,num_generations)

# %%
genCNN.best_arch
# Out:
# array([38, 47, 79,  4,  5, 13])

# %%
genCNN.max_acc
# Out:
# 99.30683374404907

# %%
genCNN.gen_acc
# Out:
# [98.68439435958862,
#  99.0522027015686,
#  99.02390837669373,
#  98.99561405181885,
#  98.78342151641846,
#  98.91073703765869,
#  99.09464120864868,
#  99.0663468837738,
#  98.7268328666687,
#  98.88244271278381,
#  99.30683374404907]

# %%
bestModelEachGeneration
# Out:
# [array([27, 51, 85,  6,  2,  2]),
#  array([29, 45, 75,  4,  4,  5]),
#  array([29, 45, 75,  4,  4,  5]),
#  array([29, 45, 75,  4,  4,  5]),
#  array([29, 45, 75,  4,  4,  5]),
#  array([29, 45, 75,  4,  4,  5]),
#  array([32, 49, 75,  5,  4,  5]),
#  array([32, 49, 75,  5,  4,  5]),
#  array([32, 49, 75,  5,  4,  5]),
#  array([32, 49, 75,  5,  4,  5]),
#  array([38, 47, 79,  4,  5, 13])]

# %%
# Next pop
# array([[38, 47, 79,  4,  5, 13],
#        [37, 47, 77,  4,  4, 11],
#        [32, 52, 79,  4,  4, 12],
#        [32, 47, 78,  4,  4,  6],
#        [40, 51, 77,  5,  9, 11],
#        [40, 47, 77,  4,  5, 13],
#        [37, 47, 81,  7,  4, 12],
#        [32, 52, 83,  4,  4,  7],
#        [32, 47, 79,  7,  4, 11],
#        [40, 51, 82,  5,  9, 14]])

pop
# Out:
# array([[38, 47, 79,  4,  5, 13],
#        [37, 47, 77,  4,  4, 11],
#        [32, 52, 79,  4,  4, 12],
#        [32, 47, 78,  4,  4,  6],
#        [40, 51, 77,  5,  9, 11],
#        [40, 47, 77,  4,  5, 13],
#        [37, 47, 81,  7,  4, 12],
#        [32, 52, 83,  4,  4,  7],
#        [32, 47, 79,  7,  4, 11],
#        [40, 51, 82,  5,  9, 14]])

# %% [markdown]
# ## Optimized Model

# %%
bestParam = genCNN.best_arch
# array([38, 47, 79,  4,  5, 13])
bestParam
# Out:
# array([38, 47, 79,  4,  5, 13])

# %%
model = Sequential()
model.add(Conv2D(bestParam[0] , (bestParam[3],bestParam[3]) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = (150,150,1)))
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model.add(Conv2D(bestParam[1] , (bestParam[4],bestParam[4]) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.1))
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model.add(Conv2D(bestParam[2] , (bestParam[5],bestParam[5]) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.2))
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model.add(Flatten())
model.add(Dense(units = 128 , activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(units = 1 , activation = 'sigmoid'))
model.compile(optimizer = "adam" , loss = 'binary_crossentropy' , metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_330 (Conv2D)         (None, 150, 150, 38)      646
#
#  max_pooling2d_330 (MaxPooli  (None, 75, 75, 38)       0
#  ng2D)
#
#  conv2d_331 (Conv2D)         (None, 75, 75, 47)        44697
#
#  dropout_330 (Dropout)       (None, 75, 75, 47)        0
#
#  max_pooling2d_331 (MaxPooli  (None, 38, 38, 47)       0
#  ng2D)
#
#  conv2d_332 (Conv2D)         (None, 38, 38, 79)        627576
#
#  dropout_331 (Dropout)       (None, 38, 38, 79)        0
#
#  max_pooling2d_332 (MaxPooli  (None, 19, 19, 79)       0
#  ng2D)
#
#  flatten_110 (Flatten)       (None, 28519)             0
#
#  dense_220 (Dense)           (None, 128)               3650560
#
#  dropout_332 (Dropout)       (None, 128)               0
#
#  dense_221 (Dense)           (None, 1)                 129
#
# =================================================================
# Total params: 4,323,608
# Trainable params: 4,323,608
# Non-trainable params: 0
# _________________________________________________________________

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 2, verbose=1,factor=0.3, min_lr=0.000001)

# %%
history = model.fit(x_train,y_train, batch_size = 64 ,epochs = 10 , validation_data = [x_val, y_val] ,callbacks = [learning_rate_reduction])
# Out:
# Epoch 1/10
# 111/111 [==============================] - 19s 153ms/step - loss: 0.3914 - accuracy: 0.8120 - val_loss: 0.1518 - val_accuracy: 0.9521 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 28s 253ms/step - loss: 0.1242 - accuracy: 0.9554 - val_loss: 0.1043 - val_accuracy: 0.9709 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 28s 254ms/step - loss: 0.0983 - accuracy: 0.9669 - val_loss: 0.0709 - val_accuracy: 0.9812 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 28s 254ms/step - loss: 0.0849 - accuracy: 0.9689 - val_loss: 0.0864 - val_accuracy: 0.9778 - lr: 0.0010
# Epoch 5/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0663 - accuracy: 0.9764
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 28s 255ms/step - loss: 0.0661 - accuracy: 0.9765 - val_loss: 0.0748 - val_accuracy: 0.9778 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 29s 258ms/step - loss: 0.0467 - accuracy: 0.9834 - val_loss: 0.0671 - val_accuracy: 0.9744 - lr: 3.0000e-04
# Epoch 7/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0415 - accuracy: 0.9837
# Epoch 7: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 111/111 [==============================] - 28s 256ms/step - loss: 0.0414 - accuracy: 0.9837 - val_loss: 0.0654 - val_accuracy: 0.9812 - lr: 3.0000e-04
# Epoch 8/10
# 111/111 [==============================] - 28s 256ms/step - loss: 0.0332 - accuracy: 0.9877 - val_loss: 0.0529 - val_accuracy: 0.9829 - lr: 9.0000e-05
# Epoch 9/10
# 111/111 [==============================] - 29s 261ms/step - loss: 0.0320 - accuracy: 0.9880 - val_loss: 0.0627 - val_accuracy: 0.9761 - lr: 9.0000e-05
# Epoch 10/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0289 - accuracy: 0.9905
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 111/111 [==============================] - 28s 256ms/step - loss: 0.0289 - accuracy: 0.9905 - val_loss: 0.0605 - val_accuracy: 0.9778 - lr: 9.0000e-05

# %%
# Adjust the range to match the number of epochs in your history data
epochs = [i for i in range(len(history.history['accuracy']))]

fig, ax = plt.subplots(1, 2, figsize=(20, 10))

train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

ax[0].plot(epochs, train_acc, 'go-', label='Training Accuracy')
ax[0].plot(epochs, val_acc, 'ro-', label='Validation Accuracy')
ax[0].set_title('Training & Validation Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs, train_loss, 'g-o', label='Training Loss')
ax[1].plot(epochs, val_loss, 'r-o', label='Validation Loss')
ax[1].set_title('Training & Validation Loss')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Loss")

plt.show()

# %%
predictions = model.predict(x_test)
predictions = predictions.reshape(1,-1)[0]
predictions[:15]
# Out:
# 19/19 [==============================] - 1s 34ms/step
# array([5.4678740e-03, 9.7285807e-02, 2.2134730e-03, 6.0054439e-04,
#        6.0054439e-04, 3.1879537e-03, 2.0782039e-02, 3.3287067e-02,
#        5.4549082e-04, 8.7385267e-02, 3.9667540e-04, 1.0232851e-02,
#        8.4237559e-05, 6.0845000e-06, 7.9712481e-04], dtype=float32)

# %%
from sklearn.metrics import classification_report

# Assuming predictions are probabilities, convert them to binary labels
binary_predictions = [1 if i > 0.5 else 0 for i in predictions]

# Generate a classification report
print(classification_report(y_test, binary_predictions, target_names=['Pneumonia (Class 0)', 'Normal (Class 1)']))
# Out:
#                      precision    recall  f1-score   support
#
# Pneumonia (Class 0)       0.99      0.99      0.99       428
#    Normal (Class 1)       0.96      0.97      0.97       159
#
#            accuracy                           0.98       587
#           macro avg       0.98      0.98      0.98       587
#        weighted avg       0.98      0.98      0.98       587

# %%
print(classification_report(y_test, binary_predictions, target_names = ['Pneumonia (Class 0)','Normal (Class 1)']))
# Out:
#                      precision    recall  f1-score   support
#
# Pneumonia (Class 0)       0.99      0.99      0.99       428
#    Normal (Class 1)       0.96      0.97      0.97       159
#
#            accuracy                           0.98       587
#           macro avg       0.98      0.98      0.98       587
#        weighted avg       0.98      0.98      0.98       587

# %%
cm = confusion_matrix(y_test,binary_predictions)
cm
# Out:
# array([[422,   6],
#        [  5, 154]], dtype=int64)

# %%
cm = pd.DataFrame(cm , index = ['0','1'] , columns = ['0','1'])

# %%
plt.figure(figsize = (10,10))
sns.heatmap(cm,cmap= "Blues", linecolor = 'black' , linewidth = 1 , annot = True, fmt='',xticklabels = labels,yticklabels = labels)
# Out:
# <Axes: >
