# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import os

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau

# %%
print(tf.config.list_physical_devices())
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
print(tf.__version__)
# Out:
# 2.10.0

# %%
labels = ['PNEUMONIA', 'NORMAL']
img_size = 150
def get_training_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data,dtype="object")

# %%
train = get_training_data('../data/train_CLAHE')      
test = get_training_data('../data/test_CLAHE')
val = get_training_data('../data/val_CLAHE')

# %%
import seaborn as sns

# %%
print(sns.__version__)
# Out:
# 0.11.1

# %%
l = []
for i in train:
    if(i[1] == 0):
        l.append("Pneumonia")
    else:
        l.append("Normal")
sns.set_style('darkgrid')
sns.countplot(l)
# Out:
# g:\Anaconda\envs\tensorflowgpu\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# g:\Anaconda\envs\tensorflowgpu\lib\site-packages\seaborn\_core.py:1478: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
# <Axes: ylabel='count'>

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[0][0], cmap='gray')
plt.title(labels[train[0][1]])

plt.figure(figsize = (5,5))
plt.imshow(train[-1][0], cmap='gray')
plt.title(labels[train[-1][1]])
# Out:
# Text(0.5, 1.0, 'NORMAL')

# %%
x_train = []
y_train = []

x_val = []
y_val = []

x_test = []
y_test = []

for feature, label in train:
    x_train.append(feature)
    y_train.append(label)

for feature, label in test:
    x_test.append(feature)
    y_test.append(label)
    
for feature, label in val:
    x_val.append(feature)
    y_val.append(label)

# %%
# Normalize the data
x_train = np.array(x_train) / 255
x_val = np.array(x_val) / 255
x_test = np.array(x_test) / 255

# %%
# resize data for deep learning 
x_train = x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)

x_val = x_val.reshape(-1, img_size, img_size, 1)
y_val = np.array(y_val)

x_test = x_test.reshape(-1, img_size, img_size, 1)
y_test = np.array(y_test)

# %%
print("Count before augmentation:", len(x_train))
# Out:
# Count before augmentation: 4684

# %%
def load_augmented_data(augmented_dir, label, img_size):
    augmented_data = []
    for img in os.listdir(augmented_dir):
        try:
            img_arr = cv2.imread(os.path.join(augmented_dir, img), cv2.IMREAD_GRAYSCALE)
            resized_arr = cv2.resize(img_arr, (img_size, img_size))
            augmented_data.append([resized_arr, label])
        except Exception as e:
            print(e)
    return np.array(augmented_data)

# Define parameters
data_dir = '../data/train_CLAHE'  # Adjust this path to your dataset
save_dir = '../data/augmented_CLAHE/NORMAL'  # Directory to save augmented images
label = 'NORMAL'  # Class label to augment
img_size = 150  # Image size (adjust if different)
additional_images_needed = 2690  # Number of additional images needed
batch_size = 32  # Number of images to generate per original image

# Load augmented 'Normal' images (assuming label for 'Normal' is 1)
augmented_normal_data = load_augmented_data(save_dir, label=1, img_size=img_size)

# Convert to appropriate format and normalize
x_augmented_normal = np.array([i[0] for i in augmented_normal_data]) / 255
x_augmented_normal = x_augmented_normal.reshape(-1, img_size, img_size, 1)
y_augmented_normal = np.array([i[1] for i in augmented_normal_data])

# Append to existing training data
x_train = np.concatenate((x_train, x_augmented_normal), axis=0)
y_train = np.concatenate((y_train, y_augmented_normal), axis=0)

# Shuffle the dataset
indices = np.arange(x_train.shape[0])
np.random.shuffle(indices)
x_train = x_train[indices]
y_train = y_train[indices]

# Count after augmentation
print("Count after augmentation:", len(x_train))
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_13136\680744385.py:10: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(augmented_data)
# Count after augmentation: 7069

# %%
# model = Sequential()
# model.add(Conv2D(32 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = (150,150,1)))
# model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

# model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
# model.add(Dropout(0.1))
# model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

# model.add(Conv2D(100 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
# model.add(Dropout(0.2))
# model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

# model.add(Flatten())
# model.add(Dense(units = 128 , activation = 'relu'))
# model.add(Dropout(0.2))
# model.add(Dense(units = 1 , activation = 'sigmoid'))
# model.compile(optimizer = "adam" , loss = 'binary_crossentropy' , metrics = ['accuracy'])
# model.summary()


# model = Sequential()
# model.add(Conv2D(24 , (1,1) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = (150,150,1)))
# model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

# model.add(Conv2D(40 , (4,4) , strides = 1 , padding = 'same' , activation = 'relu'))
# model.add(Dropout(0.1))
# model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

# model.add(Conv2D(91 , (9,9) , strides = 1 , padding = 'same' , activation = 'relu'))
# model.add(Dropout(0.2))
# model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

# model.add(Flatten())
# model.add(Dense(units = 128 , activation = 'relu'))
# model.add(Dropout(0.2))
# model.add(Dense(units = 1 , activation = 'sigmoid'))
# model.compile(optimizer = "adam" , loss = 'binary_crossentropy' , metrics = ['accuracy'])
# model.summary()

# 15, 67, 98,  4,  6, 10 Best 5 Generation

model = Sequential()
model.add(Conv2D(15 , (4,4) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = (150,150,1)))
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model.add(Conv2D(67 , (6,6) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.1))
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model.add(Conv2D(98 , (10,10) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.2))
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model.add(Flatten())
model.add(Dense(units = 128 , activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(units = 1 , activation = 'sigmoid'))
model.compile(optimizer = "adam" , loss = 'binary_crossentropy' , metrics = ['accuracy'])
model.summary()

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 2, verbose=1,factor=0.3, min_lr=0.000001)

# %%
history = model.fit(x_train,y_train, batch_size = 64 ,epochs = 10 , validation_data = [x_val, y_val] ,callbacks = [learning_rate_reduction])

# %%
# Adjust the range to match the number of epochs in your history data
epochs = [i for i in range(len(history.history['accuracy']))]

fig, ax = plt.subplots(1, 2, figsize=(20, 10))

train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

ax[0].plot(epochs, train_acc, 'go-', label='Training Accuracy')
ax[0].plot(epochs, val_acc, 'ro-', label='Validation Accuracy')
ax[0].set_title('Training & Validation Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs, train_loss, 'g-o', label='Training Loss')
ax[1].plot(epochs, val_loss, 'r-o', label='Validation Loss')
ax[1].set_title('Training & Validation Loss')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Loss")

plt.show()

# %%
predictions = model.predict(x_test)
predictions = predictions.reshape(1,-1)[0]
predictions[:15]

# %%
from sklearn.metrics import classification_report

# Assuming predictions are probabilities, convert them to binary labels
binary_predictions = [1 if i > 0.5 else 0 for i in predictions]

# Generate a classification report
print(classification_report(y_test, binary_predictions, target_names=['Pneumonia (Class 0)', 'Normal (Class 1)']))

# %%
array([[418,  10],
       [  5, 154]], dtype=int64)

# %%
cm = confusion_matrix(y_test,binary_predictions)
cm

# %%
cm = pd.DataFrame(cm , index = ['0','1'] , columns = ['0','1'])

# %%
plt.figure(figsize = (10,10))
sns.heatmap(cm,cmap= "Blues", linecolor = 'black' , linewidth = 1 , annot = True, fmt='',xticklabels = labels,yticklabels = labels)

# %% [markdown]
# ### 4 Conv Layer

# %%
model = Sequential()
model.add(Conv2D(24 , (1,1) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = (150,150,1)))
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model.add(Conv2D(40 , (4,4) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.1))
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model.add(Conv2D(91 , (9,9) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.2))
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model.add(Flatten())
model.add(Dense(units = 128 , activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(units = 1 , activation = 'sigmoid'))
model.compile(optimizer = "adam" , loss = 'binary_crossentropy' , metrics = ['accuracy'])
model.summary()

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 2, verbose=1,factor=0.3, min_lr=0.000001)

history = model.fit(x_train,y_train, batch_size = 64 ,epochs = 10 , validation_data = [x_val, y_val] ,callbacks = [learning_rate_reduction])

# %%
# Adjust the range to match the number of epochs in your history data
epochs = [i for i in range(len(history.history['accuracy']))]

fig, ax = plt.subplots(1, 2, figsize=(20, 10))

train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

ax[0].plot(epochs, train_acc, 'go-', label='Training Accuracy')
ax[0].plot(epochs, val_acc, 'ro-', label='Validation Accuracy')
ax[0].set_title('Training & Validation Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs, train_loss, 'g-o', label='Training Loss')
ax[1].plot(epochs, val_loss, 'r-o', label='Validation Loss')
ax[1].set_title('Training & Validation Loss')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Loss")

plt.show()

# %%
predictions = model.predict(x_test)
predictions = predictions.reshape(1,-1)[0]
predictions[:15]

# %%
from sklearn.metrics import classification_report

# Assuming predictions are probabilities, convert them to binary labels
binary_predictions = [1 if i > 0.5 else 0 for i in predictions]

# Generate a classification report
print(classification_report(y_test, binary_predictions, target_names=['Pneumonia (Class 0)', 'Normal (Class 1)']))

# %%
cm = confusion_matrix(y_test,binary_predictions)
cm

# %%
cm = pd.DataFrame(cm , index = ['0','1'] , columns = ['0','1'])

plt.figure(figsize = (10,10))
sns.heatmap(cm,cmap= "Blues", linecolor = 'black' , linewidth = 1 , annot = True, fmt='',xticklabels = labels,yticklabels = labels)

# %% [markdown]
# # Optimization

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

class CNN(Sequential):
    def __init__(self, nfilters, sfilters):
        super().__init__()
        tf.random.set_seed(0)
        self.add(Conv2D(nfilters[0], kernel_size=(sfilters[0], sfilters[0]), padding='same', activation='relu', input_shape=(150, 150, 1)))
        self.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

        self.add(Conv2D(nfilters[1], kernel_size=(sfilters[1], sfilters[1]), padding='same', activation='relu'))
        self.add(Dropout(0.1))
        self.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

        self.add(Conv2D(nfilters[2], kernel_size=(sfilters[2], sfilters[2]), padding='same', activation='relu'))
        self.add(Dropout(0.2))
        self.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

        self.add(Flatten())
        self.add(Dropout(0.2))
        self.add(Dense(128, activation='relu'))
        self.add(Dense(units=1, activation='sigmoid'))
        self.compile(optimizer="adam", loss='binary_crossentropy', metrics=['accuracy'])

# %%
class Genetic:
    def __init__(self, pop_size, nlayers, max_nfilters, max_sfilters):
        self.pop_size = pop_size
        self.nlayers = nlayers
        self.max_nfilters = max_nfilters
        self.max_sfilters = max_sfilters
        self.max_acc = 0
        self.best_arch = np.zeros((1, 6))
        self.gen_acc = []
        

    # def generate_population(self):
    #     np.random.seed(0)

    #     # Membuat partisi untuk nfilter
    #     partition_size_nfilter = self.max_nfilters // self.pop_size
    #     pop_nlayers = np.array([
    #         np.random.randint(1 + i * partition_size_nfilter, (i + 1) * partition_size_nfilter, self.nlayers)
    #         for i in range(self.pop_size)
    #     ])

    #     # Membuat partisi untuk sfilter
    #     partition_size_sfilter = self.max_sfilters // self.pop_size
    #     pop_sfilters = np.array([
    #         np.random.randint(1 + i * partition_size_sfilter, (i + 1) * partition_size_sfilter, self.nlayers)
    #         for i in range(self.pop_size)
    #     ])

    #     # Menggabungkan kedua set parameter
    #     pop_total = np.concatenate((pop_nlayers, pop_sfilters), axis=1)
    #     return pop_total

    def generate_unique_values(self, max_value, taken_values):
        partition_size = max_value // self.nlayers
        unique_values = []
        for j in range(self.nlayers):
            start = j * partition_size + 1
            if j == self.nlayers - 1:  # Ensure the last partition reaches the max value
                end = max_value + 1
            else:
                end = start + partition_size
            
            # Generate a unique value within the partition
            value = np.random.randint(start, end)
            while value in taken_values:  # Ensure uniqueness
                value += 1
                if value >= end:  # Reset if exceeds partition
                    value = start
            
            taken_values.add(value)
            unique_values.append(value)
        
        return unique_values

    def generate_population(self):
        np.random.seed(0)

        # Initialize population array
        pop_total = np.zeros((self.pop_size, self.nlayers * 2), dtype=int)
        
        for i in range(self.pop_size):
            taken_values_nfilters = set()
            taken_values_sfilters = set()

            # Generate unique nfilters and sfilters for each individual
            nfilters = self.generate_unique_values(self.max_nfilters, taken_values_nfilters)
            sfilters = self.generate_unique_values(self.max_sfilters, taken_values_sfilters)
            
            # Combine nfilters and sfilters for the individual
            pop_total[i] = nfilters + sfilters

        return pop_total

    
    def select_parents(self, pop, nparents, fitness):
        parents = np.zeros((nparents, pop.shape[1]))
        for i in range(nparents):
            best = np.argmax(fitness)
            parents[i] = pop[best]
            fitness[best] = -99999
        return parents

    def crossover(self, parents):
        nchild = self.pop_size - parents.shape[0]
        nparents = parents.shape[0]
        child = np.zeros((nchild, parents.shape[1]))
        for i in range(nchild):
            first = i % nparents
            second = (i + 1) % nparents
            child[i, :2] = parents[first][:2]
            child[i, 2] = parents[second][2]
            child[i, 3:5] = parents[first][3:5]
            child[i, 5] = parents[second][5]
        return child

    def mutation(self, child):
        for i in range(child.shape[0]):
            val = np.random.randint(1, 6)
            ind = np.random.randint(1, 4) - 1
            if child[i][ind] + val > 100:
                child[i][ind] -= val
            else:
                child[i][ind] += val
            val = np.random.randint(1, 4)
            ind = np.random.randint(4, 7) - 1
            if child[i][ind] + val > 20:
                child[i][ind] -= val
            else:
                child[i][ind] += val
        return child

    def fitness(self, pop, X, Y, epochs):
        pop_acc = []
        for i in range(pop.shape[0]):
            nfilters = pop[i][0:3]
            sfilters = pop[i][3:]
            model = CNN(nfilters, sfilters)
            learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=2, verbose=1, factor=0.3, min_lr=0.000001)
            history = model.fit(X, Y, batch_size=64, epochs=epochs, validation_data=[x_val, y_val], callbacks=[learning_rate_reduction])
            acc = max(history.history['accuracy'])
            pop_acc.append(acc * 100)
        if max(pop_acc) > self.max_acc:
            self.max_acc = max(pop_acc)
            self.best_arch = pop[np.argmax(pop_acc)]
        self.gen_acc.append(max(pop_acc))
        return pop_acc

    def smooth_curve(self, factor, gen):
        smoothed_points = []
        for point in self.gen_acc:
            if smoothed_points:
                prev = smoothed_points[-1]
                smoothed_points.append(prev * factor + point * (1 - factor))
            else:
                smoothed_points.append(point)
        plt.plot(range(gen + 1), smoothed_points, 'g', label='Smoothed training acc')
        plt.xticks(np.arange(gen + 1))
        plt.legend()
        plt.title('Fitness Accuracy vs Generations')
        plt.xlabel('Generations')
        plt.ylabel('Fitness (%)')
        plt.show()

# %% [markdown]
# ## Generate 1st Population

# %%
import random
import numpy as np

def generate_unique_random_values(num_values, start, end):
    random_values = []
    while len(random_values) < num_values:
        random_value = random.randint(start, end)
        if random_value not in random_values:
            random_values.append(random_value)
    return random_values

# Example usage:
list1 = generate_unique_random_values(10, 10, 30)
list2 = generate_unique_random_values(10, 30, 60)
list3 = generate_unique_random_values(10, 60, 90)
list4 = generate_unique_random_values(10, 1, 10)
list5 = generate_unique_random_values(10, 1, 10)
list6 = generate_unique_random_values(10, 1, 10)

result_pop = [[list1[i], list2[i], list3[i], list4[i], list5[i], list6[i]] for i in range(10)]
print(np.array(result_pop))

# %%
pop_size = 10
nlayers = 3
max_nfilters = 100
max_sfilters = 10
epochs = 10
num_generations = 10

genCNN = Genetic(pop_size, nlayers, max_nfilters, max_sfilters)
# pop = genCNN.generate_population()
pop = np.array([[38, 47, 79,  4,  5, 13],
                [37, 47, 77,  4,  4, 11],
                [32, 52, 79,  4,  4, 12],
                [32, 47, 78,  4,  4,  6],
                [40, 51, 77,  5,  9, 11],
                [40, 47, 77,  4,  5, 13],
                [37, 47, 81,  7,  4, 12],
                [32, 52, 83,  4,  4,  7],
                [32, 47, 79,  7,  4, 11],
                [40, 51, 82,  5,  9, 14]])

# pop = np.array(result_pop)

pop
# Out:
# array([[38, 47, 79,  4,  5, 13],
#        [37, 47, 77,  4,  4, 11],
#        [32, 52, 79,  4,  4, 12],
#        [32, 47, 78,  4,  4,  6],
#        [40, 51, 77,  5,  9, 11],
#        [40, 47, 77,  4,  5, 13],
#        [37, 47, 81,  7,  4, 12],
#        [32, 52, 83,  4,  4,  7],
#        [32, 47, 79,  7,  4, 11],
#        [40, 51, 82,  5,  9, 14]])

# %%
with tf.device('/cpu:0'):
   x = tf.convert_to_tensor(x_train, np.float32)
   y = tf.convert_to_tensor(y_train, np.float32)

bestModelEachGeneration = []

for i in range(num_generations + 1):
    print(pop)
    pop_acc = genCNN.fitness(pop, x, y, epochs)
    print('Best Accuracy at the generation {}: {}'.format(i, genCNN.max_acc))
    parents = genCNN.select_parents(pop, 5, pop_acc.copy())
    child = genCNN.crossover(parents)
    child = genCNN.mutation(child)
    pop = np.concatenate((parents, child), axis=0).astype('int')
    bestModelEachGeneration.append(genCNN.best_arch)
# Out:
# [[38 47 79  4  5 13]
#  [37 47 77  4  4 11]
#  [32 52 79  4  4 12]
#  [32 47 78  4  4  6]
#  [40 51 77  5  9 11]
#  [40 47 77  4  5 13]
#  [37 47 81  7  4 12]
#  [32 52 83  4  4  7]
#  [32 47 79  7  4 11]
#  [40 51 82  5  9 14]]
# Epoch 1/10
# 111/111 [==============================] - 19s 104ms/step - loss: 0.3734 - accuracy: 0.8287 - val_loss: 0.2350 - val_accuracy: 0.8957 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 9s 85ms/step - loss: 0.1365 - accuracy: 0.9523 - val_loss: 0.1412 - val_accuracy: 0.9624 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 9s 85ms/step - loss: 0.1132 - accuracy: 0.9591 - val_loss: 0.1667 - val_accuracy: 0.9419 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 10s 89ms/step - loss: 0.0997 - accuracy: 0.9635 - val_loss: 0.1044 - val_accuracy: 0.9641 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 10s 87ms/step - loss: 0.0788 - accuracy: 0.9737 - val_loss: 0.1323 - val_accuracy: 0.9521 - lr: 0.0010
# Epoch 6/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0696 - accuracy: 0.9754
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 9s 84ms/step - loss: 0.0693 - accuracy: 0.9755 - val_loss: 0.1109 - val_accuracy: 0.9556 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 9s 84ms/step - loss: 0.0529 - accuracy: 0.9815 - val_loss: 0.1063 - val_accuracy: 0.9556 - lr: 3.0000e-04
# Epoch 8/10
# 111/111 [==============================] - 9s 85ms/step - loss: 0.0470 - accuracy: 0.9837 - val_loss: 0.0766 - val_accuracy: 0.9709 - lr: 3.0000e-04
# Epoch 9/10
# 111/111 [==============================] - 9s 84ms/step - loss: 0.0424 - accuracy: 0.9839 - val_loss: 0.0714 - val_accuracy: 0.9709 - lr: 3.0000e-04
# Epoch 10/10
# 111/111 [==============================] - 9s 84ms/step - loss: 0.0400 - accuracy: 0.9860 - val_loss: 0.0751 - val_accuracy: 0.9761 - lr: 3.0000e-04
# Epoch 1/10
# 111/111 [==============================] - 14s 102ms/step - loss: 0.3894 - accuracy: 0.7970 - val_loss: 0.1716 - val_accuracy: 0.9470 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 10s 87ms/step - loss: 0.1365 - accuracy: 0.9512 - val_loss: 0.1546 - val_accuracy: 0.9436 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 10s 89ms/step - loss: 0.1021 - accuracy: 0.9646 - val_loss: 0.1089 - val_accuracy: 0.9641 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 10s 87ms/step - loss: 0.0972 - accuracy: 0.9660 - val_loss: 0.0940 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 10s 87ms/step - loss: 0.0699 - accuracy: 0.9758 - val_loss: 0.0706 - val_accuracy: 0.9863 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 10s 88ms/step - loss: 0.0598 - accuracy: 0.9791 - val_loss: 0.1024 - val_accuracy: 0.9658 - lr: 0.0010
# Epoch 7/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0510 - accuracy: 0.9810
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 10s 87ms/step - loss: 0.0508 - accuracy: 0.9810 - val_loss: 0.0887 - val_accuracy: 0.9658 - lr: 0.0010
# Epoch 8/10
# 111/111 [==============================] - 10s 87ms/step - loss: 0.0341 - accuracy: 0.9885 - val_loss: 0.0598 - val_accuracy: 0.9744 - lr: 3.0000e-04
# Epoch 9/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0299 - accuracy: 0.9899
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 111/111 [==============================] - 10s 87ms/step - loss: 0.0298 - accuracy: 0.9900 - val_loss: 0.0644 - val_accuracy: 0.9778 - lr: 3.0000e-04
# Epoch 10/10
# 111/111 [==============================] - 10s 87ms/step - loss: 0.0211 - accuracy: 0.9932 - val_loss: 0.0608 - val_accuracy: 0.9778 - lr: 9.0000e-05
# Epoch 1/10
# 111/111 [==============================] - 14s 99ms/step - loss: 0.3692 - accuracy: 0.8345 - val_loss: 0.2028 - val_accuracy: 0.9214 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 9s 83ms/step - loss: 0.1322 - accuracy: 0.9515 - val_loss: 0.1547 - val_accuracy: 0.9385 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 9s 83ms/step - loss: 0.1262 - accuracy: 0.9567 - val_loss: 0.1155 - val_accuracy: 0.9573 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 9s 82ms/step - loss: 0.1015 - accuracy: 0.9646 - val_loss: 0.0992 - val_accuracy: 0.9624 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 9s 83ms/step - loss: 0.0793 - accuracy: 0.9741 - val_loss: 0.1130 - val_accuracy: 0.9556 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 9s 82ms/step - loss: 0.0774 - accuracy: 0.9734 - val_loss: 0.0689 - val_accuracy: 0.9795 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 9s 83ms/step - loss: 0.0631 - accuracy: 0.9768 - val_loss: 0.0662 - val_accuracy: 0.9863 - lr: 0.0010
# Epoch 8/10
# 111/111 [==============================] - 9s 83ms/step - loss: 0.0597 - accuracy: 0.9795 - val_loss: 0.0867 - val_accuracy: 0.9692 - lr: 0.0010
# Epoch 9/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0505 - accuracy: 0.9826
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 9s 82ms/step - loss: 0.0505 - accuracy: 0.9826 - val_loss: 0.1426 - val_accuracy: 0.9419 - lr: 0.0010
# Epoch 10/10
# 111/111 [==============================] - 9s 83ms/step - loss: 0.0351 - accuracy: 0.9890 - val_loss: 0.0838 - val_accuracy: 0.9641 - lr: 3.0000e-04
# Epoch 1/10
# 111/111 [==============================] - 11s 86ms/step - loss: 0.3317 - accuracy: 0.8353 - val_loss: 0.1928 - val_accuracy: 0.9316 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 9s 78ms/step - loss: 0.1275 - accuracy: 0.9539 - val_loss: 0.1583 - val_accuracy: 0.9436 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 9s 78ms/step - loss: 0.1077 - accuracy: 0.9614 - val_loss: 0.1256 - val_accuracy: 0.9538 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 9s 78ms/step - loss: 0.0962 - accuracy: 0.9659 - val_loss: 0.1349 - val_accuracy: 0.9556 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 9s 79ms/step - loss: 0.0753 - accuracy: 0.9751 - val_loss: 0.1055 - val_accuracy: 0.9590 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 9s 79ms/step - loss: 0.0663 - accuracy: 0.9764 - val_loss: 0.0781 - val_accuracy: 0.9744 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 9s 78ms/step - loss: 0.0626 - accuracy: 0.9758 - val_loss: 0.0879 - val_accuracy: 0.9658 - lr: 0.0010
# Epoch 8/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0511 - accuracy: 0.9807
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 9s 78ms/step - loss: 0.0518 - accuracy: 0.9806 - val_loss: 0.0915 - val_accuracy: 0.9658 - lr: 0.0010
# Epoch 9/10
# 111/111 [==============================] - 9s 79ms/step - loss: 0.0340 - accuracy: 0.9881 - val_loss: 0.0642 - val_accuracy: 0.9709 - lr: 3.0000e-04
# Epoch 10/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0256 - accuracy: 0.9911
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 111/111 [==============================] - 9s 79ms/step - loss: 0.0255 - accuracy: 0.9911 - val_loss: 0.0829 - val_accuracy: 0.9658 - lr: 3.0000e-04
# Epoch 1/10
# 111/111 [==============================] - 19s 133ms/step - loss: 0.3689 - accuracy: 0.8209 - val_loss: 0.2011 - val_accuracy: 0.9111 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 12s 113ms/step - loss: 0.1389 - accuracy: 0.9489 - val_loss: 0.1847 - val_accuracy: 0.9402 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 13s 113ms/step - loss: 0.1226 - accuracy: 0.9559 - val_loss: 0.1856 - val_accuracy: 0.9333 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 12s 113ms/step - loss: 0.1173 - accuracy: 0.9581 - val_loss: 0.1090 - val_accuracy: 0.9607 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 12s 113ms/step - loss: 0.0895 - accuracy: 0.9680 - val_loss: 0.1171 - val_accuracy: 0.9556 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 12s 112ms/step - loss: 0.0850 - accuracy: 0.9704 - val_loss: 0.0882 - val_accuracy: 0.9658 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 12s 112ms/step - loss: 0.0724 - accuracy: 0.9737 - val_loss: 0.0892 - val_accuracy: 0.9641 - lr: 0.0010
# Epoch 8/10
# 111/111 [==============================] - 12s 113ms/step - loss: 0.0654 - accuracy: 0.9761 - val_loss: 0.0689 - val_accuracy: 0.9761 - lr: 0.0010
# Epoch 9/10
# 111/111 [==============================] - 12s 113ms/step - loss: 0.0532 - accuracy: 0.9820 - val_loss: 0.0612 - val_accuracy: 0.9795 - lr: 0.0010
# Epoch 10/10
# 111/111 [==============================] - 12s 112ms/step - loss: 0.0508 - accuracy: 0.9813 - val_loss: 0.0654 - val_accuracy: 0.9744 - lr: 0.0010
# Epoch 1/10
# 111/111 [==============================] - 14s 103ms/step - loss: 0.5808 - accuracy: 0.7106 - val_loss: 0.2257 - val_accuracy: 0.9094 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 9s 84ms/step - loss: 0.1502 - accuracy: 0.9428 - val_loss: 0.1529 - val_accuracy: 0.9350 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 9s 85ms/step - loss: 0.1368 - accuracy: 0.9478 - val_loss: 0.1052 - val_accuracy: 0.9624 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 9s 84ms/step - loss: 0.1001 - accuracy: 0.9595 - val_loss: 0.0932 - val_accuracy: 0.9624 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 9s 85ms/step - loss: 0.0765 - accuracy: 0.9709 - val_loss: 0.0862 - val_accuracy: 0.9658 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 9s 85ms/step - loss: 0.0634 - accuracy: 0.9761 - val_loss: 0.0809 - val_accuracy: 0.9726 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 9s 85ms/step - loss: 0.0582 - accuracy: 0.9776 - val_loss: 0.0705 - val_accuracy: 0.9778 - lr: 0.0010
# Epoch 8/10
# 111/111 [==============================] - 9s 85ms/step - loss: 0.0507 - accuracy: 0.9812 - val_loss: 0.0861 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 9/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0397 - accuracy: 0.9851
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 9s 85ms/step - loss: 0.0396 - accuracy: 0.9851 - val_loss: 0.0723 - val_accuracy: 0.9726 - lr: 0.0010
# Epoch 10/10
# 111/111 [==============================] - 9s 85ms/step - loss: 0.0258 - accuracy: 0.9905 - val_loss: 0.0658 - val_accuracy: 0.9761 - lr: 3.0000e-04
# Epoch 1/10
# 111/111 [==============================] - 14s 109ms/step - loss: 0.3661 - accuracy: 0.8424 - val_loss: 0.2084 - val_accuracy: 0.9162 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 11s 97ms/step - loss: 0.1485 - accuracy: 0.9437 - val_loss: 0.1366 - val_accuracy: 0.9538 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 11s 97ms/step - loss: 0.1202 - accuracy: 0.9567 - val_loss: 0.1275 - val_accuracy: 0.9521 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 11s 97ms/step - loss: 0.1154 - accuracy: 0.9566 - val_loss: 0.1061 - val_accuracy: 0.9658 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 11s 97ms/step - loss: 0.0910 - accuracy: 0.9673 - val_loss: 0.0944 - val_accuracy: 0.9624 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 11s 96ms/step - loss: 0.0788 - accuracy: 0.9733 - val_loss: 0.1016 - val_accuracy: 0.9726 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 11s 97ms/step - loss: 0.0812 - accuracy: 0.9723 - val_loss: 0.1044 - val_accuracy: 0.9590 - lr: 0.0010
# Epoch 8/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0712 - accuracy: 0.9753
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 11s 98ms/step - loss: 0.0712 - accuracy: 0.9752 - val_loss: 0.1416 - val_accuracy: 0.9419 - lr: 0.0010
# Epoch 9/10
# 111/111 [==============================] - 11s 97ms/step - loss: 0.0585 - accuracy: 0.9796 - val_loss: 0.0810 - val_accuracy: 0.9624 - lr: 3.0000e-04
# Epoch 10/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0475 - accuracy: 0.9817
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 111/111 [==============================] - 11s 97ms/step - loss: 0.0473 - accuracy: 0.9818 - val_loss: 0.0771 - val_accuracy: 0.9641 - lr: 3.0000e-04
# Epoch 1/10
# 111/111 [==============================] - 11s 87ms/step - loss: 0.3610 - accuracy: 0.8290 - val_loss: 0.1566 - val_accuracy: 0.9521 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 9s 81ms/step - loss: 0.1259 - accuracy: 0.9550 - val_loss: 0.1387 - val_accuracy: 0.9607 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 9s 81ms/step - loss: 0.1210 - accuracy: 0.9561 - val_loss: 0.1329 - val_accuracy: 0.9487 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 9s 81ms/step - loss: 0.1052 - accuracy: 0.9629 - val_loss: 0.1091 - val_accuracy: 0.9641 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 9s 81ms/step - loss: 0.0805 - accuracy: 0.9723 - val_loss: 0.1185 - val_accuracy: 0.9556 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 9s 81ms/step - loss: 0.0725 - accuracy: 0.9748 - val_loss: 0.0785 - val_accuracy: 0.9692 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 9s 81ms/step - loss: 0.0658 - accuracy: 0.9755 - val_loss: 0.1034 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 8/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0570 - accuracy: 0.9790
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 9s 80ms/step - loss: 0.0572 - accuracy: 0.9789 - val_loss: 0.0937 - val_accuracy: 0.9641 - lr: 0.0010
# Epoch 9/10
# 111/111 [==============================] - 9s 81ms/step - loss: 0.0438 - accuracy: 0.9846 - val_loss: 0.0670 - val_accuracy: 0.9761 - lr: 3.0000e-04
# Epoch 10/10
# 111/111 [==============================] - 9s 81ms/step - loss: 0.0337 - accuracy: 0.9874 - val_loss: 0.0590 - val_accuracy: 0.9778 - lr: 3.0000e-04
# Epoch 1/10
# 111/111 [==============================] - 12s 91ms/step - loss: 0.4118 - accuracy: 0.8073 - val_loss: 0.1758 - val_accuracy: 0.9333 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 9s 80ms/step - loss: 0.1342 - accuracy: 0.9511 - val_loss: 0.1502 - val_accuracy: 0.9419 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 9s 80ms/step - loss: 0.1148 - accuracy: 0.9583 - val_loss: 0.1304 - val_accuracy: 0.9538 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 9s 80ms/step - loss: 0.1043 - accuracy: 0.9618 - val_loss: 0.1129 - val_accuracy: 0.9573 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 9s 80ms/step - loss: 0.0892 - accuracy: 0.9670 - val_loss: 0.1201 - val_accuracy: 0.9487 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 9s 80ms/step - loss: 0.0772 - accuracy: 0.9720 - val_loss: 0.0758 - val_accuracy: 0.9795 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 9s 80ms/step - loss: 0.0695 - accuracy: 0.9757 - val_loss: 0.0863 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 8/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0655 - accuracy: 0.9761
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 9s 80ms/step - loss: 0.0656 - accuracy: 0.9761 - val_loss: 0.0769 - val_accuracy: 0.9709 - lr: 0.0010
# Epoch 9/10
# 111/111 [==============================] - 9s 80ms/step - loss: 0.0470 - accuracy: 0.9833 - val_loss: 0.0602 - val_accuracy: 0.9778 - lr: 3.0000e-04
# Epoch 10/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0369 - accuracy: 0.9876
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 111/111 [==============================] - 9s 80ms/step - loss: 0.0368 - accuracy: 0.9877 - val_loss: 0.0619 - val_accuracy: 0.9744 - lr: 3.0000e-04
# Epoch 1/10
# 111/111 [==============================] - 16s 124ms/step - loss: 0.4636 - accuracy: 0.8184 - val_loss: 0.1481 - val_accuracy: 0.9590 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 13s 114ms/step - loss: 0.1154 - accuracy: 0.9598 - val_loss: 0.1177 - val_accuracy: 0.9726 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 13s 114ms/step - loss: 0.0971 - accuracy: 0.9677 - val_loss: 0.1207 - val_accuracy: 0.9504 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0801 - accuracy: 0.9700
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 13s 114ms/step - loss: 0.0801 - accuracy: 0.9700 - val_loss: 0.0825 - val_accuracy: 0.9726 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 13s 114ms/step - loss: 0.0512 - accuracy: 0.9820 - val_loss: 0.0575 - val_accuracy: 0.9846 - lr: 3.0000e-04
# Epoch 6/10
# 111/111 [==============================] - 13s 114ms/step - loss: 0.0436 - accuracy: 0.9849 - val_loss: 0.0674 - val_accuracy: 0.9778 - lr: 3.0000e-04
# Epoch 7/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0382 - accuracy: 0.9864
# Epoch 7: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 111/111 [==============================] - 13s 114ms/step - loss: 0.0382 - accuracy: 0.9864 - val_loss: 0.0808 - val_accuracy: 0.9675 - lr: 3.0000e-04
# Epoch 8/10
# 111/111 [==============================] - 13s 114ms/step - loss: 0.0298 - accuracy: 0.9904 - val_loss: 0.0680 - val_accuracy: 0.9778 - lr: 9.0000e-05
# Epoch 9/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0280 - accuracy: 0.9907
# Epoch 9: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 111/111 [==============================] - 13s 114ms/step - loss: 0.0280 - accuracy: 0.9907 - val_loss: 0.0640 - val_accuracy: 0.9761 - lr: 9.0000e-05
# Epoch 10/10
# 111/111 [==============================] - 13s 114ms/step - loss: 0.0244 - accuracy: 0.9919 - val_loss: 0.0600 - val_accuracy: 0.9812 - lr: 2.7000e-05
# Best Accuracy at the generation 0: 99.32097792625427
# [[37 47 77  4  4 11]
#  [40 51 82  5  9 14]
#  [32 47 78  4  4  6]
#  [40 47 77  4  5 13]
#  [32 52 79  4  4 12]
#  [41 47 82  4  4 16]
#  [40 55 78  5  9  7]
#  [37 47 77  7  4 13]
#  [40 47 83  4  5 13]
#  [36 52 77  5  4 11]]
# Epoch 1/10
# 111/111 [==============================] - 10s 87ms/step - loss: 0.3713 - accuracy: 0.8324 - val_loss: 0.2473 - val_accuracy: 0.9060 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 10s 86ms/step - loss: 0.1382 - accuracy: 0.9499 - val_loss: 0.1430 - val_accuracy: 0.9573 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 10s 86ms/step - loss: 0.1121 - accuracy: 0.9602 - val_loss: 0.1462 - val_accuracy: 0.9624 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 10s 86ms/step - loss: 0.0957 - accuracy: 0.9663 - val_loss: 0.1156 - val_accuracy: 0.9521 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 10s 86ms/step - loss: 0.0856 - accuracy: 0.9723 - val_loss: 0.0869 - val_accuracy: 0.9744 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 10s 86ms/step - loss: 0.0762 - accuracy: 0.9730 - val_loss: 0.0751 - val_accuracy: 0.9709 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 9s 86ms/step - loss: 0.0699 - accuracy: 0.9764 - val_loss: 0.0789 - val_accuracy: 0.9795 - lr: 0.0010
# Epoch 8/10
# 111/111 [==============================] - 10s 86ms/step - loss: 0.0619 - accuracy: 0.9779 - val_loss: 0.0938 - val_accuracy: 0.9641 - lr: 0.0010
# Epoch 9/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0578 - accuracy: 0.9787
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 10s 86ms/step - loss: 0.0576 - accuracy: 0.9788 - val_loss: 0.0577 - val_accuracy: 0.9761 - lr: 0.0010
# Epoch 10/10
# 111/111 [==============================] - 10s 86ms/step - loss: 0.0384 - accuracy: 0.9864 - val_loss: 0.0578 - val_accuracy: 0.9761 - lr: 3.0000e-04
# Epoch 1/10
# 111/111 [==============================] - 13s 116ms/step - loss: 0.8146 - accuracy: 0.5101 - val_loss: 0.6974 - val_accuracy: 0.2701 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 13s 113ms/step - loss: 0.6928 - accuracy: 0.5165 - val_loss: 0.7019 - val_accuracy: 0.2701 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - ETA: 0s - loss: 0.6927 - accuracy: 0.5165
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 13s 113ms/step - loss: 0.6927 - accuracy: 0.5165 - val_loss: 0.7054 - val_accuracy: 0.2701 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 13s 113ms/step - loss: 0.6926 - accuracy: 0.5165 - val_loss: 0.7059 - val_accuracy: 0.2701 - lr: 3.0000e-04
# Epoch 5/10
# 111/111 [==============================] - ETA: 0s - loss: 0.6926 - accuracy: 0.5165
# Epoch 5: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 111/111 [==============================] - 13s 113ms/step - loss: 0.6926 - accuracy: 0.5165 - val_loss: 0.7067 - val_accuracy: 0.2701 - lr: 3.0000e-04
# Epoch 6/10
# 111/111 [==============================] - 13s 113ms/step - loss: 0.6926 - accuracy: 0.5165 - val_loss: 0.7069 - val_accuracy: 0.2701 - lr: 9.0000e-05
# Epoch 7/10
# 111/111 [==============================] - ETA: 0s - loss: 0.6926 - accuracy: 0.5165
# Epoch 7: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 111/111 [==============================] - 13s 113ms/step - loss: 0.6926 - accuracy: 0.5165 - val_loss: 0.7068 - val_accuracy: 0.2701 - lr: 9.0000e-05
# Epoch 8/10
# 111/111 [==============================] - 13s 113ms/step - loss: 0.6926 - accuracy: 0.5165 - val_loss: 0.7068 - val_accuracy: 0.2701 - lr: 2.7000e-05
# Epoch 9/10
# 111/111 [==============================] - ETA: 0s - loss: 0.6926 - accuracy: 0.5165
# Epoch 9: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 111/111 [==============================] - 13s 113ms/step - loss: 0.6926 - accuracy: 0.5165 - val_loss: 0.7069 - val_accuracy: 0.2701 - lr: 2.7000e-05
# Epoch 10/10
# 111/111 [==============================] - 13s 113ms/step - loss: 0.6926 - accuracy: 0.5165 - val_loss: 0.7069 - val_accuracy: 0.2701 - lr: 8.1000e-06
# Epoch 1/10
# 111/111 [==============================] - 9s 79ms/step - loss: 0.3438 - accuracy: 0.8370 - val_loss: 0.1744 - val_accuracy: 0.9333 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 9s 78ms/step - loss: 0.1308 - accuracy: 0.9519 - val_loss: 0.1541 - val_accuracy: 0.9573 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 9s 77ms/step - loss: 0.1262 - accuracy: 0.9539 - val_loss: 0.1311 - val_accuracy: 0.9453 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 9s 78ms/step - loss: 0.1023 - accuracy: 0.9608 - val_loss: 0.1214 - val_accuracy: 0.9641 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 9s 78ms/step - loss: 0.0890 - accuracy: 0.9675 - val_loss: 0.1113 - val_accuracy: 0.9624 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 9s 77ms/step - loss: 0.0759 - accuracy: 0.9735 - val_loss: 0.0951 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 9s 78ms/step - loss: 0.0741 - accuracy: 0.9758 - val_loss: 0.0990 - val_accuracy: 0.9624 - lr: 0.0010
# Epoch 8/10
# 111/111 [==============================] - 9s 78ms/step - loss: 0.0664 - accuracy: 0.9754 - val_loss: 0.0918 - val_accuracy: 0.9692 - lr: 0.0010
# Epoch 9/10
# 111/111 [==============================] - 9s 77ms/step - loss: 0.0585 - accuracy: 0.9782 - val_loss: 0.0994 - val_accuracy: 0.9607 - lr: 0.0010
# Epoch 10/10
# 111/111 [==============================] - 9s 77ms/step - loss: 0.0485 - accuracy: 0.9815 - val_loss: 0.0546 - val_accuracy: 0.9829 - lr: 0.0010
# Epoch 1/10
# 111/111 [==============================] - 10s 85ms/step - loss: 0.4603 - accuracy: 0.8097 - val_loss: 0.2119 - val_accuracy: 0.9248 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 9s 84ms/step - loss: 0.1429 - accuracy: 0.9488 - val_loss: 0.1423 - val_accuracy: 0.9538 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 9s 84ms/step - loss: 0.1189 - accuracy: 0.9569 - val_loss: 0.1357 - val_accuracy: 0.9487 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 9s 84ms/step - loss: 0.0981 - accuracy: 0.9629 - val_loss: 0.0937 - val_accuracy: 0.9692 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 9s 84ms/step - loss: 0.0879 - accuracy: 0.9703 - val_loss: 0.0808 - val_accuracy: 0.9744 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 9s 84ms/step - loss: 0.0733 - accuracy: 0.9743 - val_loss: 0.0712 - val_accuracy: 0.9846 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 9s 84ms/step - loss: 0.0678 - accuracy: 0.9748 - val_loss: 0.0812 - val_accuracy: 0.9761 - lr: 0.0010
# Epoch 8/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0698 - accuracy: 0.9753
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 9s 84ms/step - loss: 0.0699 - accuracy: 0.9752 - val_loss: 0.0664 - val_accuracy: 0.9795 - lr: 0.0010
# Epoch 9/10
# 111/111 [==============================] - 9s 84ms/step - loss: 0.0463 - accuracy: 0.9819 - val_loss: 0.0655 - val_accuracy: 0.9778 - lr: 3.0000e-04
# Epoch 10/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0382 - accuracy: 0.9876
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 111/111 [==============================] - 9s 84ms/step - loss: 0.0381 - accuracy: 0.9877 - val_loss: 0.0797 - val_accuracy: 0.9692 - lr: 3.0000e-04
# Epoch 1/10
# 111/111 [==============================] - 10s 82ms/step - loss: 0.3534 - accuracy: 0.8288 - val_loss: 0.1947 - val_accuracy: 0.9299 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 9s 81ms/step - loss: 0.1266 - accuracy: 0.9546 - val_loss: 0.1479 - val_accuracy: 0.9521 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 9s 81ms/step - loss: 0.1112 - accuracy: 0.9634 - val_loss: 0.1248 - val_accuracy: 0.9504 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 9s 81ms/step - loss: 0.0933 - accuracy: 0.9675 - val_loss: 0.0971 - val_accuracy: 0.9744 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 9s 81ms/step - loss: 0.0827 - accuracy: 0.9709 - val_loss: 0.0953 - val_accuracy: 0.9607 - lr: 0.0010
# Epoch 6/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0691 - accuracy: 0.9770
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 9s 81ms/step - loss: 0.0689 - accuracy: 0.9771 - val_loss: 0.0930 - val_accuracy: 0.9607 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 9s 81ms/step - loss: 0.0520 - accuracy: 0.9820 - val_loss: 0.0926 - val_accuracy: 0.9624 - lr: 3.0000e-04
# Epoch 8/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0468 - accuracy: 0.9834
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 111/111 [==============================] - 9s 81ms/step - loss: 0.0471 - accuracy: 0.9833 - val_loss: 0.0685 - val_accuracy: 0.9709 - lr: 3.0000e-04
# Epoch 9/10
# 111/111 [==============================] - 9s 81ms/step - loss: 0.0379 - accuracy: 0.9859 - val_loss: 0.0652 - val_accuracy: 0.9744 - lr: 9.0000e-05
# Epoch 10/10
# 111/111 [==============================] - 9s 81ms/step - loss: 0.0365 - accuracy: 0.9863 - val_loss: 0.0625 - val_accuracy: 0.9761 - lr: 9.0000e-05
# Epoch 1/10
# 111/111 [==============================] - 16s 115ms/step - loss: 0.3566 - accuracy: 0.8440 - val_loss: 0.2987 - val_accuracy: 0.8769 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 11s 97ms/step - loss: 0.1213 - accuracy: 0.9559 - val_loss: 0.1415 - val_accuracy: 0.9624 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 11s 98ms/step - loss: 0.0999 - accuracy: 0.9652 - val_loss: 0.1175 - val_accuracy: 0.9590 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 11s 97ms/step - loss: 0.0849 - accuracy: 0.9696 - val_loss: 0.0934 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 11s 97ms/step - loss: 0.0698 - accuracy: 0.9752 - val_loss: 0.0923 - val_accuracy: 0.9692 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 11s 97ms/step - loss: 0.0536 - accuracy: 0.9809 - val_loss: 0.0733 - val_accuracy: 0.9709 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 11s 97ms/step - loss: 0.0495 - accuracy: 0.9818 - val_loss: 0.1213 - val_accuracy: 0.9504 - lr: 0.0010
# Epoch 8/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0514 - accuracy: 0.9797
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 11s 97ms/step - loss: 0.0514 - accuracy: 0.9796 - val_loss: 0.1238 - val_accuracy: 0.9521 - lr: 0.0010
# Epoch 9/10
# 111/111 [==============================] - 11s 97ms/step - loss: 0.0295 - accuracy: 0.9902 - val_loss: 0.0535 - val_accuracy: 0.9829 - lr: 3.0000e-04
# Epoch 10/10
# 111/111 [==============================] - 11s 97ms/step - loss: 0.0205 - accuracy: 0.9934 - val_loss: 0.0432 - val_accuracy: 0.9880 - lr: 3.0000e-04
# Epoch 1/10
# 111/111 [==============================] - 18s 129ms/step - loss: 0.3506 - accuracy: 0.8392 - val_loss: 0.1742 - val_accuracy: 0.9316 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 21s 185ms/step - loss: 0.1341 - accuracy: 0.9526 - val_loss: 0.1535 - val_accuracy: 0.9453 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 20s 184ms/step - loss: 0.1277 - accuracy: 0.9552 - val_loss: 0.2034 - val_accuracy: 0.9197 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 20s 184ms/step - loss: 0.1094 - accuracy: 0.9605 - val_loss: 0.0906 - val_accuracy: 0.9692 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 20s 184ms/step - loss: 0.0894 - accuracy: 0.9700 - val_loss: 0.0968 - val_accuracy: 0.9607 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 20s 184ms/step - loss: 0.0748 - accuracy: 0.9740 - val_loss: 0.0850 - val_accuracy: 0.9795 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 20s 184ms/step - loss: 0.0672 - accuracy: 0.9761 - val_loss: 0.0861 - val_accuracy: 0.9709 - lr: 0.0010
# Epoch 8/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0645 - accuracy: 0.9754
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 20s 184ms/step - loss: 0.0645 - accuracy: 0.9754 - val_loss: 0.0671 - val_accuracy: 0.9795 - lr: 0.0010
# Epoch 9/10
# 111/111 [==============================] - 20s 184ms/step - loss: 0.0475 - accuracy: 0.9829 - val_loss: 0.0544 - val_accuracy: 0.9761 - lr: 3.0000e-04
# Epoch 10/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0403 - accuracy: 0.9866
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 111/111 [==============================] - 20s 184ms/step - loss: 0.0403 - accuracy: 0.9866 - val_loss: 0.0582 - val_accuracy: 0.9761 - lr: 3.0000e-04
# Epoch 1/10
# 111/111 [==============================] - 11s 96ms/step - loss: 0.4143 - accuracy: 0.8049 - val_loss: 0.2562 - val_accuracy: 0.8991 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 10s 94ms/step - loss: 0.1664 - accuracy: 0.9337 - val_loss: 0.1976 - val_accuracy: 0.9316 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 11s 95ms/step - loss: 0.1326 - accuracy: 0.9529 - val_loss: 0.1624 - val_accuracy: 0.9419 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 10s 94ms/step - loss: 0.1195 - accuracy: 0.9564 - val_loss: 0.1362 - val_accuracy: 0.9487 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 10s 95ms/step - loss: 0.1026 - accuracy: 0.9629 - val_loss: 0.1570 - val_accuracy: 0.9504 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 10s 94ms/step - loss: 0.0914 - accuracy: 0.9673 - val_loss: 0.0911 - val_accuracy: 0.9658 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 10s 94ms/step - loss: 0.0819 - accuracy: 0.9710 - val_loss: 0.0891 - val_accuracy: 0.9692 - lr: 0.0010
# Epoch 8/10
# 111/111 [==============================] - 10s 94ms/step - loss: 0.0767 - accuracy: 0.9741 - val_loss: 0.0800 - val_accuracy: 0.9692 - lr: 0.0010
# Epoch 9/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0769 - accuracy: 0.9736
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 11s 96ms/step - loss: 0.0767 - accuracy: 0.9737 - val_loss: 0.1129 - val_accuracy: 0.9538 - lr: 0.0010
# Epoch 10/10
# 111/111 [==============================] - 11s 95ms/step - loss: 0.0525 - accuracy: 0.9818 - val_loss: 0.0719 - val_accuracy: 0.9726 - lr: 3.0000e-04
# Epoch 1/10
# 111/111 [==============================] - 13s 95ms/step - loss: 0.4673 - accuracy: 0.7778 - val_loss: 0.1572 - val_accuracy: 0.9487 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 9s 85ms/step - loss: 0.1367 - accuracy: 0.9512 - val_loss: 0.1565 - val_accuracy: 0.9436 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 9s 85ms/step - loss: 0.1088 - accuracy: 0.9610 - val_loss: 0.1263 - val_accuracy: 0.9521 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 9s 85ms/step - loss: 0.0870 - accuracy: 0.9692 - val_loss: 0.1091 - val_accuracy: 0.9607 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 9s 85ms/step - loss: 0.0700 - accuracy: 0.9765 - val_loss: 0.1059 - val_accuracy: 0.9590 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 9s 85ms/step - loss: 0.0622 - accuracy: 0.9791 - val_loss: 0.0795 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 9s 85ms/step - loss: 0.0575 - accuracy: 0.9782 - val_loss: 0.0931 - val_accuracy: 0.9761 - lr: 0.0010
# Epoch 8/10
# 111/111 [==============================] - 9s 85ms/step - loss: 0.0611 - accuracy: 0.9757 - val_loss: 0.0953 - val_accuracy: 0.9624 - lr: 0.0010
# Epoch 9/10
# 111/111 [==============================] - 9s 85ms/step - loss: 0.0461 - accuracy: 0.9837 - val_loss: 0.0653 - val_accuracy: 0.9795 - lr: 0.0010
# Epoch 10/10
# 111/111 [==============================] - 9s 85ms/step - loss: 0.0407 - accuracy: 0.9847 - val_loss: 0.0666 - val_accuracy: 0.9778 - lr: 0.0010
# Epoch 1/10
# 111/111 [==============================] - 14s 104ms/step - loss: 0.3622 - accuracy: 0.8321 - val_loss: 0.1759 - val_accuracy: 0.9419 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 10s 89ms/step - loss: 0.1468 - accuracy: 0.9461 - val_loss: 0.1488 - val_accuracy: 0.9538 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 10s 89ms/step - loss: 0.1347 - accuracy: 0.9503 - val_loss: 0.1276 - val_accuracy: 0.9538 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 10s 89ms/step - loss: 0.1102 - accuracy: 0.9578 - val_loss: 0.1172 - val_accuracy: 0.9556 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 10s 89ms/step - loss: 0.0911 - accuracy: 0.9699 - val_loss: 0.0882 - val_accuracy: 0.9641 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 10s 89ms/step - loss: 0.0838 - accuracy: 0.9685 - val_loss: 0.1204 - val_accuracy: 0.9590 - lr: 0.0010
# Epoch 7/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0757 - accuracy: 0.9756
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 10s 89ms/step - loss: 0.0756 - accuracy: 0.9755 - val_loss: 0.1017 - val_accuracy: 0.9590 - lr: 0.0010
# Epoch 8/10
# 111/111 [==============================] - 10s 89ms/step - loss: 0.0519 - accuracy: 0.9819 - val_loss: 0.0712 - val_accuracy: 0.9744 - lr: 3.0000e-04
# Epoch 9/10
# 111/111 [==============================] - 10s 89ms/step - loss: 0.0455 - accuracy: 0.9849 - val_loss: 0.0621 - val_accuracy: 0.9795 - lr: 3.0000e-04
# Epoch 10/10
# 111/111 [==============================] - 10s 89ms/step - loss: 0.0404 - accuracy: 0.9861 - val_loss: 0.0670 - val_accuracy: 0.9778 - lr: 3.0000e-04
# Best Accuracy at the generation 1: 99.33512806892395
# [[41 47 82  4  4 16]
#  [40 47 77  4  5 13]
#  [40 55 78  5  9  7]
#  [37 47 77  4  4 11]
#  [32 52 79  4  4 12]
#  [43 47 77  4  4 14]
#  [40 47 81  4  7  7]
#  [45 55 77  7  9 11]
#  [40 47 79  4  4 13]
#  [32 56 82  4  5 16]]
# Epoch 1/10
# 111/111 [==============================] - 12s 99ms/step - loss: 0.4271 - accuracy: 0.7990 - val_loss: 0.1899 - val_accuracy: 0.9333 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 11s 97ms/step - loss: 0.1342 - accuracy: 0.9512 - val_loss: 0.1322 - val_accuracy: 0.9573 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 11s 97ms/step - loss: 0.1112 - accuracy: 0.9615 - val_loss: 0.0970 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 11s 97ms/step - loss: 0.0947 - accuracy: 0.9655 - val_loss: 0.0966 - val_accuracy: 0.9658 - lr: 0.0010
# Epoch 5/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0728 - accuracy: 0.9763
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 11s 97ms/step - loss: 0.0725 - accuracy: 0.9764 - val_loss: 0.1030 - val_accuracy: 0.9607 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 11s 97ms/step - loss: 0.0506 - accuracy: 0.9830 - val_loss: 0.0707 - val_accuracy: 0.9761 - lr: 3.0000e-04
# Epoch 7/10
# 111/111 [==============================] - 11s 98ms/step - loss: 0.0436 - accuracy: 0.9849 - val_loss: 0.1031 - val_accuracy: 0.9607 - lr: 3.0000e-04
# Epoch 8/10
# 111/111 [==============================] - 11s 98ms/step - loss: 0.0399 - accuracy: 0.9857 - val_loss: 0.0527 - val_accuracy: 0.9795 - lr: 3.0000e-04
# Epoch 9/10
# 111/111 [==============================] - 11s 98ms/step - loss: 0.0384 - accuracy: 0.9857 - val_loss: 0.0711 - val_accuracy: 0.9744 - lr: 3.0000e-04
# Epoch 10/10
# 111/111 [==============================] - 11s 98ms/step - loss: 0.0369 - accuracy: 0.9856 - val_loss: 0.0562 - val_accuracy: 0.9829 - lr: 3.0000e-04
# Epoch 1/10
# 111/111 [==============================] - 10s 85ms/step - loss: 0.5118 - accuracy: 0.7338 - val_loss: 0.3793 - val_accuracy: 0.8393 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 9s 84ms/step - loss: 0.2118 - accuracy: 0.9164 - val_loss: 0.2123 - val_accuracy: 0.9282 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 9s 84ms/step - loss: 0.1440 - accuracy: 0.9477 - val_loss: 0.1599 - val_accuracy: 0.9333 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 9s 84ms/step - loss: 0.1298 - accuracy: 0.9503 - val_loss: 0.1274 - val_accuracy: 0.9470 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 9s 83ms/step - loss: 0.1111 - accuracy: 0.9612 - val_loss: 0.1030 - val_accuracy: 0.9590 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 9s 84ms/step - loss: 0.0972 - accuracy: 0.9668 - val_loss: 0.1071 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 9s 83ms/step - loss: 0.0893 - accuracy: 0.9686 - val_loss: 0.1164 - val_accuracy: 0.9556 - lr: 0.0010
# Epoch 8/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0820 - accuracy: 0.9686
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 9s 84ms/step - loss: 0.0821 - accuracy: 0.9686 - val_loss: 0.0869 - val_accuracy: 0.9658 - lr: 0.0010
# Epoch 9/10
# 111/111 [==============================] - 9s 84ms/step - loss: 0.0683 - accuracy: 0.9764 - val_loss: 0.0798 - val_accuracy: 0.9726 - lr: 3.0000e-04
# Epoch 10/10
# 111/111 [==============================] - 9s 84ms/step - loss: 0.0605 - accuracy: 0.9772 - val_loss: 0.0773 - val_accuracy: 0.9709 - lr: 3.0000e-04
# Epoch 1/10
# 111/111 [==============================] - 13s 116ms/step - loss: 0.4244 - accuracy: 0.7957 - val_loss: 0.2198 - val_accuracy: 0.9214 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 13s 114ms/step - loss: 0.1475 - accuracy: 0.9450 - val_loss: 0.1481 - val_accuracy: 0.9538 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 13s 114ms/step - loss: 0.1203 - accuracy: 0.9584 - val_loss: 0.1423 - val_accuracy: 0.9402 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - ETA: 0s - loss: 0.1172 - accuracy: 0.9578
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 13s 114ms/step - loss: 0.1172 - accuracy: 0.9578 - val_loss: 0.1359 - val_accuracy: 0.9504 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 13s 114ms/step - loss: 0.0854 - accuracy: 0.9689 - val_loss: 0.0811 - val_accuracy: 0.9744 - lr: 3.0000e-04
# Epoch 6/10
# 111/111 [==============================] - 13s 114ms/step - loss: 0.0759 - accuracy: 0.9728 - val_loss: 0.0882 - val_accuracy: 0.9675 - lr: 3.0000e-04
# Epoch 7/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0662 - accuracy: 0.9771
# Epoch 7: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 111/111 [==============================] - 13s 114ms/step - loss: 0.0662 - accuracy: 0.9771 - val_loss: 0.0997 - val_accuracy: 0.9590 - lr: 3.0000e-04
# Epoch 8/10
# 111/111 [==============================] - 13s 114ms/step - loss: 0.0622 - accuracy: 0.9782 - val_loss: 0.0824 - val_accuracy: 0.9641 - lr: 9.0000e-05
# Epoch 9/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0586 - accuracy: 0.9795
# Epoch 9: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 111/111 [==============================] - 13s 115ms/step - loss: 0.0586 - accuracy: 0.9795 - val_loss: 0.0780 - val_accuracy: 0.9692 - lr: 9.0000e-05
# Epoch 10/10
# 111/111 [==============================] - 13s 114ms/step - loss: 0.0541 - accuracy: 0.9815 - val_loss: 0.0763 - val_accuracy: 0.9726 - lr: 2.7000e-05
# Epoch 1/10
# 111/111 [==============================] - 10s 87ms/step - loss: 0.3735 - accuracy: 0.8075 - val_loss: 0.2159 - val_accuracy: 0.9111 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 10s 86ms/step - loss: 0.1399 - accuracy: 0.9498 - val_loss: 0.1647 - val_accuracy: 0.9419 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 10s 86ms/step - loss: 0.1105 - accuracy: 0.9631 - val_loss: 0.1588 - val_accuracy: 0.9453 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 10s 86ms/step - loss: 0.0976 - accuracy: 0.9658 - val_loss: 0.1226 - val_accuracy: 0.9556 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 10s 86ms/step - loss: 0.0811 - accuracy: 0.9728 - val_loss: 0.1154 - val_accuracy: 0.9538 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 10s 86ms/step - loss: 0.0739 - accuracy: 0.9751 - val_loss: 0.0986 - val_accuracy: 0.9641 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 10s 87ms/step - loss: 0.0711 - accuracy: 0.9748 - val_loss: 0.0809 - val_accuracy: 0.9795 - lr: 0.0010
# Epoch 8/10
# 111/111 [==============================] - 10s 86ms/step - loss: 0.0621 - accuracy: 0.9764 - val_loss: 0.0917 - val_accuracy: 0.9556 - lr: 0.0010
# Epoch 9/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0524 - accuracy: 0.9797
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 10s 86ms/step - loss: 0.0523 - accuracy: 0.9798 - val_loss: 0.0757 - val_accuracy: 0.9692 - lr: 0.0010
# Epoch 10/10
# 111/111 [==============================] - 10s 86ms/step - loss: 0.0387 - accuracy: 0.9854 - val_loss: 0.0703 - val_accuracy: 0.9675 - lr: 3.0000e-04
# Epoch 1/10
# 111/111 [==============================] - 10s 83ms/step - loss: 0.3405 - accuracy: 0.8566 - val_loss: 0.1824 - val_accuracy: 0.9282 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 9s 81ms/step - loss: 0.1292 - accuracy: 0.9553 - val_loss: 0.1415 - val_accuracy: 0.9538 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 9s 82ms/step - loss: 0.1083 - accuracy: 0.9627 - val_loss: 0.1533 - val_accuracy: 0.9453 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 9s 81ms/step - loss: 0.0890 - accuracy: 0.9692 - val_loss: 0.1113 - val_accuracy: 0.9573 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 9s 81ms/step - loss: 0.0775 - accuracy: 0.9726 - val_loss: 0.0868 - val_accuracy: 0.9692 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 9s 81ms/step - loss: 0.0676 - accuracy: 0.9761 - val_loss: 0.0972 - val_accuracy: 0.9590 - lr: 0.0010
# Epoch 7/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0629 - accuracy: 0.9771
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 9s 81ms/step - loss: 0.0627 - accuracy: 0.9772 - val_loss: 0.0979 - val_accuracy: 0.9590 - lr: 0.0010
# Epoch 8/10
# 111/111 [==============================] - 9s 81ms/step - loss: 0.0422 - accuracy: 0.9839 - val_loss: 0.0611 - val_accuracy: 0.9744 - lr: 3.0000e-04
# Epoch 9/10
# 111/111 [==============================] - 9s 81ms/step - loss: 0.0340 - accuracy: 0.9884 - val_loss: 0.0648 - val_accuracy: 0.9744 - lr: 3.0000e-04
# Epoch 10/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0303 - accuracy: 0.9895
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 111/111 [==============================] - 9s 81ms/step - loss: 0.0302 - accuracy: 0.9895 - val_loss: 0.0711 - val_accuracy: 0.9675 - lr: 3.0000e-04
# Epoch 1/10
# 111/111 [==============================] - 14s 108ms/step - loss: 0.3872 - accuracy: 0.8201 - val_loss: 0.2993 - val_accuracy: 0.8684 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 10s 93ms/step - loss: 0.1372 - accuracy: 0.9496 - val_loss: 0.1481 - val_accuracy: 0.9607 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 10s 93ms/step - loss: 0.1059 - accuracy: 0.9636 - val_loss: 0.1288 - val_accuracy: 0.9538 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 10s 93ms/step - loss: 0.1002 - accuracy: 0.9649 - val_loss: 0.1099 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 10s 93ms/step - loss: 0.0840 - accuracy: 0.9716 - val_loss: 0.1102 - val_accuracy: 0.9624 - lr: 0.0010
# Epoch 6/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0758 - accuracy: 0.9741
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 10s 93ms/step - loss: 0.0755 - accuracy: 0.9743 - val_loss: 0.1084 - val_accuracy: 0.9607 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 10s 93ms/step - loss: 0.0560 - accuracy: 0.9798 - val_loss: 0.1112 - val_accuracy: 0.9573 - lr: 3.0000e-04
# Epoch 8/10
# 111/111 [==============================] - 10s 93ms/step - loss: 0.0470 - accuracy: 0.9842 - val_loss: 0.0790 - val_accuracy: 0.9726 - lr: 3.0000e-04
# Epoch 9/10
# 111/111 [==============================] - 10s 93ms/step - loss: 0.0498 - accuracy: 0.9818 - val_loss: 0.0866 - val_accuracy: 0.9726 - lr: 3.0000e-04
# Epoch 10/10
# 110/111 [============================>.] - ETA: 0s - loss: 0.0460 - accuracy: 0.9838
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# ...
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 111/111 [==============================] - 13s 115ms/step - loss: 0.0299 - accuracy: 0.9887 - val_loss: 0.0497 - val_accuracy: 0.9795 - lr: 3.0000e-04
# Epoch 9/10
# 111/111 [==============================] - 13s 115ms/step - loss: 0.0214 - accuracy: 0.9931 - val_loss: 0.0541 - val_accuracy: 0.9846 - lr: 9.0000e-05
# Epoch 10/10
# 111/111 [==============================] - 13s 115ms/step - loss: 0.0189 - accuracy: 0.9941 - val_loss: 0.0498 - val_accuracy: 0.9846 - lr: 9.0000e-05
# Epoch 1/10
# 111/111 [==============================] - 13s 109ms/step - loss: 0.5743 - accuracy: 0.7892 - val_loss: 0.1858 - val_accuracy: 0.9368 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 12s 107ms/step - loss: 0.1331 - accuracy: 0.9505 - val_loss: 0.1553 - val_accuracy: 0.9333 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - ETA: 0s - loss: 0.1139 - accuracy: 0.9610
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 12s 108ms/step - loss: 0.1139 - accuracy: 0.9610 - val_loss: 0.2073 - val_accuracy: 0.9179 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 12s 107ms/step - loss: 0.0836 - accuracy: 0.9697 - val_loss: 0.0881 - val_accuracy: 0.9675 - lr: 3.0000e-04
# Epoch 5/10
# 111/111 [==============================] - 12s 107ms/step - loss: 0.0684 - accuracy: 0.9757 - val_loss: 0.0664 - val_accuracy: 0.9761 - lr: 3.0000e-04
# Epoch 6/10
# 111/111 [==============================] - 12s 107ms/step - loss: 0.0604 - accuracy: 0.9796 - val_loss: 0.0760 - val_accuracy: 0.9726 - lr: 3.0000e-04
# Epoch 7/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0545 - accuracy: 0.9826
# Epoch 7: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 111/111 [==============================] - 12s 107ms/step - loss: 0.0545 - accuracy: 0.9826 - val_loss: 0.0970 - val_accuracy: 0.9607 - lr: 3.0000e-04
# Epoch 8/10
# 111/111 [==============================] - 12s 107ms/step - loss: 0.0443 - accuracy: 0.9843 - val_loss: 0.0686 - val_accuracy: 0.9726 - lr: 9.0000e-05
# Epoch 9/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0429 - accuracy: 0.9840
# Epoch 9: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 111/111 [==============================] - 12s 108ms/step - loss: 0.0429 - accuracy: 0.9840 - val_loss: 0.0653 - val_accuracy: 0.9744 - lr: 9.0000e-05
# Epoch 10/10
# 111/111 [==============================] - 12s 108ms/step - loss: 0.0379 - accuracy: 0.9860 - val_loss: 0.0657 - val_accuracy: 0.9744 - lr: 2.7000e-05
# Epoch 1/10
# 111/111 [==============================] - 15s 129ms/step - loss: 0.5169 - accuracy: 0.7696 - val_loss: 0.3699 - val_accuracy: 0.8462 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 14s 128ms/step - loss: 0.1695 - accuracy: 0.9356 - val_loss: 0.1608 - val_accuracy: 0.9470 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 14s 128ms/step - loss: 0.1417 - accuracy: 0.9523 - val_loss: 0.1472 - val_accuracy: 0.9436 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 14s 128ms/step - loss: 0.1242 - accuracy: 0.9553 - val_loss: 0.1251 - val_accuracy: 0.9641 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 14s 128ms/step - loss: 0.1120 - accuracy: 0.9597 - val_loss: 0.1059 - val_accuracy: 0.9573 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0925 - accuracy: 0.9679
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 14s 128ms/step - loss: 0.0925 - accuracy: 0.9679 - val_loss: 0.0987 - val_accuracy: 0.9607 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 14s 128ms/step - loss: 0.0756 - accuracy: 0.9737 - val_loss: 0.0897 - val_accuracy: 0.9709 - lr: 3.0000e-04
# Epoch 8/10
# 111/111 [==============================] - 14s 128ms/step - loss: 0.0691 - accuracy: 0.9765 - val_loss: 0.0752 - val_accuracy: 0.9812 - lr: 3.0000e-04
# Epoch 9/10
# 111/111 [==============================] - 14s 128ms/step - loss: 0.0653 - accuracy: 0.9775 - val_loss: 0.0757 - val_accuracy: 0.9778 - lr: 3.0000e-04
# Epoch 10/10
# 111/111 [==============================] - 14s 128ms/step - loss: 0.0649 - accuracy: 0.9754 - val_loss: 0.0658 - val_accuracy: 0.9829 - lr: 3.0000e-04
# Epoch 1/10
# 111/111 [==============================] - 14s 117ms/step - loss: 0.6662 - accuracy: 0.6383 - val_loss: 0.4861 - val_accuracy: 0.7521 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 13s 115ms/step - loss: 0.1630 - accuracy: 0.9375 - val_loss: 0.1229 - val_accuracy: 0.9624 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 13s 115ms/step - loss: 0.1108 - accuracy: 0.9607 - val_loss: 0.0805 - val_accuracy: 0.9709 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 13s 115ms/step - loss: 0.0814 - accuracy: 0.9710 - val_loss: 0.0891 - val_accuracy: 0.9709 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 13s 115ms/step - loss: 0.0740 - accuracy: 0.9731 - val_loss: 0.0642 - val_accuracy: 0.9795 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 13s 115ms/step - loss: 0.0620 - accuracy: 0.9778 - val_loss: 0.0624 - val_accuracy: 0.9829 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 13s 115ms/step - loss: 0.0533 - accuracy: 0.9806 - val_loss: 0.0834 - val_accuracy: 0.9726 - lr: 0.0010
# Epoch 8/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0478 - accuracy: 0.9829
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 13s 115ms/step - loss: 0.0478 - accuracy: 0.9829 - val_loss: 0.0805 - val_accuracy: 0.9692 - lr: 0.0010
# Epoch 9/10
# 111/111 [==============================] - 13s 115ms/step - loss: 0.0295 - accuracy: 0.9898 - val_loss: 0.0543 - val_accuracy: 0.9761 - lr: 3.0000e-04
# Epoch 10/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0248 - accuracy: 0.9911
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 111/111 [==============================] - 13s 115ms/step - loss: 0.0248 - accuracy: 0.9911 - val_loss: 0.0829 - val_accuracy: 0.9658 - lr: 3.0000e-04
# Epoch 1/10
# 111/111 [==============================] - 23s 148ms/step - loss: 0.6210 - accuracy: 0.7243 - val_loss: 0.1825 - val_accuracy: 0.9504 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 18s 165ms/step - loss: 0.1476 - accuracy: 0.9457 - val_loss: 0.1490 - val_accuracy: 0.9504 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 18s 166ms/step - loss: 0.0971 - accuracy: 0.9652 - val_loss: 0.1118 - val_accuracy: 0.9641 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 18s 165ms/step - loss: 0.0701 - accuracy: 0.9740 - val_loss: 0.1251 - val_accuracy: 0.9556 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0555 - accuracy: 0.9799
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 18s 166ms/step - loss: 0.0555 - accuracy: 0.9799 - val_loss: 0.0853 - val_accuracy: 0.9641 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 18s 166ms/step - loss: 0.0322 - accuracy: 0.9902 - val_loss: 0.0754 - val_accuracy: 0.9726 - lr: 3.0000e-04
# Epoch 7/10
# 111/111 [==============================] - 18s 166ms/step - loss: 0.0232 - accuracy: 0.9928 - val_loss: 0.1249 - val_accuracy: 0.9521 - lr: 3.0000e-04
# Epoch 8/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0200 - accuracy: 0.9929
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 111/111 [==============================] - 18s 165ms/step - loss: 0.0200 - accuracy: 0.9929 - val_loss: 0.0823 - val_accuracy: 0.9709 - lr: 3.0000e-04
# Epoch 9/10
# 111/111 [==============================] - 18s 165ms/step - loss: 0.0153 - accuracy: 0.9941 - val_loss: 0.0907 - val_accuracy: 0.9709 - lr: 9.0000e-05
# Epoch 10/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0127 - accuracy: 0.9965
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 111/111 [==============================] - 18s 165ms/step - loss: 0.0127 - accuracy: 0.9965 - val_loss: 0.0839 - val_accuracy: 0.9709 - lr: 9.0000e-05
# Epoch 1/10
# 111/111 [==============================] - 21s 165ms/step - loss: 0.6583 - accuracy: 0.6673 - val_loss: 0.2124 - val_accuracy: 0.9282 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 17s 154ms/step - loss: 0.1896 - accuracy: 0.9259 - val_loss: 0.1724 - val_accuracy: 0.9350 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 17s 155ms/step - loss: 0.1181 - accuracy: 0.9557 - val_loss: 0.0898 - val_accuracy: 0.9709 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 17s 154ms/step - loss: 0.0886 - accuracy: 0.9690 - val_loss: 0.0943 - val_accuracy: 0.9761 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 17s 155ms/step - loss: 0.0681 - accuracy: 0.9758 - val_loss: 0.0799 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0595 - accuracy: 0.9789
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 17s 155ms/step - loss: 0.0595 - accuracy: 0.9789 - val_loss: 0.0734 - val_accuracy: 0.9744 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 17s 155ms/step - loss: 0.0439 - accuracy: 0.9840 - val_loss: 0.0889 - val_accuracy: 0.9658 - lr: 3.0000e-04
# Epoch 8/10
# 111/111 [==============================] - 17s 155ms/step - loss: 0.0320 - accuracy: 0.9883 - val_loss: 0.0601 - val_accuracy: 0.9812 - lr: 3.0000e-04
# Epoch 9/10
# 111/111 [==============================] - 17s 155ms/step - loss: 0.0286 - accuracy: 0.9890 - val_loss: 0.0714 - val_accuracy: 0.9761 - lr: 3.0000e-04
# Epoch 10/10
# 111/111 [==============================] - 17s 155ms/step - loss: 0.0257 - accuracy: 0.9907 - val_loss: 0.0566 - val_accuracy: 0.9829 - lr: 3.0000e-04
# Epoch 1/10
# 111/111 [==============================] - 15s 120ms/step - loss: 0.5190 - accuracy: 0.7970 - val_loss: 0.2208 - val_accuracy: 0.9162 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 13s 113ms/step - loss: 0.1500 - accuracy: 0.9453 - val_loss: 0.1665 - val_accuracy: 0.9368 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 13s 113ms/step - loss: 0.1223 - accuracy: 0.9553 - val_loss: 0.1634 - val_accuracy: 0.9333 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 13s 113ms/step - loss: 0.1150 - accuracy: 0.9595 - val_loss: 0.1050 - val_accuracy: 0.9692 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 13s 114ms/step - loss: 0.0924 - accuracy: 0.9676 - val_loss: 0.1535 - val_accuracy: 0.9521 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0844 - accuracy: 0.9692
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 13s 114ms/step - loss: 0.0844 - accuracy: 0.9692 - val_loss: 0.1254 - val_accuracy: 0.9487 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 13s 114ms/step - loss: 0.0620 - accuracy: 0.9764 - val_loss: 0.0870 - val_accuracy: 0.9641 - lr: 3.0000e-04
# Epoch 8/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0573 - accuracy: 0.9803
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 111/111 [==============================] - 13s 113ms/step - loss: 0.0573 - accuracy: 0.9803 - val_loss: 0.0895 - val_accuracy: 0.9607 - lr: 3.0000e-04
# Epoch 9/10
# 111/111 [==============================] - 12s 112ms/step - loss: 0.0503 - accuracy: 0.9815 - val_loss: 0.0668 - val_accuracy: 0.9812 - lr: 9.0000e-05
# Epoch 10/10
# 111/111 [==============================] - 13s 113ms/step - loss: 0.0446 - accuracy: 0.9849 - val_loss: 0.0653 - val_accuracy: 0.9795 - lr: 9.0000e-05
# Epoch 1/10
# 111/111 [==============================] - 29s 192ms/step - loss: 0.5107 - accuracy: 0.7662 - val_loss: 0.2954 - val_accuracy: 0.8769 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 18s 165ms/step - loss: 0.1530 - accuracy: 0.9403 - val_loss: 0.1380 - val_accuracy: 0.9487 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 18s 165ms/step - loss: 0.1173 - accuracy: 0.9607 - val_loss: 0.1660 - val_accuracy: 0.9350 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 18s 165ms/step - loss: 0.1147 - accuracy: 0.9567 - val_loss: 0.1157 - val_accuracy: 0.9521 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 18s 164ms/step - loss: 0.0915 - accuracy: 0.9692 - val_loss: 0.0953 - val_accuracy: 0.9692 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 18s 165ms/step - loss: 0.0807 - accuracy: 0.9721 - val_loss: 0.1040 - val_accuracy: 0.9624 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 18s 165ms/step - loss: 0.0749 - accuracy: 0.9733 - val_loss: 0.0684 - val_accuracy: 0.9778 - lr: 0.0010
# Epoch 8/10
# 111/111 [==============================] - 18s 164ms/step - loss: 0.0683 - accuracy: 0.9760 - val_loss: 0.0753 - val_accuracy: 0.9726 - lr: 0.0010
# Epoch 9/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0647 - accuracy: 0.9767
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 18s 164ms/step - loss: 0.0647 - accuracy: 0.9767 - val_loss: 0.0827 - val_accuracy: 0.9709 - lr: 0.0010
# Epoch 10/10
# 111/111 [==============================] - 18s 164ms/step - loss: 0.0443 - accuracy: 0.9847 - val_loss: 0.0473 - val_accuracy: 0.9846 - lr: 3.0000e-04
# Epoch 1/10
# 111/111 [==============================] - 16s 132ms/step - loss: 0.5740 - accuracy: 0.7670 - val_loss: 0.1848 - val_accuracy: 0.9282 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 14s 124ms/step - loss: 0.1412 - accuracy: 0.9488 - val_loss: 0.1363 - val_accuracy: 0.9590 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 14s 124ms/step - loss: 0.1109 - accuracy: 0.9594 - val_loss: 0.1517 - val_accuracy: 0.9402 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0977 - accuracy: 0.9646
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 14s 124ms/step - loss: 0.0977 - accuracy: 0.9646 - val_loss: 0.1148 - val_accuracy: 0.9573 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 14s 124ms/step - loss: 0.0741 - accuracy: 0.9745 - val_loss: 0.0720 - val_accuracy: 0.9744 - lr: 3.0000e-04
# Epoch 6/10
# 111/111 [==============================] - 14s 125ms/step - loss: 0.0662 - accuracy: 0.9769 - val_loss: 0.0834 - val_accuracy: 0.9675 - lr: 3.0000e-04
# Epoch 7/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0603 - accuracy: 0.9810
# Epoch 7: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 111/111 [==============================] - 14s 124ms/step - loss: 0.0603 - accuracy: 0.9810 - val_loss: 0.0968 - val_accuracy: 0.9556 - lr: 3.0000e-04
# Epoch 8/10
# 111/111 [==============================] - 14s 124ms/step - loss: 0.0533 - accuracy: 0.9808 - val_loss: 0.0713 - val_accuracy: 0.9709 - lr: 9.0000e-05
# Epoch 9/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0510 - accuracy: 0.9826
# Epoch 9: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 111/111 [==============================] - 14s 125ms/step - loss: 0.0510 - accuracy: 0.9826 - val_loss: 0.0732 - val_accuracy: 0.9692 - lr: 9.0000e-05
# Epoch 10/10
# 111/111 [==============================] - 14s 124ms/step - loss: 0.0471 - accuracy: 0.9847 - val_loss: 0.0713 - val_accuracy: 0.9709 - lr: 2.7000e-05
# Best Accuracy at the generation 10: 99.66049194335938

# %%
genCNN.smooth_curve(0.5,num_generations)

# %%
genCNN.best_arch
# Out:
# array([35, 59, 80,  4,  7, 17])

# %%
genCNN.max_acc
# Out:
# 99.66049194335938

# %%
genCNN.gen_acc
# Out:
# [99.32097792625427,
#  99.33512806892395,
#  99.50488209724426,
#  99.32097792625427,
#  99.39171075820923,
#  99.51902627944946,
#  99.50488209724426,
#  99.19366240501404,
#  99.33512806892395,
#  99.66049194335938,
#  99.6463418006897]

# %%
bestModelEachGeneration
# Out:
# [array([37, 47, 77,  4,  4, 11]),
#  array([41, 47, 82,  4,  4, 16]),
#  array([40, 47, 79,  4,  4, 13]),
#  array([40, 47, 79,  4,  4, 13]),
#  array([40, 47, 79,  4,  4, 13]),
#  array([32, 56, 80,  4,  4, 18]),
#  array([32, 56, 80,  4,  4, 18]),
#  array([32, 56, 80,  4,  4, 18]),
#  array([32, 56, 80,  4,  4, 18]),
#  array([35, 59, 80,  4,  7, 17]),
#  array([35, 59, 80,  4,  7, 17])]

# %%
# Next pop
# for gen 11
# array([[38, 47, 79,  4,  5, 13],
#        [37, 47, 77,  4,  4, 11],
#        [32, 52, 79,  4,  4, 12],
#        [32, 47, 78,  4,  4,  6],
#        [40, 51, 77,  5,  9, 11],
#        [40, 47, 77,  4,  5, 13],
#        [37, 47, 81,  7,  4, 12],
#        [32, 52, 83,  4,  4,  7],
#        [32, 47, 79,  7,  4, 11],
#        [40, 51, 82,  5,  9, 14]])

# for gen 21
pop
# Out:
# array([[35, 59, 88,  4,  8, 18],
#        [35, 61, 83,  4,  6, 18],
#        [37, 59, 80,  4,  7, 15],
#        [38, 61, 83,  4,  9, 18],
#        [35, 59, 80,  4,  7, 17],
#        [39, 59, 83,  4,  8, 20],
#        [35, 65, 80,  6,  6, 15],
#        [37, 59, 85,  4, 10, 18],
#        [43, 61, 80,  4, 10, 17],
#        [35, 59, 93,  4,  7, 15]])

# %% [markdown]
# ## Optimized Model

# %%
bestParam = genCNN.best_arch
# bestParam = [38, 47, 79,  4,  5, 13]
# array([38, 47, 79,  4,  5, 13]) Gen 1 ~ 10
bestParam
# Out:
# array([35, 59, 80,  4,  7, 17])

# %%
model = Sequential()
model.add(Conv2D(bestParam[0] , (bestParam[3],bestParam[3]) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = (150,150,1)))
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model.add(Conv2D(bestParam[1] , (bestParam[4],bestParam[4]) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.1))
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model.add(Conv2D(bestParam[2] , (bestParam[5],bestParam[5]) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.2))
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model.add(Flatten())
model.add(Dense(units = 128 , activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(units = 1 , activation = 'sigmoid'))
model.compile(optimizer = "adam" , loss = 'binary_crossentropy' , metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_330 (Conv2D)         (None, 150, 150, 35)      595
#
#  max_pooling2d_330 (MaxPooli  (None, 75, 75, 35)       0
#  ng2D)
#
#  conv2d_331 (Conv2D)         (None, 75, 75, 59)        101244
#
#  dropout_330 (Dropout)       (None, 75, 75, 59)        0
#
#  max_pooling2d_331 (MaxPooli  (None, 38, 38, 59)       0
#  ng2D)
#
#  conv2d_332 (Conv2D)         (None, 38, 38, 80)        1364160
#
#  dropout_331 (Dropout)       (None, 38, 38, 80)        0
#
#  max_pooling2d_332 (MaxPooli  (None, 19, 19, 80)       0
#  ng2D)
#
#  flatten_110 (Flatten)       (None, 28880)             0
#
#  dense_220 (Dense)           (None, 128)               3696768
#
#  dropout_332 (Dropout)       (None, 128)               0
#
#  dense_221 (Dense)           (None, 1)                 129
#
# =================================================================
# Total params: 5,162,896
# Trainable params: 5,162,896
# Non-trainable params: 0
# _________________________________________________________________

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 2, verbose=1,factor=0.3, min_lr=0.000001)

# %%
history = model.fit(x_train,y_train, batch_size = 64 ,epochs = 10 , validation_data = [x_val, y_val] ,callbacks = [learning_rate_reduction])
# Out:
# Epoch 1/10
# 111/111 [==============================] - 22s 152ms/step - loss: 0.4701 - accuracy: 0.7894 - val_loss: 0.2087 - val_accuracy: 0.9197 - lr: 0.0010
# Epoch 2/10
# 111/111 [==============================] - 15s 138ms/step - loss: 0.1408 - accuracy: 0.9508 - val_loss: 0.1498 - val_accuracy: 0.9402 - lr: 0.0010
# Epoch 3/10
# 111/111 [==============================] - 15s 138ms/step - loss: 0.1101 - accuracy: 0.9615 - val_loss: 0.1532 - val_accuracy: 0.9504 - lr: 0.0010
# Epoch 4/10
# 111/111 [==============================] - 15s 138ms/step - loss: 0.0954 - accuracy: 0.9649 - val_loss: 0.0785 - val_accuracy: 0.9812 - lr: 0.0010
# Epoch 5/10
# 111/111 [==============================] - 15s 138ms/step - loss: 0.0784 - accuracy: 0.9726 - val_loss: 0.1069 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 6/10
# 111/111 [==============================] - 15s 138ms/step - loss: 0.0727 - accuracy: 0.9745 - val_loss: 0.0691 - val_accuracy: 0.9863 - lr: 0.0010
# Epoch 7/10
# 111/111 [==============================] - 15s 138ms/step - loss: 0.0624 - accuracy: 0.9772 - val_loss: 0.0663 - val_accuracy: 0.9744 - lr: 0.0010
# Epoch 8/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0543 - accuracy: 0.9825
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 111/111 [==============================] - 15s 138ms/step - loss: 0.0543 - accuracy: 0.9825 - val_loss: 0.0829 - val_accuracy: 0.9692 - lr: 0.0010
# Epoch 9/10
# 111/111 [==============================] - 15s 138ms/step - loss: 0.0380 - accuracy: 0.9867 - val_loss: 0.0696 - val_accuracy: 0.9812 - lr: 3.0000e-04
# Epoch 10/10
# 111/111 [==============================] - ETA: 0s - loss: 0.0296 - accuracy: 0.9894
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 111/111 [==============================] - 15s 138ms/step - loss: 0.0296 - accuracy: 0.9894 - val_loss: 0.0734 - val_accuracy: 0.9744 - lr: 3.0000e-04

# %%
# Adjust the range to match the number of epochs in your history data
epochs = [i for i in range(len(history.history['accuracy']))]

fig, ax = plt.subplots(1, 2, figsize=(20, 10))

train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

ax[0].plot(epochs, train_acc, 'go-', label='Training Accuracy')
ax[0].plot(epochs, val_acc, 'ro-', label='Validation Accuracy')
ax[0].set_title('Training & Validation Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs, train_loss, 'g-o', label='Training Loss')
ax[1].plot(epochs, val_loss, 'r-o', label='Validation Loss')
ax[1].set_title('Training & Validation Loss')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Loss")

plt.show()

# %%
predictions = model.predict(x_test)
predictions = predictions.reshape(1,-1)[0]
predictions[:15]
# Out:
# 19/19 [==============================] - 1s 32ms/step
# array([1.0681439e-03, 9.4904276e-03, 4.4540996e-03, 1.6565592e-04,
#        1.6565592e-04, 1.5129318e-03, 9.7634672e-04, 5.4685795e-03,
#        3.3764011e-04, 4.6314180e-02, 3.6402747e-05, 9.9140906e-04,
#        2.1454146e-06, 1.2822647e-07, 5.5159576e-04], dtype=float32)

# %%
from sklearn.metrics import classification_report

# Assuming predictions are probabilities, convert them to binary labels
binary_predictions = [1 if i > 0.5 else 0 for i in predictions]

# Generate a classification report
print(classification_report(y_test, binary_predictions, target_names=['Pneumonia (Class 0)', 'Normal (Class 1)']))
# Out:
#                      precision    recall  f1-score   support
#
# Pneumonia (Class 0)       0.99      0.98      0.98       428
#    Normal (Class 1)       0.95      0.96      0.96       159
#
#            accuracy                           0.98       587
#           macro avg       0.97      0.97      0.97       587
#        weighted avg       0.98      0.98      0.98       587

# %%
print(classification_report(y_test, binary_predictions, target_names = ['Pneumonia (Class 0)','Normal (Class 1)']))
# Out:
#                      precision    recall  f1-score   support
#
# Pneumonia (Class 0)       0.99      0.98      0.98       428
#    Normal (Class 1)       0.95      0.96      0.96       159
#
#            accuracy                           0.98       587
#           macro avg       0.97      0.97      0.97       587
#        weighted avg       0.98      0.98      0.98       587

# %%
cm = confusion_matrix(y_test,binary_predictions)
cm
# Out:
# array([[420,   8],
#        [  6, 153]], dtype=int64)

# %%
cm = pd.DataFrame(cm , index = ['0','1'] , columns = ['0','1'])

# %%
plt.figure(figsize = (10,10))
sns.heatmap(cm,cmap= "Blues", linecolor = 'black' , linewidth = 1 , annot = True, fmt='',xticklabels = labels,yticklabels = labels)
# Out:
# <Axes: >
